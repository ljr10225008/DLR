# %%
import math
import numpy as np
import sklearn
from sklearn.cluster import KMeans
import matplotlib as mpl
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import re
import seaborn as sns
import pandas as pd
import random
from scipy import stats  #t-test
import semopy
import pandas as pd
from semopy import Model
import scipy.stats as stats 
from itertools import groupby
import statsmodels.formula.api as smf
import statsmodels.api as sm
# Out:
# C:\Users\ljr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
pathturn11 = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\fanew\turn1"
filesturn11= os.listdir(pathturn11)
pathturn12 = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\fanew\turn2"
filesturn12= os.listdir(pathturn12)
pathturn13 = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\fanew\turn3"
filesturn13= os.listdir(pathturn13)
pathturn14 = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\fanew\turn4"
filesturn14= os.listdir(pathturn14)
pathturn15 = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\fanew\turn5"
filesturn15= os.listdir(pathturn15)

pathturn11c = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\chinew\turn1"
filesturn11c= os.listdir(pathturn11c)
pathturn12c = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\chinew\turn2"
filesturn12c= os.listdir(pathturn12c)
pathturn13c = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\chinew\turn3"
filesturn13c= os.listdir(pathturn13c)
pathturn14c = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\chinew\turn4"
filesturn14c= os.listdir(pathturn14c)
pathturn15c = r"C:\LJR\babylab\marisa\datamanual\cut\0643\turntaking\block\chinew\turn5"
filesturn15c= os.listdir(pathturn15c)

# %%
pathturn21 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn1"
filesturn21= os.listdir(pathturn21)
pathturn22 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn2"
filesturn22= os.listdir(pathturn22)
#pathturn23 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn3"
#filesturn23= os.listdir(pathturn23)
pathturn24 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn4"
filesturn24= os.listdir(pathturn24)
pathturn25 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn5"
filesturn25= os.listdir(pathturn25)
pathturn26 = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\fanew\turn6"
filesturn26= os.listdir(pathturn26)

pathturn21c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn1"
filesturn21c= os.listdir(pathturn21c)
pathturn22c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn2"
filesturn22c= os.listdir(pathturn22c)
#pathturn23c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn3"
#filesturn23c= os.listdir(pathturn23c)
pathturn24c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn4"
filesturn24c= os.listdir(pathturn24c)
pathturn25c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn5"
filesturn25c= os.listdir(pathturn25c)
pathturn26c = r"C:\LJR\babylab\marisa\datamanual\cut\2109\turntaking\block\chinew\turn6"
filesturn26c= os.listdir(pathturn26c)

# %%
pathturn61 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn1"
filesturn61= os.listdir(pathturn61)
pathturn62 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn2"
filesturn62= os.listdir(pathturn62)
pathturn63 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn3"
filesturn63= os.listdir(pathturn63)
pathturn64 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn4"
filesturn64= os.listdir(pathturn64)
pathturn65 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn5"
filesturn65= os.listdir(pathturn65)
pathturn66 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn6"
filesturn66= os.listdir(pathturn66)
pathturn67 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn7"
filesturn67= os.listdir(pathturn67)
pathturn68 = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\fanew\turn8"
filesturn68= os.listdir(pathturn68)


pathturn61c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn1"
filesturn61c= os.listdir(pathturn61c)
pathturn62c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn2"
filesturn62c= os.listdir(pathturn62c)
pathturn63c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn3"
filesturn63c= os.listdir(pathturn63c)
pathturn64c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn4"
filesturn64c= os.listdir(pathturn64c)
pathturn65c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn5"
filesturn65c= os.listdir(pathturn65c)
pathturn66c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn6"
filesturn66c= os.listdir(pathturn66c)
pathturn67c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn7"
filesturn67c= os.listdir(pathturn67c)
pathturn68c = r"C:\LJR\babylab\marisa\datamanual\cut\7176\turntaking\block\chinew\turn8"
filesturn68c= os.listdir(pathturn68c)

# %%
pathturn71 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn1"
filesturn71= os.listdir(pathturn71)
pathturn72 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn2"
filesturn72= os.listdir(pathturn72)
pathturn73 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn3"
filesturn73= os.listdir(pathturn73)
pathturn74 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn4"
filesturn74= os.listdir(pathturn74)
pathturn75 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn5"
filesturn75= os.listdir(pathturn75)
pathturn76 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn6"
filesturn76= os.listdir(pathturn76)
pathturn77 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn7"
filesturn77= os.listdir(pathturn77)
pathturn78 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn8"
filesturn78= os.listdir(pathturn78)
pathturn79 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn9"
filesturn79= os.listdir(pathturn79)
pathturn710 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn10"
filesturn710= os.listdir(pathturn710)
pathturn711 = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\fanew\turn11"
filesturn711= os.listdir(pathturn711)

pathturn71c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn1"
filesturn71c= os.listdir(pathturn71c)
pathturn72c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn2"
filesturn72c= os.listdir(pathturn72c)
pathturn73c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn3"
filesturn73c= os.listdir(pathturn73c)
pathturn74c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn4"
filesturn74c= os.listdir(pathturn74c)
pathturn75c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn5"
filesturn75c= os.listdir(pathturn75c)
pathturn76c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn6"
filesturn76c= os.listdir(pathturn76c)
pathturn77c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn7"
filesturn77c= os.listdir(pathturn77c)
pathturn78c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn8"
filesturn78c= os.listdir(pathturn78c)
pathturn79c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn9"
filesturn79c= os.listdir(pathturn79c)
pathturn710c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn10"
filesturn710c= os.listdir(pathturn710c)
pathturn711c = r"C:\LJR\babylab\marisa\datamanual\cut\7220\turntaking\block\chinew\turn11"
filesturn711c= os.listdir(pathturn711c)

# %%
pathturn81 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn1"
filesturn81= os.listdir(pathturn81)
pathturn82 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn2"
filesturn82= os.listdir(pathturn82)
pathturn83 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn3"
filesturn83= os.listdir(pathturn83)
pathturn84 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn4"
filesturn84= os.listdir(pathturn84)
pathturn85 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn5"
filesturn85= os.listdir(pathturn85)
pathturn86 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn6"
filesturn86= os.listdir(pathturn86)
pathturn87 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn7"
filesturn87= os.listdir(pathturn87)
#pathturn88 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn8"
#filesturn88= os.listdir(pathturn88)
pathturn89 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn9"
filesturn89= os.listdir(pathturn89)
pathturn810 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn10"
filesturn810= os.listdir(pathturn810)


pathturn81c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn1"
filesturn81c= os.listdir(pathturn81c)
pathturn82c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn2"
filesturn82c= os.listdir(pathturn82c)
pathturn83c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn3"
filesturn83c= os.listdir(pathturn83c)
pathturn84c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn4"
filesturn84c= os.listdir(pathturn84c)
pathturn85c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn5"
filesturn85c= os.listdir(pathturn85c)
pathturn86c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn6"
filesturn86c= os.listdir(pathturn86c)
pathturn87c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn7"
filesturn87c= os.listdir(pathturn87c)
#pathturn88c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn8"
#filesturn88c= os.listdir(pathturn88c)
pathturn89c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn9"
filesturn89c= os.listdir(pathturn89c)
pathturn810c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn10"
filesturn810c= os.listdir(pathturn810c)

# %%
#pathturn811 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn11"
#filesturn811= os.listdir(pathturn811)
pathturn812 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn12"
filesturn812= os.listdir(pathturn812)
pathturn813 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn13"
filesturn813= os.listdir(pathturn813)
pathturn814 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn14"
filesturn814= os.listdir(pathturn814)
pathturn815 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn15"
filesturn815= os.listdir(pathturn815)
pathturn816 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn16"
filesturn816= os.listdir(pathturn816)
pathturn817 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn17"
filesturn817= os.listdir(pathturn817)
pathturn818 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn18"
filesturn818= os.listdir(pathturn818)
pathturn819 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn19"
filesturn819= os.listdir(pathturn819)
pathturn820 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn20"
filesturn820= os.listdir(pathturn820)
pathturn821 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn21"
filesturn821= os.listdir(pathturn821)
pathturn822 = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\fanew\turn22"
filesturn822= os.listdir(pathturn822)


#pathturn811c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn11"
#filesturn811c= os.listdir(pathturn811c)
pathturn812c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn12"
filesturn812c= os.listdir(pathturn812c)
pathturn813c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn13"
filesturn813c= os.listdir(pathturn813c)
pathturn814c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn14"
filesturn814c= os.listdir(pathturn814c)
pathturn815c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn15"
filesturn815c= os.listdir(pathturn815c)
pathturn816c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn16"
filesturn816c= os.listdir(pathturn816c)
pathturn817c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn17"
filesturn817c= os.listdir(pathturn817c)
pathturn818c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn18"
filesturn818c= os.listdir(pathturn818c)
pathturn819c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn19"
filesturn819c= os.listdir(pathturn819c)
pathturn820c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn20"
filesturn820c= os.listdir(pathturn820c)
pathturn821c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn21"
filesturn821c= os.listdir(pathturn821c)
pathturn822c = r"C:\LJR\babylab\marisa\datamanual\cut\7326\turntaking\block\chinew\turn22"
filesturn822c= os.listdir(pathturn822c)

# %%
pathturn91 = r"C:\LJR\babylab\marisa\datamanual\cut\8787\turntaking\block\fanew\turn1"
filesturn91= os.listdir(pathturn91)
pathturn91c = r"C:\LJR\babylab\marisa\datamanual\cut\8787\turntaking\block\chinew\turn1"
filesturn91c= os.listdir(pathturn91c)

# %%
import sklearn
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)

# %%
def featurec(path,files):
    t=np.zeros((len(files),10))
    for i in range(len(files)):
        x,sr1=librosa.load(path+"\\"+files[i],sr=None)
        duration=librosa.get_duration(y=x, sr=sr1)
        emphasized_signal = np.append(x[0], x[1:] -0.97 * x[:-1])
        mfccss = librosa.feature.mfcc(y=emphasized_signal, sr=sr1)
        mfccs = normalize(mfccss , axis=1)
        mfccs=mfccs.T
        mfccsm=np.mean(mfccs)
        f0, voiced_flag, voiced_probs = librosa.pyin(x,sr=sr1,frame_length=512, fill_na=np.nan, n_thresholds=50, fmin=120, fmax=600)
        rf0= np.nanmax(f0)-np.nanmin(f0)
        if np.isnan(rf0):
            print(path+"\\"+files[i])
        maxf0 = np.nanmax(f0)
        minf0 = np.nanmin(f0)
        mmf0=np.nanmean(f0)
        rms = librosa.feature.rms(y=x,frame_length=512, hop_length=128)
        mrms=np.nanmean(rms)
        zerocrossr = librosa.feature.zero_crossing_rate(y=x,frame_length=512, hop_length=128)
        mzerocrossr=np.nanmean(zerocrossr)
        starttime=re.search("(\d+\.\d+)",files[i]).group(0)
        label=0
        feature=np.c_[float(starttime),duration,mfccsm,rf0,maxf0,minf0,mmf0,mrms,mzerocrossr,label]
        t[i,:]=feature
    return t

# %%
def featureci(path,files):
    t=np.zeros((len(files),10))
    for i in range(len(files)):
        x,sr1=librosa.load(path+"\\"+files[i],sr=None)
        duration=librosa.get_duration(y=x, sr=sr1)
        emphasized_signal = np.append(x[0], x[1:] -0.97 * x[:-1])
        mfccss = librosa.feature.mfcc(y=emphasized_signal, sr=sr1)
        mfccs = normalize(mfccss , axis=1)
        mfccs=mfccs.T
        mfccsm=np.mean(mfccs)
        f0, voiced_flag, voiced_probs = librosa.pyin(x,sr=sr1,frame_length=512, fill_na=np.nan, n_thresholds=50, fmin=120, fmax=1000)
        rf0= np.nanmax(f0)-np.nanmin(f0)
        if np.isnan(rf0):
            print(path+"\\"+files[i])
        maxf0 = np.nanmax(f0)
        minf0 = np.nanmin(f0)
        mmf0=np.nanmean(f0)
        rms = librosa.feature.rms(y=x,frame_length=512, hop_length=128)
        mrms=np.nanmean(rms)
        zerocrossr = librosa.feature.zero_crossing_rate(y=x,frame_length=512, hop_length=128)
        mzerocrossr=np.nanmean(zerocrossr)
        starttime=re.search("(\d+\.\d+)",files[i]).group(0)
        label=1
        feature=np.c_[float(starttime),duration,mfccsm,rf0,maxf0,minf0,mmf0,mrms,mzerocrossr,label]
        t[i,:]=feature
    return t

# %%
def diffc(pathturn,filesturn,pathturnc,filesturnc):
    t=featurec(pathturn,filesturn)
    tc=featureci(pathturnc,filesturnc)
    block=np.r_[t,tc]
    blocks = block[block[:,0].argsort()]
    groups = [(k, sum(1 for _ in g)) for k, g in groupby(blocks[:,-1])]
    groupn=np.zeros((len(groups),1))
    #print(blocks[:,1])
    for i in range(len(groups)):
        groupn[i]=groups[i][1]
    #print(groupn)
    ind=np.zeros((len(groupn),2))
    for i in range(len(groupn)):
        if i!=len(groupn):
            ind[i,:]=np.c_[sum(groupn[0:i]),sum(groupn[0:i+1])]
    blockn=np.zeros((len(groupn),10))
    #print(ind)
    for i in range(len(groupn)):
        blockn[i,:]=np.mean(blocks[int(ind[i,0]):int(ind[i,1]),:],axis=0)
    #print(blockn[:,1])
    diff=np.zeros((len(groupn)-1,10))
    mother=np.zeros((len(groupn)-1,10))
    infant=np.zeros((len(groupn)-1,10))
    for i in range(len(groupn)-1):
        diff[i,:]=np.absolute(blockn[i+1,:]-blockn[i,:])
        if (blockn[i+1,-1]==0)&(blockn[i,-1]==1):
            mother[i,:]=blockn[i+1,:]
            infant[i,:]=blockn[i,:]
        if (blockn[i+1,-1]==1)&(blockn[i,-1]==0):
            mother[i,:]=blockn[i,:]
            infant[i,:]=blockn[i+1,:]
    xlabel=(np.arange(len(diff))+1)
    print(len(diff))
    return -diff,xlabel,mother,infant

# %%
diffc11,xlabel11,t11,tc11=diffc(pathturn11,filesturn11,pathturn11c,filesturn11c)
diffc12,xlabel12,t12,tc12=diffc(pathturn12,filesturn12,pathturn12c,filesturn12c)
diffc13,xlabel13,t13,tc13=diffc(pathturn13,filesturn13,pathturn13c,filesturn13c)
diffc14,xlabel14,t14,tc14=diffc(pathturn14,filesturn14,pathturn14c,filesturn14c)
diffc15,xlabel15,t15,tc15=diffc(pathturn15,filesturn15,pathturn15c,filesturn15c)
# Out:
# 12
# 2
# 2
# 5
# 2

# %%
lenall=[]

# %%
lenall.append(len(diffc11))
lenall.append(len(diffc12))
lenall.append(len(diffc13))
lenall.append(len(diffc14))
lenall.append(len(diffc15))

# %%
plt.scatter(xlabel11,tc11[:,4],c='r')
plt.scatter(xlabel11,t11[:,4],c='b')
plt.show()
plt.scatter(xlabel11,diffc11[:,4],c='b')
plt.show()

# %%
feature11=featurec(pathturn11,filesturn11)
feature11c=featureci(pathturn11c,filesturn11c)

# %%
x11=np.arange(len(feature11[:,0]))
x11c=np.arange(len(feature11c[:,0]))

# %%
#plt.scatter(xlabel11,tc11[:,4],c='r')
#plt.scatter(xlabel11,t11[:,4],c='b')
#plt.show()
#plt.scatter(feature12[:,0],feature12[:,4],c='b')
#plt.scatter(feature12c[:,0],feature12c[:,4],c='r')
#plt.show()

# %%
diffc1=np.r_[diffc11,diffc12,diffc13,diffc14,diffc15]
xlabel1=np.r_[xlabel11,xlabel12,xlabel13,xlabel14,xlabel15]
t1=np.r_[t11,t12,t13,t14,t15]
tc1=np.r_[tc11,tc12,tc13,tc14,tc15]

# %%
diffc21,xlabel21,t21,tc21=diffc(pathturn21,filesturn21,pathturn21c,filesturn21c)
diffc22,xlabel22,t22,tc22=diffc(pathturn22,filesturn22,pathturn22c,filesturn22c)
#diffc23,xlabel23,t23,tc23=diffc(pathturn23,filesturn23,pathturn23c,filesturn23c)
diffc24,xlabel24,t24,tc24=diffc(pathturn24,filesturn24,pathturn24c,filesturn24c)
diffc25,xlabel25,t25,tc25=diffc(pathturn25,filesturn25,pathturn25c,filesturn25c)
diffc26,xlabel26,t26,tc26=diffc(pathturn26,filesturn26,pathturn26c,filesturn26c)
# Out:
# 2
# 4
# 2
# 2
# 2

# %%
lenall.append(len(diffc21))
lenall.append(len(diffc22))
#lenall.append(len(diffc23))
lenall.append(len(diffc24))
lenall.append(len(diffc25))
lenall.append(len(diffc26))

# %%
#diffc2=np.r_[diffc21,diffc22,diffc23,diffc24,diffc25,diffc26]
#xlabel2=np.r_[xlabel21,xlabel22,xlabel23,xlabel24,xlabel25,xlabel26]
#t2=np.r_[t21,t22,t23,t24,t25,t26]
#tc2=np.r_[tc21,tc22,tc23,tc24,tc25,tc26]

diffc2=np.r_[diffc21,diffc22,diffc24,diffc25,diffc26]
xlabel2=np.r_[xlabel21,xlabel22,xlabel24,xlabel25,xlabel26]
t2=np.r_[t21,t22,t24,t25,t26]
tc2=np.r_[tc21,tc22,tc24,tc25,tc26]

# %%
diffc61,xlabel61,t61,tc61=diffc(pathturn61,filesturn61,pathturn61c,filesturn61c)
diffc62,xlabel62,t62,tc62=diffc(pathturn62,filesturn62,pathturn62c,filesturn62c)
diffc63,xlabel63,t63,tc63=diffc(pathturn63,filesturn63,pathturn63c,filesturn63c)
diffc64,xlabel64,t64,tc64=diffc(pathturn64,filesturn64,pathturn64c,filesturn64c)
diffc65,xlabel65,t65,tc65=diffc(pathturn65,filesturn65,pathturn65c,filesturn65c)
diffc66,xlabel66,t66,tc66=diffc(pathturn66,filesturn66,pathturn66c,filesturn66c)
diffc67,xlabel67,t67,tc67=diffc(pathturn67,filesturn67,pathturn67c,filesturn67c)
diffc68,xlabel68,t68,tc68=diffc(pathturn68,filesturn68,pathturn68c,filesturn68c)
# Out:
# 4
# 4
# 2
# 2
# 4
# 2
# 2
# 8

# %%
lenall.append(len(diffc61))
lenall.append(len(diffc62))
lenall.append(len(diffc63))
lenall.append(len(diffc64))
lenall.append(len(diffc65))
lenall.append(len(diffc66))
lenall.append(len(diffc67))
lenall.append(len(diffc68))

# %%
diffc6=np.r_[diffc61,diffc62,diffc63,diffc64,diffc65,diffc66,diffc67,diffc68]
xlabel6=np.r_[xlabel61,xlabel62,xlabel63,xlabel64,xlabel65,xlabel66,xlabel67,xlabel68]
t6=np.r_[t61,t62,t63,t64,t65,t66,t67,t68]
tc6=np.r_[tc61,tc62,tc63,tc64,tc65,tc66,tc67,tc68]

# %%
diffc71,xlabel71,t71,tc71=diffc(pathturn71,filesturn71,pathturn71c,filesturn71c)
diffc72,xlabel72,t72,tc72=diffc(pathturn72,filesturn72,pathturn72c,filesturn72c)
diffc73,xlabel73,t73,tc73=diffc(pathturn73,filesturn73,pathturn73c,filesturn73c)
diffc74,xlabel74,t74,tc74=diffc(pathturn74,filesturn74,pathturn74c,filesturn74c)
diffc75,xlabel75,t75,tc75=diffc(pathturn75,filesturn75,pathturn75c,filesturn75c)
diffc76,xlabel76,t76,tc76=diffc(pathturn76,filesturn76,pathturn76c,filesturn76c)
diffc77,xlabel77,t77,tc77=diffc(pathturn77,filesturn77,pathturn77c,filesturn77c)
diffc78,xlabel78,t78,tc78=diffc(pathturn78,filesturn78,pathturn78c,filesturn78c)
diffc79,xlabel79,t79,tc79=diffc(pathturn79,filesturn79,pathturn79c,filesturn79c)
diffc710,xlabel710,t710,tc710=diffc(pathturn710,filesturn710,pathturn710c,filesturn710c)
diffc711,xlabel711,t711,tc711=diffc(pathturn711,filesturn711,pathturn711c,filesturn711c)
# Out:
# 6
# 2
# 5
# 8
# 4
# 2
# 3
# 2
# 2
# 8
# 3

# %%
lenall.append(len(diffc71))
lenall.append(len(diffc72))
lenall.append(len(diffc73))
lenall.append(len(diffc74))
lenall.append(len(diffc75))
lenall.append(len(diffc76))
lenall.append(len(diffc77))
lenall.append(len(diffc78))
lenall.append(len(diffc79))
lenall.append(len(diffc710))
lenall.append(len(diffc711))

# %%
diffc7=np.r_[diffc71,diffc72,diffc73,diffc74,diffc75,diffc76,diffc77,diffc78,diffc79,diffc710,diffc711]
xlabel7=np.r_[xlabel71,xlabel72,xlabel73,xlabel74,xlabel75,xlabel76,xlabel77,xlabel78,xlabel79,xlabel710,xlabel711]
t7=np.r_[t71,t72,t73,t74,t75,t76,t77,t78,t79,t710,t711]
tc7=np.r_[tc71,tc72,tc73,tc74,tc75,tc76,tc77,tc78,tc79,tc710,tc711]

# %%
diffc81,xlabel81,t81,tc81=diffc(pathturn81,filesturn81,pathturn81c,filesturn81c)
diffc82,xlabel82,t82,tc82=diffc(pathturn82,filesturn82,pathturn82c,filesturn82c)
diffc83,xlabel83,t83,tc83=diffc(pathturn83,filesturn83,pathturn83c,filesturn83c)
diffc84,xlabel84,t84,tc84=diffc(pathturn84,filesturn84,pathturn84c,filesturn84c)
diffc85,xlabel85,t85,tc85=diffc(pathturn85,filesturn85,pathturn85c,filesturn85c)
diffc86,xlabel86,t86,tc86=diffc(pathturn86,filesturn86,pathturn86c,filesturn86c)
diffc87,xlabel87,t87,tc87=diffc(pathturn87,filesturn87,pathturn87c,filesturn87c)
#diffc88,xlabel88,t88,tc88=diffc(pathturn88,filesturn88,pathturn88c,filesturn88c)
diffc89,xlabel89,t89,tc89=diffc(pathturn89,filesturn89,pathturn89c,filesturn89c)
diffc810,xlabel810,t810,tc810=diffc(pathturn810,filesturn810,pathturn810c,filesturn810c)
# Out:
# 4
# 2
# 2
# 2
# 4
# 4
# 13
# 9
# 15

# %%
#tdiffc81=np.r_[diffc81,diffc82,diffc83,diffc84,diffc85,diffc86,diffc87,diffc88,diffc89,diffc810]
#txlabel81=np.r_[xlabel81,xlabel82,xlabel83,xlabel84,xlabel85,xlabel86,xlabel87,xlabel88,xlabel89,xlabel810]
#tt81=np.r_[t81,t82,t83,t84,t85,t86,t87,t88,t89,t810]
#ttc81=np.r_[tc81,tc82,tc83,tc84,tc85,tc86,tc87,tc88,tc89,tc810]
#tdiffc81=np.r_[diffc81,diffc82,diffc83,diffc84,diffc85,diffc86,diffc87,diffc89,diffc810]
#txlabel81=np.r_[xlabel81,xlabel82,xlabel83,xlabel84,xlabel85,xlabel86,xlabel87,xlabel89,xlabel810]
#tt81=np.r_[t81,t82,t83,t84,t85,t86,t87,t89,t810]
#ttc81=np.r_[tc81,tc82,tc83,tc84,tc85,tc86,tc87,tc89,tc810]

#tdiffc81=np.r_[diffc81,diffc82,diffc83,diffc84,diffc85,diffc86,diffc87,diffc89]
tdiffc81=np.r_[diffc81,diffc82,diffc83,diffc84,diffc85,diffc86,diffc89]
#txlabel81=np.r_[xlabel81,xlabel82,xlabel83,xlabel84,xlabel85,xlabel86,xlabel87,xlabel89]
txlabel81=np.r_[xlabel81,xlabel82,xlabel83,xlabel84,xlabel85,xlabel86,xlabel89]
#tt81=np.r_[t81,t82,t83,t84,t85,t86,t87,t89]
tt81=np.r_[t81,t82,t83,t84,t85,t86,t89]
#ttc81=np.r_[tc81,tc82,tc83,tc84,tc85,tc86,tc87,tc89]
ttc81=np.r_[tc81,tc82,tc83,tc84,tc85,tc86,tc89]

# %%
#diffc811,xlabel811,t811,tc811=diffc(pathturn811,filesturn811,pathturn811c,filesturn811c)
diffc812,xlabel812,t812,tc812=diffc(pathturn812,filesturn812,pathturn812c,filesturn812c)
diffc813,xlabel813,t813,tc813=diffc(pathturn813,filesturn813,pathturn813c,filesturn813c)
diffc814,xlabel814,t814,tc814=diffc(pathturn814,filesturn814,pathturn814c,filesturn814c)
diffc815,xlabel815,t815,tc815=diffc(pathturn815,filesturn815,pathturn815c,filesturn815c)
diffc816,xlabel816,t816,tc816=diffc(pathturn816,filesturn816,pathturn816c,filesturn816c)
diffc817,xlabel817,t817,tc817=diffc(pathturn817,filesturn817,pathturn817c,filesturn817c)
diffc818,xlabel818,t818,tc818=diffc(pathturn818,filesturn818,pathturn818c,filesturn818c)
diffc819,xlabel819,t819,tc819=diffc(pathturn819,filesturn819,pathturn819c,filesturn819c)
diffc820,xlabel820,t820,tc820=diffc(pathturn820,filesturn820,pathturn820c,filesturn820c)
diffc821,xlabel821,t821,tc821=diffc(pathturn821,filesturn821,pathturn821c,filesturn821c)
diffc822,xlabel822,t822,tc822=diffc(pathturn822,filesturn822,pathturn822c,filesturn822c)
# Out:
# 3
# 6
# 2
# 5
# 4
# 3
# 9
# 10
# 3
# 2
# 2

# %%
lenall.append(len(diffc81))
lenall.append(len(diffc82))
lenall.append(len(diffc83))
lenall.append(len(diffc84))
lenall.append(len(diffc85))
lenall.append(len(diffc86))
#lenall.append(len(diffc87))
#lenall.append(len(diffc88))
lenall.append(len(diffc89))
lenall.append(len(diffc810))
#lenall.append(len(diffc811))
lenall.append(len(diffc812))
lenall.append(len(diffc813))
lenall.append(len(diffc814))
lenall.append(len(diffc815))
lenall.append(len(diffc816))
lenall.append(len(diffc817))
lenall.append(len(diffc818))
lenall.append(len(diffc819))
lenall.append(len(diffc820))
lenall.append(len(diffc821))
lenall.append(len(diffc822))

# %%
#tdiffc82=np.r_[diffc811,diffc812,diffc813,diffc814,diffc815,diffc816,diffc817,diffc818,diffc819,diffc820,diffc821,diffc822]
#txlabel82=np.r_[xlabel811,xlabel812,xlabel813,xlabel814,xlabel815,xlabel816,xlabel817,xlabel818,xlabel819,xlabel820,xlabel821,xlabel822]
#tt82=np.r_[t811,t812,t813,t814,t815,t816,t817,t818,t819,t820,t821,t822]
#ttc82=np.r_[tc811,tc812,tc813,tc814,tc815,tc816,tc817,tc818,tc819,tc820,tc821,tc822]

tdiffc82=np.r_[diffc812,diffc813,diffc814,diffc815,diffc816,diffc817,diffc818,diffc819,diffc820,diffc821,diffc822]
txlabel82=np.r_[xlabel812,xlabel813,xlabel814,xlabel815,xlabel816,xlabel817,xlabel818,xlabel819,xlabel820,xlabel821,xlabel822]
tt82=np.r_[t812,t813,t814,t815,t816,t817,t818,t819,t820,t821,t822]
ttc82=np.r_[tc812,tc813,tc814,tc815,tc816,tc817,tc818,tc819,tc820,tc821,tc822]

# %%
diffc8=np.r_[tdiffc81,tdiffc82]
xlabel8=np.r_[txlabel81,txlabel82]
t8=np.r_[tt81,tt82]
tc8=np.r_[ttc81,ttc82]

# %%
diffc9,xlabel9,t9,tc9=diffc(pathturn91,filesturn91,pathturn91c,filesturn91c)
# Out:
# 5

# %%
lenall.append(len(diffc9))

# %%
diff=np.r_[diffc1,diffc2,diffc6,diffc7,diffc8,diffc9]
xlabel=np.r_[xlabel1,xlabel2,xlabel6,xlabel7,xlabel8,xlabel9]

# %%
print(np.mean(diff[:,3]),np.mean(diff[:,4]),np.mean(diff[:,5]),np.mean(diff[:,6]))
# Out:
# -108.96353563468834 -166.99682131180288 -108.9434286967964 -130.28752501299402

# %%
#print('cofft of duration=',stats.pearsonr(xlabel,-diff[:,1]))
#print('cofft of mfcc=',stats.pearsonr(xlabel,-diff[:,2]))
print('cofft of f0_range=',stats.pearsonr(xlabel,diff[:,3]))
print('cofft of f0_max=',stats.pearsonr(xlabel,diff[:,4]))
print('cofft of f0_min=',stats.pearsonr(xlabel,diff[:,5]))
print('cofft of f0_mean=',stats.pearsonr(xlabel,diff[:,6]))
#print('cofft of energy_rms=',stats.pearsonr(xlabel,-diff[:,7]))
#print('cofft of energy_zc=',stats.pearsonr(xlabel,-diff[:,8]))
# Out:
# cofft of f0_range= PearsonRResult(statistic=0.1204399670664854, pvalue=0.09877815953424736)
# cofft of f0_max= PearsonRResult(statistic=0.17792681555337192, pvalue=0.014307899768993854)
# cofft of f0_min= PearsonRResult(statistic=0.2114666146357845, pvalue=0.0034890340057644113)
# cofft of f0_mean= PearsonRResult(statistic=0.23126555555970096, pvalue=0.0013657085762139713)

# %%
lenalla=np.array(lenall)
lenp=pd.DataFrame(lenalla)
lenp.columns=['length']
#lenp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\marisalen.csv')

# %%
print(np.mean(lenall),np.std(lenall))
# Out:
# 4.163265306122449 2.9231443705785924

# %%
from scipy.optimize import curve_fit

# %%
# Define different types of functions to fit
def linear_func(x, a, b):
    return a * x + b

def quadratic_func(x, a, b, c):
    return a * x**2 + b * x + c

def cubic_func(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

def four_func(x, a, b, c, d,e):
    return a * x**4 + b * x**3 + c * x**2 + d*x+e

def five_func(x, a, b,c,d,e,f):
    return a * x**5 + b * x**4 + c * x**3 + d*x**2+e*x+f

#def six_func(x, a, b,c,d,e,f,g):
    #return a * x**6 + b * x**5 + c * x**4 + d*x**3+e*x**2+f*x+g

#def seven_func(x, a, b,c,d,e,f,g,h):
    #return a * x**7 + b * x**6 + c * x**5 + d*x**4+e*x**3+f*x**2+g*x+h
#def sigmoid_func(x, L, k, x0):
    #return a * x**3 + b * x**2 + c * x + d

#def gaussian_func(x, a, x0, sigma):
    #return return a * x**3 + b * x**2 + c * x + d

# %%
# Curve fitting for each function
functions = [linear_func, quadratic_func, cubic_func, four_func,
             five_func]

# %%
def ind(datain,labelin,ind):
    inds=np.zeros(len(datain))+ind
    dataout=np.c_[datain,labelin,inds]
    return dataout

# %%
dataallr=np.r_[ind(diffc1[:,3],xlabel1,1),ind(diffc2[:,3],xlabel2,2),ind(diffc6[:,3],xlabel6,6),ind(diffc7[:,3],xlabel7,7),ind(diffc8[:,3],xlabel8,8),ind(diffc9[:,3],xlabel9,9)]
dataallma=np.r_[ind(diffc1[:,4],xlabel1,1),ind(diffc2[:,4],xlabel2,2),ind(diffc6[:,4],xlabel6,6),ind(diffc7[:,4],xlabel7,7),ind(diffc8[:,4],xlabel8,8),ind(diffc9[:,4],xlabel9,9)]
dataallmi=np.r_[ind(diffc1[:,5],xlabel1,1),ind(diffc2[:,5],xlabel2,2),ind(diffc6[:,5],xlabel6,6),ind(diffc7[:,5],xlabel7,7),ind(diffc8[:,5],xlabel8,8),ind(diffc9[:,5],xlabel9,9)]
dataallme=np.r_[ind(diffc1[:,6],xlabel1,1),ind(diffc2[:,6],xlabel2,2),ind(diffc6[:,6],xlabel6,6),ind(diffc7[:,6],xlabel7,7),ind(diffc8[:,6],xlabel8,8),ind(diffc9[:,6],xlabel9,9)]

# %%
def remove16(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    endindex=datain[labelend.astype(int),1]
    startr=labelstart[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(startr)
    endr=labelend[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(endr)
    dataformer=datain[:startr[0]]
    datalatter=datain[endr[0]+1:]
    dataout=np.r_[dataformer,datalatter]
    #print(len(datain),len(dataout),dataout[:,1])
    return dataout

# %%
def startend(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    return labelstart,labelend.astype(int)

# %%
labelsr,labeler=startend(dataallr)
labelsme,labeleme=startend(dataallme)
labelsma,labelema=startend(dataallma)
labelsmi,labelemi=startend(dataallmi)

# %%
motherr=np.r_[ind(t1[:,3],xlabel1,1),ind(t2[:,3],xlabel2,2),ind(t6[:,3],xlabel6,6),ind(t7[:,3],xlabel7,7),ind(t8[:,3],xlabel8,8),ind(t9[:,3],xlabel9,9)]
motherma=np.r_[ind(t1[:,4],xlabel1,1),ind(t2[:,4],xlabel2,2),ind(t6[:,4],xlabel6,6),ind(t7[:,4],xlabel7,7),ind(t8[:,4],xlabel8,8),ind(t9[:,4],xlabel9,9)]
mothermi=np.r_[ind(t1[:,5],xlabel1,1),ind(t2[:,5],xlabel2,2),ind(t6[:,5],xlabel6,6),ind(t7[:,5],xlabel7,7),ind(t8[:,5],xlabel8,8),ind(t9[:,5],xlabel9,9)]
motherme=np.r_[ind(t1[:,6],xlabel1,1),ind(t2[:,6],xlabel2,2),ind(t6[:,6],xlabel6,6),ind(t7[:,6],xlabel7,7),ind(t8[:,6],xlabel8,8),ind(t9[:,6],xlabel9,9)]

# %%
infantr=np.r_[ind(tc1[:,3],xlabel1,1),ind(tc2[:,3],xlabel2,2),ind(tc6[:,3],xlabel6,6),ind(tc7[:,3],xlabel7,7),ind(tc8[:,3],xlabel8,8),ind(tc9[:,3],xlabel9,9)]
infantma=np.r_[ind(tc1[:,4],xlabel1,1),ind(tc2[:,4],xlabel2,2),ind(tc6[:,4],xlabel6,6),ind(tc7[:,4],xlabel7,7),ind(tc8[:,4],xlabel8,8),ind(tc9[:,4],xlabel9,9)]
infantmi=np.r_[ind(tc1[:,5],xlabel1,1),ind(tc2[:,5],xlabel2,2),ind(tc6[:,5],xlabel6,6),ind(tc7[:,5],xlabel7,7),ind(tc8[:,5],xlabel8,8),ind(tc9[:,5],xlabel9,9)]
infantme=np.r_[ind(tc1[:,6],xlabel1,1),ind(tc2[:,6],xlabel2,2),ind(tc6[:,6],xlabel6,6),ind(tc7[:,6],xlabel7,7),ind(tc8[:,6],xlabel8,8),ind(tc9[:,6],xlabel9,9)]

# %%
def stdc(datain,labelsin,labelein):
    stdout=[]
    for i in range(len(labelsin)):
        stdout.append(np.std(datain[labelsin[i]:labelein[i]+1,0]))
    return stdout

# %%
def meanc(datain,labelsin,labelein):
    meanout=[]
    for i in range(len(labelsin)):
        meanout.append(np.mean(datain[labelsin[i]:labelein[i]+1,0]))
    return meanout

# %%
mstdme=stdc(motherme,labelsme,labeleme)
mstdma=stdc(motherma,labelsma,labelema)
mstdmi=stdc(mothermi,labelsmi,labelemi)
mstdr=stdc(motherr,labelsr,labeler)

# %%
cstdme=stdc(infantme,labelsme,labeleme)
cstdma=stdc(infantma,labelsma,labelema)
cstdmi=stdc(infantmi,labelsmi,labelemi)
cstdr=stdc(infantr,labelsr,labeler)

# %%
mmeanme=meanc(motherme,labelsme,labeleme)
mmeanma=meanc(motherma,labelsma,labelema)
mmeanmi=meanc(mothermi,labelsmi,labelemi)
mmeanr=meanc(motherr,labelsr,labeler)

# %%
cmeanme=meanc(infantme,labelsme,labeleme)
cmeanma=meanc(infantma,labelsma,labelema)
cmeanmi=meanc(infantmi,labelsmi,labelemi)
cmeanr=meanc(infantr,labelsr,labeler)

# %%
dataallmep=pd.DataFrame(dataallme)
dataallmep.columns=['DV','IV','type']
dataallmap=pd.DataFrame(dataallma)
dataallmap.columns=['DV','IV','type']
dataallmip=pd.DataFrame(dataallmi)
dataallmip.columns=['DV','IV','type']
dataallrp=pd.DataFrame(dataallr)
dataallrp.columns=['DV','IV','type']

# %%
dataallrf=dataallr[np.where(dataallr[:,1]<=1)[0]]
dataallmaf=dataallma[np.where(dataallma[:,1]<=1)[0]]
dataallmif=dataallmi[np.where(dataallmi[:,1]<=1)[0]]
dataallmef=dataallme[np.where(dataallme[:,1]<=1)[0]]

# %%
print(np.mean(dataallrf[:,0]),np.mean(dataallmaf[:,0]),np.mean(dataallmif[:,0]),np.mean(dataallmef[:,0]))
# Out:
# -135.4582655308836 -193.8196158494719 -131.18513057254162 -145.70142360254914

# %%
mstdmep=pd.DataFrame(mstdme)
mstdmep.columns=['STD']
mstdmap=pd.DataFrame(mstdma)
mstdmap.columns=['STD']
mstdmip=pd.DataFrame(mstdmi)
mstdmip.columns=['STD']
mstdrp=pd.DataFrame(mstdr)
mstdrp.columns=['STD']

# %%
cstdmep=pd.DataFrame(cstdme)
cstdmep.columns=['STD']
cstdmap=pd.DataFrame(cstdma)
cstdmap.columns=['STD']
cstdmip=pd.DataFrame(cstdmi)
cstdmip.columns=['STD']
cstdrp=pd.DataFrame(cstdr)
cstdrp.columns=['STD']

# %%
mmeanmep=pd.DataFrame(mmeanme)
mmeanmep.columns=['MEAN']
mmeanmap=pd.DataFrame(mmeanma)
mmeanmap.columns=['MEAN']
mmeanmip=pd.DataFrame(mmeanmi)
mmeanmip.columns=['MEAN']
mmeanrp=pd.DataFrame(mmeanr)
mmeanrp.columns=['MEAN']

# %%
cmeanmep=pd.DataFrame(cmeanme)
cmeanmep.columns=['MEAN']
cmeanmap=pd.DataFrame(cmeanma)
cmeanmap.columns=['MEAN']
cmeanmip=pd.DataFrame(cmeanmi)
cmeanmip.columns=['MEAN']
cmeanrp=pd.DataFrame(cmeanr)
cmeanrp.columns=['MEAN']

# %%
#mmeanmep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmemean.csv')
#mmeanmap.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmamean.csv')
#mmeanmip.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmimean.csv')
#mmeanrp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mrmean.csv')

# %%
#cmeanmep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmemean.csv')
#cmeanmap.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmamean.csv')
#cmeanmip.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmimean.csv')
#cmeanrp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\crmean.csv')

# %%
#mstdmep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmestd.csv')
#mstdmap.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmastd.csv')
#mstdmip.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mmistd.csv')
#mstdrp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\mrstd.csv')

# %%
#cstdmep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmestd.csv')
#cstdmap.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmastd.csv')
#cstdmip.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\cmistd.csv')
#cstdrp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\crstd.csv')

# %%
#dataallmep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\conme.csv')
#dataallmip.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\conmi.csv')
#dataallmap.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\conma.csv')
#dataallrp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\conr.csv')

# %%
dataallmepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12menew.csv')
dataallmipe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12minew.csv')
dataallmape= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12manew.csv')
dataallrpe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12rnew.csv')

# %%
mstdmerepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd12menew.csv')
mstdmarepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd12minew.csv')
mstdmirepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd12manew.csv')
mstdrrepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd12rnew.csv')

# %%
mstdmepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16menew.csv')
mstdmape= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16minew.csv')
mstdmipe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16manew.csv')
mstdrpe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16rnew.csv')

# %%
cstdmerepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12menew.csv')
cstdmarepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12minew.csv')
cstdmirepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12manew.csv')
cstdrrepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12rnew.csv')

# %%
cstdmepe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16menew.csv')
cstdmape= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16minew.csv')
cstdmipe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16manew.csv')
cstdrpe= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16rnew.csv')

# %%
dataallrped=np.array(dataallrpe['DV'])
dataallmiped=np.array(dataallmipe['DV'])
dataallmeped=np.array(dataallmepe['DV'])
dataallmaped=np.array(dataallmape['DV'])

# %%
motherrped=np.array(mstdrpe['STD'])
mothermiped=np.array(mstdmipe['STD'])
mothermeped=np.array(mstdmepe['STD'])
mothermaped=np.array(mstdmape['STD'])

# %%
infantrped=np.array(cstdrpe['STD'])
infantmiped=np.array(cstdmipe['STD'])
infantmeped=np.array(cstdmepe['STD'])
infantmaped=np.array(cstdmape['STD'])

# %%
motherrreped=np.array(mstdrrepe['STD'])
mothermireped=np.array(mstdmirepe['STD'])
mothermereped=np.array(mstdmerepe['STD'])
mothermareped=np.array(mstdmarepe['STD'])

# %%
infantrreped=np.array(cstdrrepe['STD'])
infantmireped=np.array(cstdmirepe['STD'])
infantmereped=np.array(cstdmerepe['STD'])
infantmareped=np.array(cstdmarepe['STD'])

# %%
dataallrfe=dataallrped[np.where(np.array(dataallrpe['IV'])<=1)[0]]
dataallmafe=dataallmaped[np.where(np.array(dataallmape['IV'])<=1)[0]]
dataallmife=dataallmiped[np.where(np.array(dataallmipe['IV'])<=1)[0]]
dataallmefe=dataallmeped[np.where(np.array(dataallmepe['IV'])<=1)[0]]

# %%
print(len(motherme),len(dataallmep['DV']))
# Out:
# 189 189

# %%
print('meanstdranget=',np.mean(mstdr))
print('meanstdrangee=',np.mean(motherrreped))
print('meanstdmat=',np.mean(mstdma))
print('meanstdmae=',np.mean(mothermareped))
print('meanstdmet=',np.mean(mstdme))
print('meanstdmee=',np.mean(mothermereped))
print('meanstdmit=',np.mean(mstdmi))
print('meanstdmie=',np.mean(mothermireped))
# Out:
# meanstdranget= 26.977648474722486
# meanstdrangee= 33.46580317893213
# meanstdmat= 30.22394514676519
# meanstdmae= 33.934248023881565
# meanstdmet= 16.783147726762092
# meanstdmee= 21.784198800827035
# meanstdmit= 16.813309539742196
# meanstdmie= 20.78631347495379

# %%
print('cmeanstdranget=',np.mean(cstdr))
print('cmeanstdrangee=',np.mean(infantrreped))
print('cmeanstdmat=',np.mean(cstdma))
print('cmeanstdmae=',np.mean(infantmareped))
print('cmeanstdmet=',np.mean(cstdme))
print('cmeanstdmee=',np.mean(infantmereped))
print('cmeanstdmit=',np.mean(cstdmi))
print('cmeanstdmie=',np.mean(infantmireped))
# Out:
# cmeanstdranget= 60.93742003394325
# cmeanstdrangee= 36.26783855350695
# cmeanstdmat= 60.590322721522945
# cmeanstdmae= 43.23141497737102
# cmeanstdmet= 31.77839220870423
# cmeanstdmee= 28.241820074217603
# cmeanstdmit= 36.09014504822456
# cmeanstdmie= 23.3025333852078

# %%
from scipy import stats

# %%
t_stat, p_value = stats.ttest_ind(dataallrfe,dataallrf[:,0])
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmafe,dataallmaf[:,0])
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmife,dataallmif[:,0])
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmefe,dataallmef[:,0])
print('mep=',p_value)
# Out:
# rangefp= 0.026902906424089535
# map= 0.0209407212746852
# mip= 0.0004168722787590326
# mep= 0.0021249453236375153

# %%
t_stat, p_value = stats.ttest_ind(dataallrpe['DV'],dataallrp['DV'])
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmape['DV'],dataallmap['DV'])
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmipe['DV'],dataallmip['DV'])
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(dataallmepe['DV'],dataallmep['DV'])
print('mep=',p_value)
# Out:
# rangefp= 0.005727494279263186
# map= 4.0685730076661265e-06
# mip= 1.2936556906945802e-05
# mep= 2.263443485466488e-09

# %%
xxx=np.empty([len(dataallrpe['DV'])+len(dataallrp['DV'])],dtype = str) 
xxx[0:len(dataallrpe['DV'])]='E'
xxx[len(dataallrpe['DV']):]='T'
    
compare_durationrow=np.r_[dataallrpe['DV'],dataallrp['DV']]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmepe['DV'])+len(dataallmep['DV'])],dtype = str) 
xxx[0:len(dataallmepe['DV'])]='E'
xxx[len(dataallmepe['DV']):]='T'
    
compare_durationrow=np.r_[dataallmepe['DV'],dataallmep['DV']]

ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmape['DV'])+len(dataallmap['DV'])],dtype = str) 
xxx[0:len(dataallmape['DV'])]='E'
xxx[len(dataallmape['DV']):]='T'
    
compare_durationrow=np.r_[dataallmape['DV'],dataallmap['DV']]

ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmipe['DV'])+len(dataallmip['DV'])],dtype = str) 
xxx[0:len(dataallmipe['DV'])]='E'
xxx[len(dataallmipe['DV']):]='T'
    
compare_durationrow=np.r_[dataallmipe['DV'],dataallmip['DV']]

ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
t_stat, p_value = stats.ttest_ind(mstdr,motherrreped)
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(mstdma,mothermareped)
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(mstdmi,mothermireped)
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(mstdme,mothermereped)
print('mep=',p_value)
# Out:
# rangefp= 0.3633317633430274
# map= 0.5988645337625224
# mip= 0.3727465694869737
# mep= 0.22059471870030442

# %%
t_stat, p_value = stats.ttest_ind(cstdr,infantrreped)
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(cstdma,infantmareped)
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(cstdmi,infantmireped)
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(cstdme,infantmereped)
print('mep=',p_value)
# Out:
# rangefp= 0.033100828272994064
# map= 0.1395749429807049
# mip= 0.044415438962268725
# mep= 0.6008805514206206

# %%
t_stat, p_value = stats.ttest_ind(mstdr,cstdr)
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(mstdma,cstdma)
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(mstdmi,cstdmi)
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(mstdme,cstdme)
print('mep=',p_value)
# Out:
# rangefp= 0.00308950831828435
# map= 0.005080138736278471
# mip= 0.0010878861161989766
# mep= 0.007116988918371836

# %%
xxx=np.empty([len(cstdr)+len(mstdr)],dtype = str) 
xxx[0:len(cstdr)]='I'
xxx[len(cstdr):]='M'
    
compare_durationrow=np.r_[cstdr,mstdr]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(cstdme)+len(mstdme)],dtype = str) 
xxx[0:len(cstdme)]='I'
xxx[len(cstdme):]='M'
    
compare_durationrow=np.r_[cstdme,mstdme]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(cstdma)+len(mstdma)],dtype = str) 
xxx[0:len(cstdma)]='I'
xxx[len(cstdma):]='M'
    
compare_durationrow=np.r_[cstdma,mstdma]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(cstdmi)+len(mstdmi)],dtype = str) 
xxx[0:len(cstdmi)]='I'
xxx[len(cstdmi):]='M'
    
compare_durationrow=np.r_[cstdmi,mstdmi]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
t_stat, p_value = stats.ttest_ind(motherrreped,infantrreped)
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(mothermareped,infantmareped)
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(mothermireped,infantmireped)
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(mothermereped,infantmereped)
print('mep=',p_value)
# Out:
# rangefp= 0.6865925232259469
# map= 0.2644272035792794
# mip= 0.619242742442708
# mep= 0.2574805914838551

# %%
xxx=np.empty([len(infantrreped)+len(motherrreped)],dtype = str) 
xxx[0:len(infantrreped)]='I'
xxx[len(infantrreped):]='M'
    
compare_durationrow=np.r_[infantrreped,motherrreped]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(infantmereped)+len(mothermereped)],dtype = str) 
xxx[0:len(infantmereped)]='I'
xxx[len(infantmereped):]='M'
    
compare_durationrow=np.r_[infantmereped,mothermereped]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(infantmareped)+len(mothermareped)],dtype = str) 
xxx[0:len(infantmareped)]='I'
xxx[len(infantmareped):]='M'
    
compare_durationrow=np.r_[infantmareped,mothermareped]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(infantmireped)+len(mothermireped)],dtype = str) 
xxx[0:len(infantmireped)]='I'
xxx[len(infantmireped):]='M'
    
compare_durationrow=np.r_[infantmireped,mothermireped]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(motherrreped)+len(mstdr)],dtype = str) 
xxx[0:len(motherrreped)]='E'
xxx[len(motherrreped):]='T'
    
compare_durationrow=np.r_[motherrreped,mstdr]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(mothermereped)+len(mstdme)],dtype = str) 
xxx[0:len(mothermereped)]='E'
xxx[len(mothermereped):]='T'
    
compare_durationrow=np.r_[mothermereped,mstdme]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(mothermareped)+len(mstdma)],dtype = str) 
xxx[0:len(mothermareped)]='E'
xxx[len(mothermareped):]='T'
    
compare_durationrow=np.r_[mothermareped,mstdma]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(mothermireped)+len(mstdmi)],dtype = str) 
xxx[0:len(mothermireped)]='E'
xxx[len(mothermireped):]='T'
    
compare_durationrow=np.r_[mothermireped,mstdmi]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
t_stat, p_value = stats.ttest_ind(mstdr,motherrped)
print('rangefp=',p_value)
t_stat, p_value = stats.ttest_ind(mstdma,mothermaped)
print('map=',p_value)
t_stat, p_value = stats.ttest_ind(mstdmi,mothermiped)
print('mip=',p_value)
t_stat, p_value = stats.ttest_ind(mstdme,mothermeped)
print('mep=',p_value)
# Out:
# rangefp= 0.27426551688578527
# map= 0.47329167928210014
# mip= 0.36316141657945156
# mep= 0.1980215148625694

# %%
xxx=np.empty([len(dataallrfe)+len(dataallrf[:,0])],dtype = str) 
xxx[0:len(dataallrfe)]='E'
xxx[len(dataallrfe):]='T'
    
compare_durationrow=np.r_[dataallrfe,dataallrf[:,0]]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmefe)+len(dataallmef[:,0])],dtype = str) 
xxx[0:len(dataallmefe)]='E'
xxx[len(dataallmefe):]='T'
    
compare_durationrow=np.r_[dataallmefe,dataallmef[:,0]]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmafe)+len(dataallmaf[:,0])],dtype = str) 
xxx[0:len(dataallmafe)]='E'
xxx[len(dataallmafe):]='T'
    
compare_durationrow=np.r_[dataallmafe,dataallmaf[:,0]]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
xxx=np.empty([len(dataallmife)+len(dataallmif[:,0])],dtype = str) 
xxx[0:len(dataallmife)]='E'
xxx[len(dataallmife):]='T'
    
compare_durationrow=np.r_[dataallmife,dataallmif[:,0]]

    
ax = sns.boxplot(x=xxx, y=compare_durationrow, linewidth=1.5,whis=1.5)

# %%
def remove16(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    endindex=datain[labelend.astype(int),1]
    startr=labelstart[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(startr)
    endr=labelend[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(endr)
    dataformer=datain[:startr[0]]
    datalatter=datain[endr[0]+1:]
    dataout=np.r_[dataformer,datalatter]
    #print(len(datain),len(dataout),dataout[:,1])
    return dataout

# %%
def startend(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    return labelstart,labelend.astype(int)

# %%
labelsr,labeler=startend(dataallr)
labelsme,labeleme=startend(dataallme)
labelsma,labelema=startend(dataallma)
labelsmi,labelemi=startend(dataallmi)

# %%
def plotall(datain,labelsin,labelein):
    fig=plt.figure(figsize=(20,10))
    num_rows = len(labelsin)//5+(len(labelsin)%5>0)
    for i in range(len(labelsin)):
        plt.subplot(num_rows,5,i+1)
        xlabelp=np.arange(datain[labelein[i],1])+1
        plt.scatter(xlabelp,datain[labelsin[i]:labelein[i]+1,0])
        #plt.axis('off')
    plt.subplots_adjust(wspace=0.1)
    #fig.savefig(namein,dpi=300)
    #plt.tight_layout()
    plt.show()

# %%
plotall(dataallme,labelsme,labeleme)

# %%
def sep(datain,labelsin, labelein):
    data2=[]
    data3=[]
    data4=[]
    data5=[]
    data6=[]
    data7=[]
    data8=[]
    data9=[]
    data10=[]
    data11=[]
    data12=[]
    data13=[]
    lenin=labelein-labelsin+1
    for i in range(len(lenin)):
        if lenin[i]==2:
            data2.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==3:
            data3.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==4:
            data4.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==5:
            data5.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==6:
            data6.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==7:
            data7.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==8:
            data8.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==9:
            data9.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==10:
            data10.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==11:
            data11.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==12:
            data12.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==13:
            data13.append(datain[labelsin[i]:labelein[i]+1])
    print('2=',len(data2),'3=',len(data3),'4=',len(data4),'5=',len(data5),'6=',len(data6),'7=',len(data7),'8=',len(data8)
         ,'9=',len(data9),'10=',len(data10),'11=',len(data11),'12=',len(data12),'13=',len(data13))
    return data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13

# %%
data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere,data13mere=sep(dataallme,labelsme, labeleme)
data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare,data13mare=sep(dataallma,labelsma, labelema)
data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire,data13mire=sep(dataallmi,labelsmi, labelemi)
data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre,data13rre=sep(dataallr,labelsr, labeler)
# Out:
# 2= 21 3= 5 4= 9 5= 4 6= 2 7= 0 8= 3 9= 2 10= 1 11= 0 12= 1 13= 0
# 2= 21 3= 5 4= 9 5= 4 6= 2 7= 0 8= 3 9= 2 10= 1 11= 0 12= 1 13= 0
# 2= 21 3= 5 4= 9 5= 4 6= 2 7= 0 8= 3 9= 2 10= 1 11= 0 12= 1 13= 0
# 2= 21 3= 5 4= 9 5= 4 6= 2 7= 0 8= 3 9= 2 10= 1 11= 0 12= 1 13= 0

# %%
from matplotlib.pyplot import cm

# %%
def plotsep(data2in,data3in,data4in,data5in,data6in,data7in,data8in,data9in,data10in,data11in,data12in,data13in):
    color = iter(cm.rainbow(np.linspace(0, 1, len(data2in))))
    for i in range(len(data2in)):
        
        dataplot=data2in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data3in))))
    for i in range(len(data3in)):
        dataplot=data3in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data4in))))
    for i in range(len(data4in)):
        dataplot=data4in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data5in))))
    for i in range(len(data5in)):
        dataplot=data5in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data6in)+len(data8in))))
    for i in range(len(data6in)):
        dataplot=data6in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data7in))))
    #for i in range(len(data7in)):
        #dataplot=data7in[i]
        #plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data8in))))    
    for i in range(len(data8in)):
        dataplot=data8in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data9in)+len(data10in)+len(data12in)+len(data13in))))     
    for i in range(len(data9in)):
        dataplot=data9in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data10in))))    
    for i in range(len(data10in)):
        dataplot=data10in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data11in))))   
    #for i in range(len(data11in)):
        #dataplot=data11in[i]
        #plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data12in))))  
    for i in range(len(data12in)):
        dataplot=data12in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    for i in range(len(data13in)):
        dataplot=data13in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()

# %%
plotsep(data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere,data13mere)

# %%
plotsep(data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare,data13mare)

# %%
plotsep(data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire,data13mire)

# %%
plotsep(data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre,data13rre)

# %%
#lenes= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishlen12.csv')
#lene= pd.read_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishlen16.csv')

# %%
#lenea=np.array(lene['length'])
#lenesa=np.array(lenes['length'])

# %%
#t_stat, p_value = stats.ttest_ind(lenea,lenalla)
#print('mip=',p_value)
#t_stat, p_value = stats.ttest_ind(lenesa,lenalla)
#print('mep=',p_value)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def calculate_bic(y_true, y_pred, n, k):
    mse = mean_squared_error(y_true, y_pred)
    bic = n * np.log(mse) + k * np.log(n)
    return bic

# %%
def outputfit(functionsin,xin,yin):
    r2_values=[]
    fit_results=[]
    iii=2
    for func in functionsin:
        popt, _ = curve_fit(func, xin, yin)
        fit_results.append(popt)
        y_fit = func(xin, *popt)
        r2_values.append(calculate_bic(yin, y_fit, len(yin), iii))
        iii=iii+1
    return r2_values,fit_results

# %%
def fittingsep(datain2,datain3,datain4,datain5,datain6,datain7,datain8,datain9,datain10,datain11,datain12,datain13):
    rout2,fit2=outputfit(functions,np.array(datain2).reshape(2*len(datain2),3)[:,1],np.array(datain2).reshape(2*len(datain2),3)[:,0])
    print('re2=',rout2)
    rout3,fit3=outputfit(functions,np.array(datain3).reshape(3*len(datain3),3)[:,1],np.array(datain3).reshape(3*len(datain3),3)[:,0])
    print('re3=',rout3)
    rout4,fit4=outputfit(functions,np.array(datain4).reshape(4*len(datain4),3)[:,1],np.array(datain4).reshape(4*len(datain4),3)[:,0])
    print('re4=',rout2)
    rout5,fit5=outputfit(functions,np.array(datain5).reshape(5*len(datain5),3)[:,1],np.array(datain5).reshape(5*len(datain5),3)[:,0])
    print('re5=',rout5)
    datain68=np.r_[np.array(datain6).reshape(6*len(datain6),3),np.array(datain8).reshape(8*len(datain8),3)]
    #rout6,fit6=outputfit(functions,np.array(datain6).reshape(6*len(datain6),3)[:,1],np.array(datain6).reshape(6*len(datain6),3)[:,0])
    #print('re6=',rout6)
    rout6,fit6=outputfit(functions,datain68[:,1],datain68[:,0])
    print('re6=',rout6)
    #rout7,fit7=outputfit(functions,np.array(datain7).reshape(7*len(datain7),3)[:,1],np.array(datain7).reshape(7*len(datain7),3)[:,0])
    #print('re7=',rout7)
    rout8,fit8=outputfit(functions,np.array(datain8).reshape(8*len(datain8),3)[:,1],np.array(datain8).reshape(8*len(datain8),3)[:,0])
    print('re8=',rout8)
    datain902=np.r_[np.array(datain9).reshape(9*len(datain9),3),np.array(datain10).reshape(10*len(datain10),3),np.array(datain12).reshape(12*len(datain12),3),np.array(datain13).reshape(13*len(datain13),3)]
    rout9,fit9=outputfit(functions,datain902[:,1],datain902[:,0])
    print('re9=',rout9)
    
    rout10,fit10=outputfit(functions,np.array(datain10).reshape(10*len(datain10),3)[:,1],np.array(datain10).reshape(10*len(datain10),3)[:,0])
    print('re10=',rout10)
    #rout11,fit11=outputfit(functions,np.array(datain11).reshape(11*len(datain11),3)[:,1],np.array(datain11).reshape(11*len(datain11),3)[:,0])
    #print('re11=',rout11)
    rout12,fit12=outputfit(functions,np.array(datain12).reshape(12*len(datain12),3)[:,1],np.array(datain12).reshape(12*len(datain12),3)[:,0])
    print('re12=',rout12)
    return rout2,rout3,rout4,rout5,rout6,rout8,rout9,rout10,rout12,fit2,fit3,fit4,fit5,fit6,fit8,fit9,fit10,fit12

# %%
routme2,routme3,routme4,routme5,routme6,routme8,routme9,routme10,routme12,fitme2,fitme3,fitme4,fitme5,fitme6,fitme8,fitme9,fitme10,fitme12=fittingsep(data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere,data13mere)
# Out:
# re2= [371.52744453561394, 375.2651141538973, 379.00278377218063, 382.74045339046404, 386.4781230087474]
# re3= [115.72192138487904, 118.35611361236205, 121.06416381346426, 123.77221401456647, 126.48026421566868]
# re4= [371.52744453561394, 375.2651141538973, 379.00278377218063, 382.74045339046404, 386.4781230087474]
# re5= [181.2351838886037, 183.86114978418286, 186.24655680755512, 187.9469220433639, 190.94265431691792]
# re6= [286.14462811294294, 289.63636632919236, 290.91521624282984, 294.37740045616266, 295.54353919119694]
# re8= [189.53874409977198, 192.09304138047685, 193.11614419388667, 196.1832029118745, 196.17889771211728]
# re9= [320.86526447244785, 324.5490204261534, 326.5072269417671, 325.7495030956037, 329.42994297205433]
# re10= [77.65416032554806, 77.34917464390372, 64.6864680155722, 64.51230220054786, 66.423051500293]
# re12= [78.99332535149215, 76.61350478942416, 71.25198287825775, 73.55484468612335, 65.61895922402245]

# %%
routma2,routma3,routma4,routma5,routma6,routma8,routma9,routma10,routma12,fitma2,fitma3,fitma4,fitma5,fitma6,fitma8,fitma9,fitma10,fitma12=fittingsep(data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare,data13mare)
# Out:
# re2= [414.76219845768, 418.4998680759632, 422.23753769424656, 425.9752073125301, 429.7128769308133]
# re3= [156.1991342062812, 158.79324781626923, 161.50129801737145, 164.20934821847365, 166.91739841957587]
# re4= [414.76219845768, 418.4998680759632, 422.23753769424656, 425.9752073125301, 429.7128769308133]
# re5= [193.65345476232827, 195.85224942002318, 196.45719043898512, 199.42357820640282, 202.41931047995683]
# re6= [324.6563070735529, 328.23974702982514, 329.8414848271265, 331.49942354752767, 327.5407809518029]
# re8= [217.82192582568211, 220.69226465186318, 221.18151637110512, 223.19498303109796, 216.02629559450958]
# re9= [378.34295525347125, 381.5160722084657, 385.16022583635163, 386.9670810319474, 390.58807016099286]
# re10= [95.44674361661252, 97.73104089706554, 99.83502951426611, 101.59018217734032, 93.9398998684691]
# re12= [86.45648714118875, 82.31719707124674, 84.73089950670771, 83.45781742682601, 66.38298807089816]

# %%
routmi2,routmi3,routmi4,routmi5,routmi6,routmi8,routmi9,routmi10,routmi12,fitmi2,fitmi3,fitmi4,fitmi5,fitmi6,fitmi8,fitmi9,fitmi10,fitmi12=fittingsep(data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire,data13mire)
# Out:
# re2= [376.9200575645569, 380.65772718284023, 384.3953968011236, 388.133066419407, 391.87073603769034]
# re3= [129.81142698039483, 132.10892279691123, 134.8169729980134, 137.52502319911562, 140.23307340021782]
# re4= [376.9200575645569, 380.65772718284023, 384.3953968011236, 388.133066419407, 391.87073603769034]
# re5= [167.16756670492506, 170.156696465102, 172.06690973186, 174.16094273442044, 177.15667500797443]
# re6= [276.23478320394315, 278.92769810562487, 282.5010431748807, 285.88746534682565, 289.4337703581385]
# re8= [189.60811565012787, 192.20524502150772, 195.07895488384287, 197.58918138635536, 200.07956053076308]
# re9= [301.53066097088345, 304.08503985124224, 304.26997935397446, 306.54179602687475, 308.48266633347737]
# re10= [69.75849819678969, 65.79508194452215, 61.55039275269081, 63.54406270924362, 54.96208537486074]
# re12= [91.88596207638996, 91.8131349699849, 93.43460278472752, 95.88859014041051, 97.9873024809792]

# %%
routr2,routr3,routr4,routr5,routr6,routr8,routr9,routr10,routr12,fitr2,fitr3,fitr4,fitr5,fitr6,fitr8,fitr9,fitr10,fitr12=fittingsep(data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre,data13rre)
# Out:
# re2= [405.33813262331216, 409.0758022415955, 412.81347185987886, 416.55114147816226, 420.2888110964456]
# re3= [161.87353365814164, 164.56024706297984, 167.26829726408207, 169.97634746518426, 172.6843976662865]
# re4= [405.33813262331216, 409.0758022415955, 412.81347185987886, 416.55114147816226, 420.2888110964456]
# re5= [175.9435244005224, 178.4450618025222, 180.43581146092362, 182.20909026132935, 185.20482253488336]
# re6= [304.0820477048871, 307.25280590629393, 308.9184485184432, 310.5542984994999, 313.11020628242716]
# re8= [202.9673710461705, 205.8517651336494, 208.352333656257, 210.95719703751968, 211.7932797180682]
# re9= [349.3316344667322, 352.77910899336877, 356.45867715512054, 359.8224303598787, 363.1317316868053]
# re10= [97.28473641039898, 99.40801868120192, 101.7106035577267, 103.65828235892482, 94.51803227892742]
# re12= [91.97901523021301, 93.68885626061639, 96.03429947647774, 98.49377918568211, 100.88512157749787]

# %%
plt.scatter(np.array(data2mere).reshape(2*len(data2mere),3)[:,1],np.array(data2mere).reshape(2*len(data2mere),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mere).reshape(3*len(data3mere),3)[:,1],np.array(data3mere).reshape(3*len(data3mere),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mere).reshape(4*len(data4mere),3)[:,1],np.array(data4mere).reshape(4*len(data4mere),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mere).reshape(5*len(data5mere),3)[:,1],np.array(data5mere).reshape(5*len(data5mere),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data68me=np.r_[np.array(data6mere).reshape(6*len(data6mere),3),np.array(data8mere).reshape(8*len(data8mere),3)]
plt.scatter(data68me[:,1],data68me[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routme6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

#plt.scatter(np.array(data8mere).reshape(8*len(data8mere),3)[:,1],np.array(data8mere).reshape(8*len(data8mere),3)[:,0], label='Data')
#xplotin=np.arange(8)+1
#for i, func in enumerate(functions):
    #if i==0:
        #label = func.__name__ + f' (R-squared={routme8[i]:.2f})'
        #plt.plot(xplotin, func(xplotin, *fitme8[i]), label=label)
#plt.ylim(-450,10)
#plt.xlabel('x')
#plt.ylabel('y')
#plt.xlabel('number of turns')
#plt.ylabel('similarity of mean pitch')
#plt.legend()
#plt.show()


data902me=np.r_[np.array(data9mere).reshape(9*len(data9mere),3),np.array(data10mere).reshape(10*len(data10mere),3),np.array(data12mere).reshape(12*len(data12mere),3)
               ,np.array(data13mere).reshape(13*len(data13mere),3)]
plt.scatter(data902me[:,1],data902me[:,0], label='Data')
xplotin=np.arange(13)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routme9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2mare).reshape(2*len(data2mare),3)[:,1],np.array(data2mare).reshape(2*len(data2mare),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mare).reshape(3*len(data3mare),3)[:,1],np.array(data3mare).reshape(3*len(data3mare),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mare).reshape(4*len(data4mare),3)[:,1],np.array(data4mare).reshape(4*len(data4mare),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mare).reshape(5*len(data5mare),3)[:,1],np.array(data5mare).reshape(5*len(data5mare),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data68ma=np.r_[np.array(data6mare).reshape(6*len(data6mare),3),np.array(data8mare).reshape(8*len(data8mare),3)]
plt.scatter(data68ma[:,1],data68ma[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()


#plt.scatter(np.array(data8mare).reshape(8*len(data8mare),3)[:,1],np.array(data8mare).reshape(8*len(data8mare),3)[:,0], label='Data')
#xplotin=np.arange(8)+1
#for i, func in enumerate(functions):
    #if i==0:
        #label = func.__name__ + f' (R-squared={routma8[i]:.2f})'
        #plt.plot(xplotin, func(xplotin, *fitma8[i]), label=label)
#plt.ylim(-450,10)
#plt.xlabel('x')
#plt.ylabel('y')
#plt.xlabel('number of turns')
#plt.ylabel('similarity of mean pitch')
#plt.legend()
#plt.show()

data902ma=np.r_[np.array(data9mare).reshape(9*len(data9mare),3),np.array(data10mare).reshape(10*len(data10mare),3),
                np.array(data12mare).reshape(12*len(data12mare),3),np.array(data13mare).reshape(13*len(data13mare),3)]
plt.scatter(data902ma[:,1],data902ma[:,0], label='Data')
xplotin=np.arange(13)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routma9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2mire).reshape(2*len(data2mire),3)[:,1],np.array(data2mire).reshape(2*len(data2mire),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mire).reshape(3*len(data3mire),3)[:,1],np.array(data3mire).reshape(3*len(data3mire),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mire).reshape(4*len(data4mire),3)[:,1],np.array(data4mire).reshape(4*len(data4mire),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mire).reshape(5*len(data5mire),3)[:,1],np.array(data5mire).reshape(5*len(data5mire),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data68mi=np.r_[np.array(data6mire).reshape(6*len(data6mire),3),np.array(data8mire).reshape(8*len(data8mire),3)]
plt.scatter(data68mi[:,1],data68mi[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()


#plt.scatter(np.array(data8mire).reshape(8*len(data8mire),3)[:,1],np.array(data8mire).reshape(8*len(data8mire),3)[:,0], label='Data')
#xplotin=np.arange(8)+1
#for i, func in enumerate(functions):
    #if i==0:
        #label = func.__name__ + f' (R-squared={routmi8[i]:.2f})'
        #plt.plot(xplotin, func(xplotin, *fitmi8[i]), label=label)
#plt.ylim(-450,10)
#plt.xlabel('x')
#plt.ylabel('y')
#plt.xlabel('number of turns')
#plt.ylabel('similarity of mean pitch')
#plt.legend()
#plt.show()

data902mi=np.r_[np.array(data9mire).reshape(9*len(data9mire),3),np.array(data10mire).reshape(10*len(data10mire),3),
                np.array(data12mire).reshape(12*len(data12mire),3)]
plt.scatter(data902mi[:,1],data902mi[:,0], label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routmi9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2rre).reshape(2*len(data2rre),3)[:,1],np.array(data2rre).reshape(2*len(data2rre),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3rre).reshape(3*len(data3rre),3)[:,1],np.array(data3rre).reshape(3*len(data3rre),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4rre).reshape(4*len(data4rre),3)[:,1],np.array(data4rre).reshape(4*len(data4rre),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5rre).reshape(5*len(data5rre),3)[:,1],np.array(data5rre).reshape(5*len(data5rre),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data68r=np.r_[np.array(data6rre).reshape(6*len(data6rre),3),np.array(data8rre).reshape(8*len(data8rre),3)]
plt.scatter(data68r[:,1],data68r[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()


#plt.scatter(np.array(data8rre).reshape(8*len(data8rre),3)[:,1],np.array(data8rre).reshape(8*len(data8rre),3)[:,0], label='Data')
#xplotin=np.arange(8)+1
#for i, func in enumerate(functions):
    #if i==0:
        #label = func.__name__ + f' (R-squared={routr8[i]:.2f})'
        #plt.plot(xplotin, func(xplotin, *fitr8[i]), label=label)
#plt.ylim(-450,10)
#plt.xlabel('x')
#plt.ylabel('y')
#plt.xlabel('number of turns')
#plt.ylabel('similarity of mean pitch')
#plt.legend()
#plt.show()

data902r=np.r_[np.array(data9rre).reshape(9*len(data9rre),3),np.array(data10rre).reshape(10*len(data10rre),3),
               np.array(data12rre).reshape(12*len(data12rre),3),np.array(data13rre).reshape(13*len(data13rre),3)]
plt.scatter(data902r[:,1],data902r[:,0], label='Data')
xplotin=np.arange(13)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routr9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
fit_resultsme = []
r2_valuesme = []
r2_valuesmer = []
xin=dataallmep['IV']
yin=dataallmep['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsme.append(popt)
    y_fit = func(xin, *popt)
    #r2_valuesme.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmer.append(np.sqrt(mean_squared_error(yin, y_fit)))
    r2_valuesme.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesme.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesme)
#print(r2_valuesmer,r2_valuesme,(np.array(r2_valuesmer)+np.array(r2_valuesme))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1610.699497356246, 1615.628360848865, 1619.4335207326512, 1624.519307100112, 1628.3908459407028]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesme[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsme[i]), label=label)
plt.ylim(-450,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
fit_resultsma = []
r2_valuesma = []
r2_valuesmar = []
xin=dataallmap['IV']
yin=dataallmap['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsma.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesma.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesma.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmar.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesma.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesma)
#print(r2_valuesmar,r2_valuesma,(np.array(r2_valuesmar)+np.array(r2_valuesma))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1835.3067212788594, 1840.344533643169, 1845.5533539252385, 1850.2665940547672, 1855.0184170843474]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesma[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsma[i]), label=label)

plt.ylim(-750,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of max pitch')
#plt.legend()
plt.show()

# %%
fit_resultsmi = []
r2_valuesmi = []
r2_valuesmir = []
xin=dataallmip['IV']
yin=dataallmip['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsmi.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesmi.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesmi.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmir.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesmi.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesmi)
#print(r2_valuesmir,r2_valuesmi,(np.array(r2_valuesmir)+np.array(r2_valuesmi))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1571.0349405257004, 1571.1599026663575, 1576.0603117050193, 1581.2252912457168, 1585.4432078762593]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesmi[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsmi[i]), label=label)

plt.ylim(-420,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
fit_resultsr = []
r2_valuesr = []
r2_valuesrr = []
xin=dataallrp['IV']
yin=dataallrp['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsr.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesr.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesr.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesrr.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesr.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesr)
#print(r2_valuesrr,r2_valuesr,(np.array(r2_valuesrr)+np.array(r2_valuesr))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1773.7217409439986, 1776.5373503764438, 1781.0903607548178, 1786.2592139629505, 1791.3189319852688]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesr[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsr[i]), label=label)

plt.ylim(-700,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
med=smf.mixedlm("DV~IV",dataallmep,groups=dataallmep['type'])
medf = med.fit(method=['powell'])
print(medf.summary())
print(medf.tvalues['IV'])
# Out:
#            Mixed Linear Model Regression Results
# ...
# Model:             MixedLM  Dependent Variable:  DV
# No. Observations:  189      Method:              REML
# No. Groups:        6        Scale:               4023.4265
# Min. group size:   5        Log-Likelihood:      -1051.4403
# Max. group size:   76       Converged:           Yes
# Mean group size:   31.5
# -----------------------------------------------------------
#            Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# -----------------------------------------------------------
# Intercept -145.014   13.822 -10.492 0.000 -172.104 -117.924
# IV           6.873    1.999   3.438 0.001    2.955   10.792
# Group Var  693.563    8.340
# ...
#
# 3.4380663775434894

# %%
med=smf.mixedlm("DV~IV",dataallmep,groups=dataallmep['type'],re_formula="~IV")
medf = med.fit(method=['powell'])
print(medf.summary())
# Out:
#              Mixed Linear Model Regression Results
# ...
# Model:                MixedLM   Dependent Variable:   DV
# No. Observations:     189       Method:               REML
# No. Groups:           6         Scale:                4010.0136
# Min. group size:      5         Log-Likelihood:       -1051.1176
# Max. group size:      76        Converged:            Yes
# Mean group size:      31.5
# ----------------------------------------------------------------
#                 Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# ----------------------------------------------------------------
# Intercept      -146.668   12.443 -11.787 0.000 -171.055 -122.281
# IV                7.315    2.077   3.521 0.000    3.244   11.386
# Group Var       456.812    7.686
# Group x IV Cov   32.666
# IV Var            2.336
# ...

# %%
med=smf.mixedlm("DV~IV",dataallmep,groups=dataallmep['type'],re_formula="~IV")
free=sm.regression.mixed_linear_model.MixedLMParams.from_components(
np.ones(2),np.eye(2))
medf = med.fit(method=['powell'])
print(medf.summary())
# Out:
#              Mixed Linear Model Regression Results
# ...
# Model:                MixedLM   Dependent Variable:   DV
# No. Observations:     189       Method:               REML
# No. Groups:           6         Scale:                4010.0136
# Min. group size:      5         Log-Likelihood:       -1051.1176
# Max. group size:      76        Converged:            Yes
# Mean group size:      31.5
# ----------------------------------------------------------------
#                 Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# ----------------------------------------------------------------
# Intercept      -146.668   12.443 -11.787 0.000 -171.055 -122.281
# IV                7.315    2.077   3.521 0.000    3.244   11.386
# Group Var       456.812    7.686
# Group x IV Cov   32.666
# IV Var            2.336
# ...

# %%
mad=smf.mixedlm("DV~IV",dataallmap,groups=dataallmap['type'])
madf = mad.fit(method=['powell'])
print(madf.summary())
print(madf.tvalues['IV'])
# Out:
#           Mixed Linear Model Regression Results
# ...
# Model:              MixedLM Dependent Variable: DV
# No. Observations:   189     Method:             REML
# No. Groups:         6       Scale:              13278.2855
# Min. group size:    5       Log-Likelihood:     -1163.1401
# Max. group size:    76      Converged:          Yes
# Mean group size:    31.5
# ----------------------------------------------------------
#            Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ----------------------------------------------------------
# Intercept -177.456   25.410 -6.984 0.000 -227.259 -127.653
# IV           9.490    3.632  2.613 0.009    2.372   16.607
# Group Var 2364.172   15.486
# ...
#
# 2.6131023168183756

# %%
mad=smf.mixedlm("DV~IV",dataallmap,groups=dataallmap['type'],re_formula="~IV")
madf = mad.fit(method=['powell'])
print(madf.summary())
# Out:
#              Mixed Linear Model Regression Results
# ...
# Model:               MixedLM   Dependent Variable:   DV
# No. Observations:    189       Method:               REML
# No. Groups:          6         Scale:                13224.0775
# Min. group size:     5         Log-Likelihood:       -1162.7018
# Max. group size:     76        Converged:            Yes
# Mean group size:     31.5
# ---------------------------------------------------------------
#                 Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------------
# Intercept      -181.566   22.975 -7.903 0.000 -226.596 -136.537
# IV               10.642    4.379  2.430 0.015    2.059   19.225
# Group Var      1434.370   13.606
# Group x IV Cov  118.119
# IV Var            9.760
# ...

# %%
mid=smf.mixedlm("DV~IV",dataallmip,groups=dataallmip['type'])
midf = mid.fit(method=['powell'])
print(midf.summary())
print(midf.tvalues['IV'])
# Out:
#            Mixed Linear Model Regression Results
# ...
# Model:             MixedLM  Dependent Variable:  DV
# No. Observations:  189      Method:              REML
# No. Groups:        6        Scale:               3895.2936
# Min. group size:   5        Log-Likelihood:      -1044.4572
# Max. group size:   76       Converged:           Yes
# Mean group size:   31.5
# -----------------------------------------------------------
#            Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# -----------------------------------------------------------
# Intercept -127.461    8.010 -15.912 0.000 -143.161 -111.762
# IV           5.682    1.920   2.959 0.003    1.918    9.446
# Group Var    0.000    0.981
# ...
#
# 2.9585543530018015
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
mid=smf.mixedlm("DV~IV",dataallmip,groups=dataallmip['type'],re_formula="~IV")
midf = mid.fit(method=['powell'])
print(midf.summary())
# Out:
#              Mixed Linear Model Regression Results
# ...
# Model:                MixedLM   Dependent Variable:   DV
# No. Observations:     189       Method:               REML
# No. Groups:           6         Scale:                3867.8510
# Min. group size:      5         Log-Likelihood:       -1044.3431
# Max. group size:      76        Converged:            Yes
# Mean group size:      31.5
# ----------------------------------------------------------------
#                 Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# ----------------------------------------------------------------
# Intercept      -127.794   10.511 -12.158 0.000 -148.396 -107.192
# IV                6.065    3.183   1.906 0.057   -0.173   12.303
# Group Var         0.022
# Group x IV Cov   -0.127    0.669
# IV Var            2.426    0.396
# ...

# %%
rd=smf.mixedlm("DV~IV",dataallrp,groups=dataallrp['type'])
rdf = rd.fit(method=['powell'])
print(rdf.summary())
print(rdf.tvalues['IV'])
# Out:
#           Mixed Linear Model Regression Results
# ...
# Model:             MixedLM Dependent Variable: DV
# No. Observations:  189     Method:             REML
# No. Groups:        6       Scale:              11182.8001
# Min. group size:   5       Log-Likelihood:     -1144.3606
# Max. group size:   76      Converged:          Yes
# Mean group size:   31.5
# ---------------------------------------------------------
#            Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------
# Intercept -120.544   16.491 -7.310 0.000 -152.867 -88.222
# IV           5.234    3.295  1.589 0.112   -1.224  11.691
# Group Var  303.049    4.820
# ...
#
# 1.588514081094335

# %%
rd=smf.mixedlm("DV~IV",dataallrp,groups=dataallrp['type'],re_formula="~IV")
rdf = rd.fit(method=['powell'])
print(rdf.summary())
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 189     Method:             REML
# No. Groups:       6       Scale:              10986.7235
# Min. group size:  5       Log-Likelihood:     -1143.9365
# Max. group size:  76      Converged:          Yes
# Mean group size:  31.5
# --------------------------------------------------------
#                   Coef.   Std.Err. z P>|z| [0.025 0.975]
# --------------------------------------------------------
# Intercept        -115.137
# IV                  4.437
# Group Var        1775.960
# Group x IV Cov   -220.258
# IV Var             27.317
# ...
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2706: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
plt.scatter(xlabel,diff[:,3], color='blue')
#plt.scatter(xlabel121,diffc121, color='red')
#plt.scatter(xlabel53,diffc53[:,3], color='yellow')
plt.xlabel('Turns', fontsize=12)
plt.ylabel('DTW_pitch pattern',fontsize=12)
# Out:
# Text(0, 0.5, 'DTW_pitch pattern')

# %%
mothert=np.r_[t1,t2,t6,t7,t8,t9]
infantt=np.r_[tc1,tc2,tc6,tc7,tc8,tc9]

# %%
print(mothert[10,3],mothert[10,4],mothert[10,5],mothert[10,6])
print(infantt[10,3],infantt[10,4],infantt[10,5],infantt[10,6])
print(mothert[10,3]-infantt[10,3],mothert[10,4]-infantt[10,4],mothert[10,5]-infantt[10,5],
      mothert[10,6]-infantt[10,6])
print(diff[10,3],diff[10,4],diff[10,5],diff[10,6])
# Out:
# 69.50994439423039 287.0630692169769 217.5531248227465 246.15738483275595
# 49.696337690252676 322.21740066726323 272.52106297701056 302.5595368664922
# 19.81360670397771 -35.15433145028635 -54.96793815426406 -56.40215203373623
# -19.81360670397771 -35.15433145028635 -54.96793815426406 -56.40215203373623

# %%
data_d=np.c_[diff[:,1],mothert[:,1],infantt[:,1]]
data_dp=pd.DataFrame(data_d)
data_dp.columns=['Diff_d','Mother_d','Infant_d']
#data_dp.to_csv(r'C:\LJR\babylab\English\datamanual\cut\blockdata\Duration.csv')

data_r=np.c_[diff[:,3],mothert[:,3],infantt[:,3]]
data_rp=pd.DataFrame(data_r)
data_rp.columns=['Diff_r','Mother_r','Infant_r']
#data_rp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\Pitchrange.csv')

data_max=np.c_[diff[:,4],mothert[:,4],infantt[:,4]]
data_maxp=pd.DataFrame(data_max)
data_maxp.columns=['Diff_max','Mother_max','Infant_max']
#data_maxp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\Pitchmax.csv')

data_min=np.c_[diff[:,5],mothert[:,5],infantt[:,5]]
data_minp=pd.DataFrame(data_min)
data_minp.columns=['Diff_min','Mother_min','Infant_min']
#data_minp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\Pitchmin.csv')

data_mean=np.c_[diff[:,6],mothert[:,6],infantt[:,6]]
data_meanp=pd.DataFrame(data_mean)
data_meanp.columns=['Diff_mean','Mother_mean','Infant_mean']
#data_meanp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\Tseltal\conversation\Pitchmean.csv')

# %%
print(len(dataallmep['DV']),len(diff[:,6]))
# Out:
# 189 189

# %%
from scipy.stats import norm

# %%
modrm = """Diff_r~Mother_r+Infant_r
      """
modelrm = Model(modrm)
resrm = modelrm.fit(data_rp)
insrm = modelrm.inspect(std_est=True)
print(resrm,insrm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.039
# Number of iterations: 3
# Params: -0.122 -0.650 5714.532      lval  op      rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_r   ~  Mother_r    -0.122295 -0.088452    0.067548  -1.810482
# 1  Diff_r   ~  Infant_r    -0.649609 -0.729330    0.043515 -14.928260
# 2  Diff_r  ~~    Diff_r  5714.532315  0.443628  587.847653   9.721111
#
#     p-value
# 0  0.070221
# 1  0.000000
# 2  0.000000

# %%
coefmr=np.array(insrm.loc[insrm['rval']=='Mother_r','Est. Std'])
coefir=np.array(insrm.loc[insrm['rval']=='Infant_r','Est. Std'])

errmr=np.array(insrm.loc[insrm['rval']=='Mother_r','Std. Err'])
errir=np.array(insrm.loc[insrm['rval']=='Infant_r','Std. Err'])

diff_coefr=coefmr-coefir
diff_errr=(errmr**2+errir**2)**0.5

zr=diff_coefr/diff_errr
pr=2*(1-norm.cdf(abs(zr)))
print(pr)
# Out:
# [1.55431223e-15]

# %%
modmaxm = """Diff_max~Mother_max+Infant_max
      """
modelmaxm = Model(modmaxm)
resmaxm = modelmaxm.fit(data_maxp)
insmaxm = modelmaxm.inspect(std_est=True)
print(resmaxm,insmaxm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.302
# Number of iterations: 3
# Params: 0.592 -0.811 8055.997        lval  op        rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_max   ~  Mother_max     0.592221  0.375622    0.072488   8.169945
# 1  Diff_max   ~  Infant_max    -0.810872 -0.760027    0.049052 -16.530921
# 2  Diff_max  ~~    Diff_max  8055.997061  0.386053  828.711556   9.721111
#
#         p-value
# 0  2.220446e-16
# 1  0.000000e+00
# 2  0.000000e+00

# %%
coefmmax=np.array(insmaxm.loc[insmaxm['rval']=='Mother_max','Est. Std'])
coefimax=np.array(insmaxm.loc[insmaxm['rval']=='Infant_max','Est. Std'])

errmmax=np.array(insmaxm.loc[insmaxm['rval']=='Mother_max','Std. Err'])
errimax=np.array(insmaxm.loc[insmaxm['rval']=='Infant_max','Std. Err'])

diff_coefmax=coefmmax-coefimax
diff_errmax=(errmmax**2+errimax**2)**0.5

zmax=diff_coefmax/diff_errmax
pmax=2*(1-norm.cdf(abs(zmax)))
print(coefmmax,pmax)
# Out:
# [0.37562231] [0.]

# %%
modminm = """Diff_min~Mother_min+Infant_min
      """
modelminm = Model(modminm)
resminm = modelminm.fit(data_minp)
insminm = modelminm.inspect(std_est=True)
print(resminm,insminm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.012
# Number of iterations: 3
# Params: 0.012 -0.629 2017.244        lval  op        rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_min   ~  Mother_min     0.011648  0.011681    0.053692   0.216937
# 1  Diff_min   ~  Infant_min    -0.629475 -0.676556    0.050100 -12.564384
# 2  Diff_min  ~~    Diff_min  2017.244354  0.543560  207.511708   9.721111
#
#     p-value
# 0  0.828257
# 1  0.000000
# 2  0.000000

# %%
coefmmin=np.array(insminm.loc[insminm['rval']=='Mother_min','Est. Std'])
coefimin=np.array(insminm.loc[insminm['rval']=='Infant_min','Est. Std'])

errmmin=np.array(insminm.loc[insminm['rval']=='Mother_min','Std. Err'])
errimin=np.array(insminm.loc[insminm['rval']=='Infant_min','Std. Err'])

diff_coefmin=coefmmin-coefimin
diff_errmin=(errmmin**2+errimin**2)**0.5

zmin=diff_coefmin/diff_errmin
pmin=2*(1-norm.cdf(abs(zmin)))
print(coefmmin,zmin,pmin)
# Out:
# [0.01168145] [9.37193734] [0.]

# %%
modmeanm = """Diff_mean~Mother_mean+Infant_mean
      """
modelmeanm = Model(modmeanm)
resmeanm = modelmeanm.fit(data_meanp)
insmeanm = modelmeanm.inspect(std_est=True)
print(resmeanm,insmeanm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.083
# Number of iterations: 3
# Params: 0.463 -0.776 2511.339         lval  op         rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_mean   ~  Mother_mean     0.462847  0.375685    0.058838   7.866526
# 1  Diff_mean   ~  Infant_mean    -0.775802 -0.705089    0.052547 -14.763978
# 2  Diff_mean  ~~    Diff_mean  2511.338958  0.424927  258.338676   9.721111
#
#         p-value
# 0  3.552714e-15
# 1  0.000000e+00
# 2  0.000000e+00

# %%
coefmmean=np.array(insmeanm.loc[insmeanm['rval']=='Mother_mean','Est. Std'])
coefimean=np.array(insmeanm.loc[insmeanm['rval']=='Infant_mean','Est. Std'])

errmmean=np.array(insmeanm.loc[insmeanm['rval']=='Mother_mean','Std. Err'])
errimean=np.array(insmeanm.loc[insmeanm['rval']=='Infant_mean','Std. Err'])

diff_coefmean=coefmmean-coefimean
diff_errmean=(errmmean**2+errimean**2)**0.5

zmean=diff_coefmean/diff_errmean
pmean=2*(1-norm.cdf(abs(zmean)))
print(coefmmean,diff_errmean,pmean)
# Out:
# [0.37568482] [0.07888626] [0.]

# %%
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel82,diffc82[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel711,diffc711[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel22,diffc22[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel14,diffc14[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel71,diffc71[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel68,diffc68[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel89,diffc89[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel819,diffc819[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel11,diffc11[:,6], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel82,diffc82[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel711,diffc711[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel22,diffc22[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel14,diffc14[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel71,diffc71[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel68,diffc68[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel89,diffc89[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel819,diffc819[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
plt.scatter(xlabel11,diffc11[:,4], color='yellow')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel82,diffc82[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel711,diffc711[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel22,diffc22[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel14,diffc14[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel71,diffc71[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel68,diffc68[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel89,diffc89[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
plt.scatter(xlabel819,diffc819[:,5], color='yellow')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
plt.scatter(xlabel11,diffc11[:,5], color='yellow')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel82,diffc82[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel711,diffc711[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel22,diffc22[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel14,diffc14[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel71,diffc71[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel68,diffc68[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel89,diffc89[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel819,diffc819[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
plt.scatter(xlabel11,diffc11[:,3], color='yellow')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.plot(motherme[:,0],c='b')
plt.plot(infantme[:,0],c='r')
plt.ylim(100,700)
plt.show()

# %%
plt.scatter(xlabel89,tc89[:,6],c='r')
plt.scatter(xlabel89,t89[:,6],c='b')

# %%
print(tc89[:,6],t89[:,6])
# Out:
# [324.75881764 324.75881764 402.54566809 402.54566809 320.71489455
#  320.71489455 299.32660565 299.32660565 330.75168383] [221.03457565 203.89021274 203.89021274 227.44237267 227.44237267
#  232.24006043 232.24006043 238.27527761 238.27527761]

# %%
print(tc89[:,5],t89[:,5])
# Out:
# [267.83931423 267.83931423 347.34461699 347.34461699 295.4746592
#  295.4746592  246.3852821  246.3852821  295.4746592 ] [197.14972623 181.88598798 181.88598798 196.06985439 196.06985439
#  213.81569235 213.81569235 215.05431406 215.05431406]

# %%
print(tc89[:,4],t89[:,4])
# Out:
# [401.30553998 401.30553998 450.4502384  450.4502384  374.43130849
#  374.43130849 360.82137123 360.82137123 389.88115025] [263.47025813 233.16766588 233.16766588 242.78866567 242.78866567
#  244.1951261  244.1951261  249.90291661 249.90291661]

# %%
print(tc89[:,3],t89[:,3])
# Out:
# [133.46622575 133.46622575 103.10562142 103.10562142  78.95664928
#   78.95664928 114.43608912 114.43608912  94.40649105] [66.32053191 51.2816779  51.2816779  46.71881128 46.71881128 30.37943375
#  30.37943375 34.84860255 34.84860255]

# %%
mexpr=np.array([[1,66.32],[3,51.28],[5,46.72],[7,30.38],[9,34.85]])
iexpr=np.array([[2,133.46622575],[4,103.1],[6,78.96],[8,114.44],[10,94.41]])
plt.plot(iexpr[:,0],iexpr[:,1],'*-',c='r')
plt.plot(mexpr[:,0],mexpr[:,1],'*-',c='b')
plt.ylim(20,140)
# Out:
# (20.0, 140.0)

# %%
mexpma=np.array([[1,263.47],[3,233.17],[5,242.77],[7,244.19],[9,249.90]])
iexpma=np.array([[2,401.31],[4,450.45],[6,374.43],[8,360.82],[10,389.88]])
plt.plot(iexpma[:,0],iexpma[:,1],'*-',c='r')
plt.plot(mexpma[:,0],mexpma[:,1],'*-',c='b')
plt.ylim(220,460)
# Out:
# (220.0, 460.0)

# %%
mexpmi=np.array([[1,197.14],[3,181.89],[5,196.07],[7,213.82],[9,215.05]])
iexpmi=np.array([[2,267.84],[4,347.34],[6,295.47],[8,246.38],[10,295.47]])
plt.plot(iexpmi[:,0],iexpmi[:,1],'*-',c='r')
plt.plot(mexpmi[:,0],mexpmi[:,1],'*-',c='b')
plt.ylim(170,360)
# Out:
# (170.0, 360.0)

# %%
mexpme=np.array([[1,221.03],[3,203.89],[5,227.44],[7,232.24],[9,238.28]])
iexpme=np.array([[2,324.76],[4,402.55],[6,320.71],[8,299.33],[10,238.28]])
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(iexpme[:,0],iexpme[:,1],'*-',c='orangered')
plt.plot(mexpme[:,0],mexpme[:,1],'*-',c='b')
plt.ylim(190,420)
filesaveconmee=r'C:\LJR\paper\tseltalvsenglish\figures\texample.jpg'
fig.savefig(filesaveconmee, bbox_inches='tight', pad_inches=0)

# %%
plt.plot(xlabel73,tc73[:,6],'*-',c='r')
plt.plot(xlabel73,t73[:,6],'*-',c='b')
plt.show()
plt.plot(xlabel89,tc89[:,6],'*-',c='r')
plt.plot(xlabel89,t89[:,6],'*-',c='b')
plt.show()
plt.plot(xlabel813,tc813[:,6],'*-',c='r')
plt.plot(xlabel813,t813[:,6],'*-',c='b')
plt.show()
