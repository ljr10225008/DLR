# %%
import math
import numpy as np
import sklearn
from sklearn.cluster import KMeans
import matplotlib as mpl
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import re
import seaborn as sns
import pandas as pd
import random
from scipy import stats  #t-test
import semopy
import pandas as pd
from semopy import Model
import scipy.stats as stats 
from itertools import groupby
import statsmodels.formula.api as smf
import statsmodels.api as sm
# Out:
# C:\Users\ljr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
pathturn11 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn1"
filesturn11= os.listdir(pathturn11)
pathturn12 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn2"
filesturn12= os.listdir(pathturn12)
pathturn13 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn3"
filesturn13= os.listdir(pathturn13)
pathturn14 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn4"
filesturn14= os.listdir(pathturn14)
#pathturn15 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn5"
#filesturn15= os.listdir(pathturn15)
pathturn16 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn6"
filesturn16= os.listdir(pathturn16)
pathturn17 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn7"
filesturn17= os.listdir(pathturn17)
pathturn18 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn8"
filesturn18= os.listdir(pathturn18)
pathturn19 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn9"
filesturn19= os.listdir(pathturn19)
pathturn110 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn10"
filesturn110= os.listdir(pathturn110)

pathturn11c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn1"
filesturn11c= os.listdir(pathturn11c)
pathturn12c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn2"
filesturn12c= os.listdir(pathturn12c)
pathturn13c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn3"
filesturn13c= os.listdir(pathturn13c)
pathturn14c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn4"
filesturn14c= os.listdir(pathturn14c)
#pathturn15c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn5"
#filesturn15c= os.listdir(pathturn15c)
pathturn16c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn6"
filesturn16c= os.listdir(pathturn16c)
pathturn17c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn7"
filesturn17c= os.listdir(pathturn17c)
pathturn18c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn8"
filesturn18c= os.listdir(pathturn18c)
pathturn19c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn9"
filesturn19c= os.listdir(pathturn19c)
pathturn110c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn10"
filesturn110c= os.listdir(pathturn110c)

# %%
print(re.search("(\d+\.\d+)",filesturn12[0]).group(0),re.search("(\d+\.\d+)",filesturn12c[0]).group(0))
# Out:
# 633.743 637.148

# %%
pathturn111 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn11"
filesturn111= os.listdir(pathturn111)
pathturn112 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn12"
filesturn112= os.listdir(pathturn112)
pathturn113 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn13"
filesturn113= os.listdir(pathturn113)
pathturn114 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn14"
filesturn114= os.listdir(pathturn114)
pathturn115 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn15"
filesturn115= os.listdir(pathturn115)
pathturn116 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn16"
filesturn116= os.listdir(pathturn116)
pathturn117 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn17"
filesturn117= os.listdir(pathturn117)
pathturn118 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn18"
filesturn118= os.listdir(pathturn118)
pathturn119 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn19"
filesturn119= os.listdir(pathturn119)
pathturn120 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn20"
filesturn120= os.listdir(pathturn120)
pathturn121 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn21"
filesturn121= os.listdir(pathturn121)
pathturn122 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn22"
filesturn122= os.listdir(pathturn122)
pathturn123 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn23"
filesturn123= os.listdir(pathturn123)
pathturn124 = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\fanew\turn24"
filesturn124= os.listdir(pathturn124)


pathturn111c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn11"
filesturn111c= os.listdir(pathturn111c)
pathturn112c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn12"
filesturn112c= os.listdir(pathturn112c)
pathturn113c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn13"
filesturn113c= os.listdir(pathturn113c)
pathturn114c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn14"
filesturn114c= os.listdir(pathturn114c)
pathturn115c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn15"
filesturn115c= os.listdir(pathturn115c)
pathturn116c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn16"
filesturn116c= os.listdir(pathturn116c)
pathturn117c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn17"
filesturn117c= os.listdir(pathturn117c)
pathturn118c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn18"
filesturn118c= os.listdir(pathturn118c)
pathturn119c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn19"
filesturn119c= os.listdir(pathturn119c)
pathturn120c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn20"
filesturn120c= os.listdir(pathturn120c)
pathturn121c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn21"
filesturn121c= os.listdir(pathturn121c)
pathturn122c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn22"
filesturn122c= os.listdir(pathturn122c)
pathturn123c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn23"
filesturn123c= os.listdir(pathturn123c)
pathturn124c = r"C:\LJR\babylab\English\cut\high\5134\turntaking\block\chinew\turn24"
filesturn124c= os.listdir(pathturn124c)

# %%
print(len(filesturn115))
# Out:
# 12

# %%
pathturn21 = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\fanew\turn1"
filesturn21= os.listdir(pathturn21)
pathturn22 = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\fanew\turn2"
filesturn22= os.listdir(pathturn22)
pathturn23 = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\fanew\turn3"
filesturn23= os.listdir(pathturn23)
pathturn24 = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\fanew\turn4"
filesturn24= os.listdir(pathturn24)
pathturn25 = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\fanew\turn5"
filesturn25= os.listdir(pathturn25)

pathturn21c = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\chinew\turn1"
filesturn21c= os.listdir(pathturn21c)
pathturn22c = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\chinew\turn2"
filesturn22c= os.listdir(pathturn22c)
pathturn23c = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\chinew\turn3"
filesturn23c= os.listdir(pathturn23c)
pathturn24c = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\chinew\turn4"
filesturn24c= os.listdir(pathturn24c)
pathturn25c = r"C:\LJR\babylab\English\cut\high\6045\turntaking\block\chinew\turn5"
filesturn25c= os.listdir(pathturn25c)

# %%
pathturn31 = r"C:\LJR\babylab\English\cut\high\8496\turntaking\block\fanew\turn1"
filesturn31= os.listdir(pathturn31)
pathturn32 = r"C:\LJR\babylab\English\cut\high\8496\turntaking\block\fanew\turn2"
filesturn32= os.listdir(pathturn32)

pathturn31c = r"C:\LJR\babylab\English\cut\high\8496\turntaking\block\chinew\turn1"
filesturn31c= os.listdir(pathturn31c)
pathturn32c = r"C:\LJR\babylab\English\cut\high\8496\turntaking\block\chinew\turn2"
filesturn32c= os.listdir(pathturn32c)

# %%
pathturn41 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn1"
filesturn41= os.listdir(pathturn41)
pathturn42 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn2"
filesturn42= os.listdir(pathturn42)
pathturn43 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn3"
filesturn43= os.listdir(pathturn43)
pathturn44 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn4"
filesturn44= os.listdir(pathturn44)
pathturn45 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn5"
filesturn45= os.listdir(pathturn45)
pathturn46 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn6"
filesturn46= os.listdir(pathturn46)
pathturn47 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn7"
filesturn47= os.listdir(pathturn47)
pathturn48 = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\fanew\turn8"
filesturn48= os.listdir(pathturn48)

pathturn41c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn1"
filesturn41c= os.listdir(pathturn41c)
pathturn42c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn2"
filesturn42c= os.listdir(pathturn42c)
pathturn43c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn3"
filesturn43c= os.listdir(pathturn43c)
pathturn44c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn4"
filesturn44c= os.listdir(pathturn44c)
pathturn45c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn5"
filesturn45c= os.listdir(pathturn45c)
pathturn46c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn6"
filesturn46c= os.listdir(pathturn46c)
pathturn47c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn7"
filesturn47c= os.listdir(pathturn47c)
pathturn48c = r"C:\LJR\babylab\English\cut\high\8560\turntaking\block\chinew\turn8"
filesturn48c= os.listdir(pathturn48c)

# %%
pathturn51 = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\fanew\turn1"
filesturn51= os.listdir(pathturn51)
pathturn52 = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\fanew\turn2"
filesturn52= os.listdir(pathturn52)
pathturn53 = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\fanew\turn3"
filesturn53= os.listdir(pathturn53)

pathturn51c = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\chinew\turn1"
filesturn51c= os.listdir(pathturn51c)
pathturn52c = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\chinew\turn2"
filesturn52c= os.listdir(pathturn52c)
pathturn53c = r"C:\LJR\babylab\English\cut\high\9106\turntaking\block\chinew\turn3"
filesturn53c= os.listdir(pathturn53c)

# %%
pathturn61 = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\fanew\turn1"
filesturn61= os.listdir(pathturn61)
pathturn62 = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\fanew\turn2"
filesturn62= os.listdir(pathturn62)
pathturn63 = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\fanew\turn3"
filesturn63= os.listdir(pathturn63)
pathturn64 = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\fanew\turn4"
filesturn64= os.listdir(pathturn64)
pathturn65 = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\fanew\turn5"
filesturn65= os.listdir(pathturn65)

pathturn61c = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\chinew\turn1"
filesturn61c= os.listdir(pathturn61c)
pathturn62c = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\chinew\turn2"
filesturn62c= os.listdir(pathturn62c)
pathturn63c = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\chinew\turn3"
filesturn63c= os.listdir(pathturn63c)
pathturn64c = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\chinew\turn4"
filesturn64c= os.listdir(pathturn64c)
pathturn65c = r"C:\LJR\babylab\English\cut\high\9733\turntaking\block\chinew\turn5"
filesturn65c= os.listdir(pathturn65c)

# %%
import sklearn
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)

# %%
def featurec(path,files):
    t=np.zeros((len(files),10))
    for i in range(len(files)):
        x,sr1=librosa.load(path+"\\"+files[i],sr=None)
        duration=librosa.get_duration(y=x, sr=sr1)
        emphasized_signal = np.append(x[0], x[1:] -0.97 * x[:-1])
        mfccss = librosa.feature.mfcc(y=emphasized_signal, sr=sr1)
        mfccs = normalize(mfccss , axis=1)
        mfccs=mfccs.T
        mfccsm=np.mean(mfccs)
        f0, voiced_flag, voiced_probs = librosa.pyin(x,sr=sr1,frame_length=512, fill_na=np.nan, n_thresholds=50, fmin=120, fmax=600)
        rf0= np.nanmax(f0)-np.nanmin(f0)
        if np.isnan(rf0):
            print(path+"\\"+files[i])
        maxf0 = np.nanmax(f0)
        minf0 = np.nanmin(f0)
        mmf0=np.nanmean(f0)
        rms = librosa.feature.rms(y=x,frame_length=512, hop_length=128)
        mrms=np.nanmean(rms)
        zerocrossr = librosa.feature.zero_crossing_rate(y=x,frame_length=512, hop_length=128)
        mzerocrossr=np.nanmean(zerocrossr)
        starttime=re.search("(\d+\.\d+)",files[i]).group(0)
        label=0
        feature=np.c_[float(starttime),duration,mfccsm,rf0,maxf0,minf0,mmf0,mrms,mzerocrossr,label]
        t[i,:]=feature
    return t

# %%
def featureci(path,files):
    t=np.zeros((len(files),10))
    for i in range(len(files)):
        x,sr1=librosa.load(path+"\\"+files[i],sr=None)
        duration=librosa.get_duration(y=x, sr=sr1)
        emphasized_signal = np.append(x[0], x[1:] -0.97 * x[:-1])
        mfccss = librosa.feature.mfcc(y=emphasized_signal, sr=sr1)
        mfccs = normalize(mfccss , axis=1)
        mfccs=mfccs.T
        mfccsm=np.mean(mfccs)
        f0, voiced_flag, voiced_probs = librosa.pyin(x,sr=sr1,frame_length=512, fill_na=np.nan, n_thresholds=50, fmin=120, fmax=1000)
        rf0= np.nanmax(f0)-np.nanmin(f0)
        if np.isnan(rf0):
            print(path+"\\"+files[i])
        maxf0 = np.nanmax(f0)
        minf0 = np.nanmin(f0)
        mmf0=np.nanmean(f0)
        rms = librosa.feature.rms(y=x,frame_length=512, hop_length=128)
        mrms=np.nanmean(rms)
        zerocrossr = librosa.feature.zero_crossing_rate(y=x,frame_length=512, hop_length=128)
        mzerocrossr=np.nanmean(zerocrossr)
        starttime=re.search("(\d+\.\d+)",files[i]).group(0)
        label=1
        feature=np.c_[float(starttime),duration,mfccsm,rf0,maxf0,minf0,mmf0,mrms,mzerocrossr,label]
        t[i,:]=feature
    return t

# %%
def diffc(pathturn,filesturn,pathturnc,filesturnc):
    t=featurec(pathturn,filesturn)
    tc=featureci(pathturnc,filesturnc)
    block=np.r_[t,tc]
    blocks = block[block[:,0].argsort()]
    groups = [(k, sum(1 for _ in g)) for k, g in groupby(blocks[:,-1])]
    groupn=np.zeros((len(groups),1))
    for i in range(len(groups)):
        groupn[i]=groups[i][1]
    
    ind=np.zeros((len(groupn),2))
    for i in range(len(groupn)):
        if i!=len(groupn):
            ind[i,:]=np.c_[sum(groupn[0:i]),sum(groupn[0:i+1])]
    blockn=np.zeros((len(groupn),10))
    for i in range(len(groupn)):
        blockn[i,:]=np.mean(blocks[int(ind[i,0]):int(ind[i,1]),:],axis=0)
    diff=np.zeros((len(groupn)-1,10))
    mother=np.zeros((len(groupn)-1,10))
    infant=np.zeros((len(groupn)-1,10))
    for i in range(len(groupn)-1):
        diff[i,:]=np.absolute(blockn[i+1,:]-blockn[i,:])
        if (blockn[i+1,-1]==0)&(blockn[i,-1]==1):
            mother[i,:]=blockn[i+1,:]
            infant[i,:]=blockn[i,:]
        if (blockn[i+1,-1]==1)&(blockn[i,-1]==0):
            mother[i,:]=blockn[i,:]
            infant[i,:]=blockn[i+1,:]
    xlabel=(np.arange(len(diff))+1)
    print(len(diff))
    return -diff,xlabel,mother,infant

# %%
lenall=[]

# %%
diffc11,xlabel11,t11,tc11=diffc(pathturn11,filesturn11,pathturn11c,filesturn11c)
diffc12,xlabel12,t12,tc12=diffc(pathturn12,filesturn12,pathturn12c,filesturn12c)
diffc13,xlabel13,t13,tc13=diffc(pathturn13,filesturn13,pathturn13c,filesturn13c)
diffc14,xlabel14,t14,tc14=diffc(pathturn14,filesturn14,pathturn14c,filesturn14c)
#diffc15,xlabel15,t15,tc15=diffc(pathturn15,filesturn15,pathturn15c,filesturn15c)
diffc16,xlabel16,t16,tc16=diffc(pathturn16,filesturn16,pathturn16c,filesturn16c)
diffc17,xlabel17,t17,tc17=diffc(pathturn17,filesturn17,pathturn17c,filesturn17c)
diffc18,xlabel18,t18,tc18=diffc(pathturn18,filesturn18,pathturn18c,filesturn18c)
diffc19,xlabel19,t19,tc19=diffc(pathturn19,filesturn19,pathturn19c,filesturn19c)
diffc110,xlabel110,t110,tc110=diffc(pathturn110,filesturn110,pathturn110c,filesturn110c)
diffc111,xlabel111,t111,tc111=diffc(pathturn111,filesturn111,pathturn111c,filesturn111c)
diffc112,xlabel112,t112,tc112=diffc(pathturn112,filesturn112,pathturn112c,filesturn112c)
diffc113,xlabel113,t113,tc113=diffc(pathturn113,filesturn113,pathturn113c,filesturn113c)
diffc114,xlabel114,t114,tc114=diffc(pathturn114,filesturn114,pathturn114c,filesturn114c)
diffc115,xlabel115,t115,tc115=diffc(pathturn115,filesturn115,pathturn115c,filesturn115c)
diffc116,xlabel116,t116,tc116=diffc(pathturn116,filesturn116,pathturn116c,filesturn116c)
diffc117,xlabel117,t117,tc117=diffc(pathturn117,filesturn117,pathturn117c,filesturn117c)
diffc118,xlabel118,t118,tc118=diffc(pathturn118,filesturn118,pathturn118c,filesturn118c)
diffc119,xlabel119,t119,tc119=diffc(pathturn119,filesturn119,pathturn119c,filesturn119c)
diffc120,xlabel120,t120,tc120=diffc(pathturn120,filesturn120,pathturn120c,filesturn120c)
diffc121,xlabel121,t121,tc121=diffc(pathturn121,filesturn121,pathturn121c,filesturn121c)
diffc122,xlabel122,t122,tc122=diffc(pathturn122,filesturn122,pathturn122c,filesturn122c)
diffc123,xlabel123,t123,tc123=diffc(pathturn123,filesturn123,pathturn123c,filesturn123c)
diffc124,xlabel124,t124,tc124=diffc(pathturn124,filesturn124,pathturn124c,filesturn124c)
# Out:
# 2
# 2
# 3
# 3
# 4
# 2
# 2
# 4
# 7
# 2
# 4
# 8
# 2
# 16
# 6
# 2
# 3
# 9
# 11
# 26
# 12
# 2
# 2

# %%
lenall.append(len(diffc11))
lenall.append(len(diffc12))
lenall.append(len(diffc13))
lenall.append(len(diffc14))
#lenall.append(len(diffc15))
lenall.append(len(diffc16))
lenall.append(len(diffc17))
lenall.append(len(diffc18))
lenall.append(len(diffc19))
lenall.append(len(diffc110))
lenall.append(len(diffc111))
lenall.append(len(diffc112))
lenall.append(len(diffc113))
lenall.append(len(diffc114))
lenall.append(len(diffc115))
lenall.append(len(diffc116))
lenall.append(len(diffc117))
lenall.append(len(diffc118))
lenall.append(len(diffc119))
lenall.append(len(diffc120))
#lenall.append(len(diffc121))
lenall.append(len(diffc122))
lenall.append(len(diffc123))
lenall.append(len(diffc124))

# %%
#diffct11=np.r_[diffc11,diffc12,diffc13,diffc14,diffc15,diffc16,diffc17,diffc18,diffc19,diffc110]
diffct11=np.r_[diffc11,diffc12,diffc13,diffc14,diffc16,diffc17,diffc18,diffc19,diffc110]
#diffct12=np.r_[diffc111,diffc112,diffc113,diffc114,diffc115,diffc116,diffc117,diffc118,diffc119,diffc120,diffc121,diffc122,diffc123,diffc124]
diffct12=np.r_[diffc111,diffc112,diffc113,diffc114,diffc115,diffc116,diffc117,diffc118,diffc119,diffc120,diffc122,diffc123,diffc124]
diffc1=np.r_[diffct11,diffct12]
#xlabelt11=np.r_[xlabel11,xlabel12,xlabel13,xlabel14,xlabel15,xlabel16,xlabel17,xlabel18,xlabel19,xlabel110]
xlabelt11=np.r_[xlabel11,xlabel12,xlabel13,xlabel14,xlabel16,xlabel17,xlabel18,xlabel19,xlabel110]
#xlabelt12=np.r_[xlabel111,xlabel112,xlabel113,xlabel114,xlabel115,xlabel116,xlabel117,xlabel118,xlabel119,xlabel120,xlabel121,xlabel122,xlabel123,xlabel124]
xlabelt12=np.r_[xlabel111,xlabel112,xlabel113,xlabel114,xlabel115,xlabel116,xlabel117,xlabel118,xlabel119,xlabel120,xlabel122,xlabel123,xlabel124]
xlabel1=np.r_[xlabelt11,xlabelt12]
#tt11=np.r_[t11,t12,t13,t14,t15,t16,t17,t18,t19,t110]
tt11=np.r_[t11,t12,t13,t14,t16,t17,t18,t19,t110]
#tt12=np.r_[t111,t112,t113,t114,t115,t116,t117,t118,t119,t120,t121,t122,t123,t124]
tt12=np.r_[t111,t112,t113,t114,t115,t116,t117,t118,t119,t120,t122,t123,t124]
tt12s=np.r_[t111,t112,t113,t114,t116,t117,t118,t119,t120,t122,t123,t124]
t1=np.r_[tt11,tt12]
t1s=np.r_[tt11,tt12s]
#ttc11=np.r_[tc11,tc12,tc13,tc14,tc15,tc16,tc17,tc18,tc19,tc110]
ttc11=np.r_[tc11,tc12,tc13,tc14,tc16,tc17,tc18,tc19,tc110]
#ttc12=np.r_[tc111,tc112,tc113,tc114,tc115,tc116,tc117,tc118,tc119,tc120,tc121,tc122,tc123,tc124]
ttc12=np.r_[tc111,tc112,tc113,tc114,tc115,tc116,tc117,tc118,tc119,tc120,tc122,tc123,tc124]
ttc12s=np.r_[tc111,tc112,tc113,tc114,tc116,tc117,tc118,tc119,tc120,tc122,tc123,tc124]
tc1=np.r_[ttc11,ttc12]
tc1s=np.r_[ttc11,ttc12s]

# %%
#mdiff11=np.c_[np.mean(diffc11,axis = 0),np.mean(diffc12,axis = 0),np.mean(diffc13,axis = 0),np.mean(diffc14,axis = 0),np.mean(diffc15,axis = 0),np.mean(diffc16,axis = 0),np.mean(diffc17,axis = 0),np.mean(diffc18,axis = 0),np.mean(diffc19,axis = 0),np.mean(diffc110,axis = 0)]
mdiff11=np.c_[np.mean(diffc11,axis = 0),np.mean(diffc12,axis = 0),np.mean(diffc13,axis = 0),np.mean(diffc14,axis = 0),np.mean(diffc16,axis = 0),np.mean(diffc17,axis = 0),np.mean(diffc18,axis = 0),np.mean(diffc19,axis = 0),np.mean(diffc110,axis = 0)]
mdiff12=np.c_[np.mean(diffc111,axis = 0),np.mean(diffc112,axis = 0),np.mean(diffc113,axis = 0),np.mean(diffc114,axis = 0),np.mean(diffc115,axis = 0),np.mean(diffc116,axis = 0),np.mean(diffc117,axis = 0),np.mean(diffc118,axis = 0),np.mean(diffc119,axis = 0),np.mean(diffc120,axis = 0),np.mean(diffc121,axis = 0),np.mean(diffc122,axis = 0),np.mean(diffc123,axis = 0),np.mean(diffc124,axis = 0)]
mdiff1=np.c_[mdiff11,mdiff12]

# %%
diffc21,xlabel21,t21,tc21=diffc(pathturn21,filesturn21,pathturn21c,filesturn21c)
diffc22,xlabel22,t22,tc22=diffc(pathturn22,filesturn22,pathturn22c,filesturn22c)
diffc23,xlabel23,t23,tc23=diffc(pathturn23,filesturn23,pathturn23c,filesturn23c)
diffc24,xlabel24,t24,tc24=diffc(pathturn24,filesturn24,pathturn24c,filesturn24c)
diffc25,xlabel25,t25,tc25=diffc(pathturn25,filesturn25,pathturn25c,filesturn25c)
# Out:
# 2
# 3
# 3
# 5
# 2

# %%
lenall.append(len(diffc21))
lenall.append(len(diffc22))
lenall.append(len(diffc23))
lenall.append(len(diffc24))
lenall.append(len(diffc25))

# %%
diffc2=np.r_[diffc21,diffc22,diffc23,diffc24,diffc25]
xlabel2=np.r_[xlabel21,xlabel22,xlabel23,xlabel24,xlabel25]
t2=np.r_[t21,t22,t23,t24,t25]
tc2=np.r_[tc21,tc22,tc23,tc24,tc25]

# %%
mdiff2=np.c_[np.mean(diffc21,axis = 0),np.mean(diffc22,axis = 0),np.mean(diffc23,axis = 0),np.mean(diffc24,axis = 0),np.mean(diffc25,axis = 0)]

# %%
diffc31,xlabel31,t31,tc31=diffc(pathturn31,filesturn31,pathturn31c,filesturn31c)
diffc32,xlabel32,t32,tc32=diffc(pathturn32,filesturn32,pathturn32c,filesturn32c)
# Out:
# 9
# 2

# %%
lenall.append(len(diffc31))
lenall.append(len(diffc32))

# %%
mdiff3=np.c_[np.mean(diffc31,axis = 0),np.mean(diffc32,axis = 0)]

# %%
diffc3=np.r_[diffc31,diffc32]
xlabel3=np.r_[xlabel31,xlabel32]
t3=np.r_[t31,t32]
tc3=np.r_[tc31,tc32]

# %%
diffc41,xlabel41,t41,tc41=diffc(pathturn41,filesturn41,pathturn41c,filesturn41c)
diffc42,xlabel42,t42,tc42=diffc(pathturn42,filesturn42,pathturn42c,filesturn42c)
diffc43,xlabel43,t43,tc43=diffc(pathturn43,filesturn43,pathturn43c,filesturn43c)
diffc44,xlabel44,t44,tc44=diffc(pathturn44,filesturn44,pathturn44c,filesturn44c)
diffc45,xlabel45,t45,tc45=diffc(pathturn45,filesturn45,pathturn45c,filesturn45c)
diffc46,xlabel46,t46,tc46=diffc(pathturn46,filesturn46,pathturn46c,filesturn46c)
diffc47,xlabel47,t47,tc47=diffc(pathturn47,filesturn47,pathturn47c,filesturn47c)
diffc48,xlabel48,t48,tc48=diffc(pathturn48,filesturn48,pathturn48c,filesturn48c)
# Out:
# 6
# 3
# 8
# 2
# 12
# 6
# 5
# 2

# %%
lenall.append(len(diffc41))
lenall.append(len(diffc42))
lenall.append(len(diffc43))
lenall.append(len(diffc44))
lenall.append(len(diffc45))
lenall.append(len(diffc46))
lenall.append(len(diffc47))
lenall.append(len(diffc48))

# %%
diffc4=np.r_[diffc41,diffc42,diffc43,diffc44,diffc45,diffc46,diffc47,diffc48]
xlabel4=np.r_[xlabel41,xlabel42,xlabel43,xlabel44,xlabel45,xlabel46,xlabel47,xlabel48]
t4=np.r_[t41,t42,t43,t44,t45,t46,t47,t48]
tc4=np.r_[tc41,tc42,tc43,tc44,tc45,tc46,tc47,tc48]

# %%
mdiff4=np.c_[np.mean(diffc41,axis = 0),np.mean(diffc42,axis = 0),np.mean(diffc43,axis = 0),np.mean(diffc44,axis = 0),np.mean(diffc45,axis = 0),np.mean(diffc46,axis = 0),np.mean(diffc47,axis = 0),np.mean(diffc48,axis = 0)]

# %%
diffc51,xlabel51,t51,t51c=diffc(pathturn51,filesturn51,pathturn51c,filesturn51c)
diffc52,xlabel52,t52,t52c=diffc(pathturn52,filesturn52,pathturn52c,filesturn52c)
diffc53,xlabel53,t53,t53c=diffc(pathturn53,filesturn53,pathturn53c,filesturn53c)
# Out:
# 2
# 5
# 4

# %%
lenall.append(len(diffc51))
lenall.append(len(diffc52))
lenall.append(len(diffc53))

# %%
diffc5=np.r_[diffc51,diffc52,diffc53]
xlabel5=np.r_[xlabel51,xlabel52,xlabel53]
t5=np.r_[t51,t52,t53]
tc5=np.r_[t51c,t52c,t53c]

# %%
mdiff5=np.c_[np.mean(diffc51,axis = 0),np.mean(diffc52,axis = 0),np.mean(diffc53,axis = 0)]

# %%
diffc61,xlabel61,t61,tc61=diffc(pathturn61,filesturn61,pathturn61c,filesturn61c)
diffc62,xlabel62,t62,tc62=diffc(pathturn62,filesturn62,pathturn62c,filesturn62c)
diffc63,xlabel63,t63,tc63=diffc(pathturn63,filesturn63,pathturn63c,filesturn63c)
diffc64,xlabel64,t64,tc64=diffc(pathturn64,filesturn64,pathturn64c,filesturn64c)
diffc65,xlabel65,t65,tc65=diffc(pathturn65,filesturn65,pathturn65c,filesturn65c)
# Out:
# 6
# 4
# 2
# 3
# 2

# %%
lenall.append(len(diffc61))
lenall.append(len(diffc62))
lenall.append(len(diffc63))
lenall.append(len(diffc64))
lenall.append(len(diffc65))

# %%
lenalla=np.array(lenall)

# %%
lenallshort=lenalla[np.where(lenalla<=12)[0]]

# %%
lenalla
# Out:
# array([ 2,  2,  3,  3,  4,  2,  2,  4,  7,  2,  4,  8,  2, 16,  6,  2,  3,
#         9, 11, 12,  2,  2,  2,  3,  3,  5,  2,  9,  2,  6,  3,  8,  2, 12,
#         6,  5,  2,  2,  5,  4,  6,  4,  2,  3,  2])

# %%
print(np.mean(lenallshort),np.std(lenallshort))
# Out:
# 4.318181818181818 2.850619767322755

# %%
lenp=pd.DataFrame(lenalla)
lenps=pd.DataFrame(lenallshort)
lenp.columns=['length']
lenps.columns=['length']

# %%
#lenp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishlen16.csv')
#lenps.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishlen12.csv')

# %%
diffc6=np.r_[diffc61,diffc62,diffc63,diffc64,diffc65]
xlabel6=np.r_[xlabel61,xlabel62,xlabel63,xlabel64,xlabel65]
t6=np.r_[t61,t62,t63,t64,t65]
tc6=np.r_[tc61,tc62,tc63,tc64,tc65]

# %%
mdiff6=np.c_[np.mean(diffc61,axis = 0),np.mean(diffc62,axis = 0),np.mean(diffc63,axis = 0),np.mean(diffc64,axis = 0),np.mean(diffc65,axis = 0)]

# %%
diff=np.r_[diffc1,diffc2,diffc3,diffc4,diffc5,diffc6]
xlabel=np.r_[xlabel1,xlabel2,xlabel3,xlabel4,xlabel5,xlabel6]

# %%
def ind(datain,labelin,ind):
    inds=np.zeros(len(datain))+ind
    dataout=np.c_[datain,labelin,inds]
    return dataout

# %%
dataallr=np.r_[ind(diffc1[:,3],xlabel1,1),ind(diffc2[:,3],xlabel2,2),ind(diffc3[:,3],xlabel3,3),ind(diffc4[:,3],xlabel4,4),ind(diffc5[:,3],xlabel5,5),ind(diffc6[:,3],xlabel6,6)]
dataallma=np.r_[ind(diffc1[:,4],xlabel1,1),ind(diffc2[:,4],xlabel2,2),ind(diffc3[:,4],xlabel3,3),ind(diffc4[:,4],xlabel4,4),ind(diffc5[:,4],xlabel5,5),ind(diffc6[:,4],xlabel6,6)]
dataallmi=np.r_[ind(diffc1[:,5],xlabel1,1),ind(diffc2[:,5],xlabel2,2),ind(diffc3[:,5],xlabel3,3),ind(diffc4[:,5],xlabel4,4),ind(diffc5[:,5],xlabel5,5),ind(diffc6[:,5],xlabel6,6)]
dataallme=np.r_[ind(diffc1[:,6],xlabel1,1),ind(diffc2[:,6],xlabel2,2),ind(diffc3[:,6],xlabel3,3),ind(diffc4[:,6],xlabel4,4),ind(diffc5[:,6],xlabel5,5),ind(diffc6[:,6],xlabel6,6)]

# %%
def remove16(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    endindex=datain[labelend.astype(int),1]
    startr=labelstart[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(startr)
    endr=labelend[np.where(endindex.astype(int)==16)[0]].astype(int)
    #print(endr)
    dataformer=datain[:startr[0]]
    datalatter=datain[endr[0]+1:]
    dataout=np.r_[dataformer,datalatter]
    #print(len(datain),len(dataout),dataout[:,1])
    return dataout

# %%
def startend(datain):
    labelstart=np.where(datain[:,1]==1)[0]
    labelend=np.zeros((len(labelstart)))
    labelend[:len(labelstart)-1]=labelstart[1:len(labelstart)]-1
    labelend[-1]=len(datain[:,1])-1
    return labelstart,labelend.astype(int)

# %%
#dataallrre=dataallr[np.where(dataallr[:,1]<=12)[0]]
#dataallmare=dataallma[np.where(dataallma[:,1]<=12)[0]]
#dataallmire=dataallmi[np.where(dataallmi[:,1]<=12)[0]]
#dataallmere=dataallme[np.where(dataallme[:,1]<=12)[0]]

# %%
dataallrre=remove16(dataallr)
dataallmare=remove16(dataallma)
dataallmire=remove16(dataallmi)
dataallmere=remove16(dataallme)

# %%
dataallrf=dataallr[np.where(dataallr[:,1]<=1)[0]]
dataallmaf=dataallma[np.where(dataallma[:,1]<=1)[0]]
dataallmif=dataallmi[np.where(dataallmi[:,1]<=1)[0]]
dataallmef=dataallme[np.where(dataallme[:,1]<=1)[0]]

# %%
labelsrre,labelerre=startend(dataallrre)
labelsmere,labelemere=startend(dataallmere)
labelsmare,labelemare=startend(dataallmare)
labelsmire,labelemire=startend(dataallmire)

# %%
labelsr,labeler=startend(dataallr)
labelsme,labeleme=startend(dataallme)
labelsma,labelema=startend(dataallma)
labelsmi,labelemi=startend(dataallmi)

# %%
motherr=np.r_[ind(t1[:,3],xlabel1,1),ind(t2[:,3],xlabel2,2),ind(t3[:,3],xlabel3,3),ind(t4[:,3],xlabel4,4),ind(t5[:,3],xlabel5,5),ind(t6[:,3],xlabel6,6)]
motherma=np.r_[ind(t1[:,4],xlabel1,1),ind(t2[:,4],xlabel2,2),ind(t3[:,4],xlabel3,3),ind(t4[:,4],xlabel4,4),ind(t5[:,4],xlabel5,5),ind(t6[:,4],xlabel6,6)]
mothermi=np.r_[ind(t1[:,5],xlabel1,1),ind(t2[:,5],xlabel2,2),ind(t3[:,5],xlabel3,3),ind(t4[:,5],xlabel4,4),ind(t5[:,5],xlabel5,5),ind(t6[:,5],xlabel6,6)]
motherme=np.r_[ind(t1[:,6],xlabel1,1),ind(t2[:,6],xlabel2,2),ind(t3[:,6],xlabel3,3),ind(t4[:,6],xlabel4,4),ind(t5[:,6],xlabel5,5),ind(t6[:,6],xlabel6,6)]

# %%
infantr=np.r_[ind(tc1[:,3],xlabel1,1),ind(tc2[:,3],xlabel2,2),ind(tc3[:,3],xlabel3,3),ind(tc4[:,3],xlabel4,4),ind(tc5[:,3],xlabel5,5),ind(tc6[:,3],xlabel6,6)]
infantma=np.r_[ind(tc1[:,4],xlabel1,1),ind(tc2[:,4],xlabel2,2),ind(tc3[:,4],xlabel3,3),ind(tc4[:,4],xlabel4,4),ind(tc5[:,4],xlabel5,5),ind(tc6[:,4],xlabel6,6)]
infantmi=np.r_[ind(tc1[:,5],xlabel1,1),ind(tc2[:,5],xlabel2,2),ind(tc3[:,5],xlabel3,3),ind(tc4[:,5],xlabel4,4),ind(tc5[:,5],xlabel5,5),ind(tc6[:,5],xlabel6,6)]
infantme=np.r_[ind(tc1[:,6],xlabel1,1),ind(tc2[:,6],xlabel2,2),ind(tc3[:,6],xlabel3,3),ind(tc4[:,6],xlabel4,4),ind(tc5[:,6],xlabel5,5),ind(tc6[:,6],xlabel6,6)]

# %%
motherrre=remove16(motherr)
mothermare=remove16(motherma)
mothermire=remove16(mothermi)
mothermere=remove16(motherme)

# %%
infantrre=remove16(infantr)
infantmare=remove16(infantma)
infantmire=remove16(infantmi)
infantmere=remove16(infantme)

# %%
plt.plot(mothermere[:,0],c='b')
plt.plot(infantmere[:,0],c='r')
plt.ylim(100,700)
plt.show()

# %%
def stdc(datain,labelsin,labelein):
    stdout=[]
    for i in range(len(labelsin)):
        stdout.append(np.std(datain[labelsin[i]:labelein[i]+1,0]))
    return stdout

# %%
def meanc(datain,labelsin,labelein):
    meanout=[]
    for i in range(len(labelsin)):
        meanout.append(np.mean(datain[labelsin[i]:labelein[i]+1,0]))
    return meanout

# %%
mstdmere=stdc(mothermere,labelsmere,labelemere)
mstdmare=stdc(mothermare,labelsmare,labelemare)
mstdmire=stdc(mothermire,labelsmire,labelemire)
mstdrre=stdc(motherrre,labelsrre,labelerre)

# %%
mmeanmere=meanc(mothermere,labelsmere,labelemere)
mmeanmare=meanc(mothermare,labelsmare,labelemare)
mmeanmire=meanc(mothermire,labelsmire,labelemire)
mmeanrre=meanc(motherrre,labelsrre,labelerre)

# %%
cstdmere=stdc(infantmere,labelsmere,labelemere)
cstdmare=stdc(infantmare,labelsmare,labelemare)
cstdmire=stdc(infantmire,labelsmire,labelemire)
cstdrre=stdc(infantrre,labelsrre,labelerre)

# %%
cmeanmere=meanc(infantmere,labelsmere,labelemere)
cmeanmare=meanc(infantmare,labelsmare,labelemare)
cmeanmire=meanc(infantmire,labelsmire,labelemire)
cmeanrre=meanc(infantrre,labelsrre,labelerre)

# %%
mstdme=stdc(motherme,labelsme,labeleme)
mstdma=stdc(motherma,labelsma,labelema)
mstdmi=stdc(mothermi,labelsmi,labelemi)
mstdr=stdc(motherr,labelsr,labeler)

# %%
cstdme=stdc(infantme,labelsme,labeleme)
cstdma=stdc(infantma,labelsma,labelema)
cstdmi=stdc(infantmi,labelsmi,labelemi)
cstdr=stdc(infantr,labelsr,labeler)

# %%
mstdmerep=pd.DataFrame(mstdmere)
mstdmerep.columns=['STD']
mstdmarep=pd.DataFrame(mstdmare)
mstdmarep.columns=['STD']
mstdmirep=pd.DataFrame(mstdmire)
mstdmirep.columns=['STD']
mstdrrep=pd.DataFrame(mstdrre)
mstdrrep.columns=['STD']

# %%
mmeanmerep=pd.DataFrame(mmeanmere)
mmeanmerep.columns=['MEAN']
mmeanmarep=pd.DataFrame(mmeanmare)
mmeanmarep.columns=['MEAN']
mmeanmirep=pd.DataFrame(mmeanmire)
mmeanmirep.columns=['MEAN']
mmeanrrep=pd.DataFrame(mmeanrre)
mmeanrrep.columns=['MEAN']

# %%
cstdmerep=pd.DataFrame(cstdmere)
cstdmerep.columns=['STD']
cstdmarep=pd.DataFrame(cstdmare)
cstdmarep.columns=['STD']
cstdmirep=pd.DataFrame(cstdmire)
cstdmirep.columns=['STD']
cstdrrep=pd.DataFrame(cstdrre)
cstdrrep.columns=['STD']

# %%
cmeanmerep=pd.DataFrame(cmeanmere)
cmeanmerep.columns=['MEAN']
cmeanmarep=pd.DataFrame(cmeanmare)
cmeanmarep.columns=['MEAN']
cmeanmirep=pd.DataFrame(cmeanmire)
cmeanmirep.columns=['MEAN']
cmeanrrep=pd.DataFrame(cmeanrre)
cmeanrrep.columns=['MEAN']

# %%
mstdmep=pd.DataFrame(mstdme)
mstdmep.columns=['STD']
mstdmap=pd.DataFrame(mstdma)
mstdmap.columns=['STD']
mstdmip=pd.DataFrame(mstdmi)
mstdmip.columns=['STD']
mstdrp=pd.DataFrame(mstdr)
mstdrp.columns=['STD']

# %%
cstdmep=pd.DataFrame(cstdme)
cstdmep.columns=['STD']
cstdmap=pd.DataFrame(cstdma)
cstdmap.columns=['STD']
cstdmip=pd.DataFrame(cstdmi)
cstdmip.columns=['STD']
cstdrp=pd.DataFrame(cstdr)
cstdrp.columns=['STD']

# %%
#mmeanmerep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmemean.csv')
#mmeanmarep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmamean.csv')
#mmeanmirep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmimean.csv')
#mmeanrrep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mrmean.csv')

# %%
#cmeanmerep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmemean.csv')
#cmeanmarep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmamean.csv')
#cmeanmirep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmimean.csv')
#cmeanrrep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\crmean.csv')

# %%
#mstdmerep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmestd.csv')
#mstdmarep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmastd.csv')
#mstdmirep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mmistd.csv')
#mstdrrep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\mrstd.csv')

# %%
#cstdmerep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmestd.csv')
#cstdmarep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmastd.csv')
#cstdmirep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\cmistd.csv')
#cstdrrep.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\crstd.csv')

# %%
#mstdmep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16menew.csv')
#mstdmap.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16minew.csv')
#mstdmip.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16manew.csv')
#mstdrp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishmstd16rnew.csv')

# %%
#cstdmerep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12menew.csv')
#cstdmarep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12minew.csv')
#cstdmirep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12manew.csv')
#cstdrrep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd12rnew.csv')

# %%
#cstdmep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16menew.csv')
#cstdmap.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16minew.csv')
#cstdmip.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16manew.csv')
#cstdrp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishcstd16rnew.csv')

# %%
def plotall(datain,labelsin,labelein):
    fig=plt.figure(figsize=(20,10))
    num_rows = len(labelsin)//5+(len(labelsin)%5>0)
    for i in range(len(labelsin)):
        plt.subplot(num_rows,5,i+1)
        xlabelp=np.arange(datain[labelein[i],1])+1
        plt.scatter(xlabelp,datain[labelsin[i]:labelein[i]+1,0])
        #plt.axis('off')
    plt.subplots_adjust(wspace=0.1)
    #fig.savefig(namein,dpi=300)
    #plt.tight_layout()
    plt.show()

# %%
plotall(dataallmere,labelsmere,labelemere)

# %%
def sep(datain,labelsin, labelein):
    data2=[]
    data3=[]
    data4=[]
    data5=[]
    data6=[]
    data7=[]
    data8=[]
    data9=[]
    data10=[]
    data11=[]
    data12=[]
    lenin=labelein-labelsin+1
    for i in range(len(lenin)):
        if lenin[i]==2:
            data2.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==3:
            data3.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==4:
            data4.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==5:
            data5.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==6:
            data6.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==7:
            data7.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==8:
            data8.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==9:
            data9.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==10:
            data10.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==11:
            data11.append(datain[labelsin[i]:labelein[i]+1])
        if lenin[i]==12:
            data12.append(datain[labelsin[i]:labelein[i]+1])
    print('2=',len(data2),'3=',len(data3),'4=',len(data4),'5=',len(data5),'6=',len(data6),'7=',len(data7),'8=',len(data8)
         ,'9=',len(data9),'10=',len(data10),'11=',len(data11),'12=',len(data12))
    return data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12

# %%
data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere=sep(dataallmere,labelsmere, labelemere)
data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare=sep(dataallmare,labelsmare, labelemare)
data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire=sep(dataallmire,labelsmire, labelemire)
data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre=sep(dataallrre,labelsrre, labelerre)
# Out:
# 2= 17 3= 7 4= 5 5= 3 6= 4 7= 1 8= 2 9= 2 10= 0 11= 1 12= 2
# 2= 17 3= 7 4= 5 5= 3 6= 4 7= 1 8= 2 9= 2 10= 0 11= 1 12= 2
# 2= 17 3= 7 4= 5 5= 3 6= 4 7= 1 8= 2 9= 2 10= 0 11= 1 12= 2
# 2= 17 3= 7 4= 5 5= 3 6= 4 7= 1 8= 2 9= 2 10= 0 11= 1 12= 2

# %%
from matplotlib.pyplot import cm

# %%
def plotsep(data2in,data3in,data4in,data5in,data6in,data7in,data8in,data9in,data10in,data11in,data12in):
    color = iter(cm.rainbow(np.linspace(0, 1, len(data2in))))
    for i in range(len(data2in)):
        
        dataplot=data2in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data3in))))
    for i in range(len(data3in)):
        dataplot=data3in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data4in))))
    for i in range(len(data4in)):
        dataplot=data4in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data5in))))
    for i in range(len(data5in)):
        dataplot=data5in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data6in))))
    for i in range(len(data6in)):
        dataplot=data6in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data7in)+len(data8in))))
    for i in range(len(data7in)):
        dataplot=data7in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data8in))))    
    for i in range(len(data8in)):
        dataplot=data8in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()
    color = iter(cm.rainbow(np.linspace(0, 1, len(data9in)+len(data11in)+len(data12in))))     
    for i in range(len(data9in)):
        dataplot=data9in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data10in))))    
    #for i in range(len(data10in)):
        #dataplot=data10in[i]
        #plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    #plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data11in)+1)))   
    for i in range(len(data11in)):
        dataplot=data11in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
   # plt.show()
    #color = iter(cm.rainbow(np.linspace(0, 1, len(data12in))))  
    for i in range(len(data12in)):
        dataplot=data12in[i]
        plt.plot(dataplot[:,1],dataplot[:,0],'*-',c=next(color))
    plt.show()

# %%
plotsep(data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere)

# %%
plotsep(data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare)

# %%
plotsep(data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire)

# %%
plotsep(data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre)

# %%
print(np.mean(dataallrf[:,0]),np.mean(dataallmaf[:,0]),np.mean(dataallmif[:,0]),np.mean(dataallmef[:,0]))
# Out:
# -82.25535857042918 -132.29014228088954 -87.65219282871094 -103.54361807163849

# %%
dataallmep=pd.DataFrame(dataallme)
dataallmep.columns=['DV','IV','type']
dataallmap=pd.DataFrame(dataallma)
dataallmap.columns=['DV','IV','type']
dataallmip=pd.DataFrame(dataallmi)
dataallmip.columns=['DV','IV','type']
dataallrp=pd.DataFrame(dataallr)
dataallrp.columns=['DV','IV','type']

# %%
dataallmepre=pd.DataFrame(dataallmere)
dataallmepre.columns=['DV','IV','type']
dataallmapre=pd.DataFrame(dataallmare)
dataallmapre.columns=['DV','IV','type']
dataallmipre=pd.DataFrame(dataallmire)
dataallmipre.columns=['DV','IV','type']
dataallrpre=pd.DataFrame(dataallrre)
dataallrpre.columns=['DV','IV','type']

# %%
#dataallmepre.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\conme.csv')
#dataallmipre.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\conmi.csv')
#dataallmapre.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\conma.csv')
#dataallrpre.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\conr.csv')

# %%
#dataallmep.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock16menew.csv')
#dataallmip.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock16minew.csv')
#dataallmap.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock16manew.csv')
#dataallrp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock16rnew.csv')

# %%
#dataallmepre.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12menew.csv')
#dataallmipre.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12minew.csv')
#dataallmapre.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12manew.csv')
#dataallrpre.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Englishblock12rnew.csv')

# %%
print('cofft of f0_range=',stats.pearsonr(dataallrp['IV'],dataallrp['DV']))
print('cofft of f0_max=',stats.pearsonr(dataallmap['IV'],dataallmap['DV']))
print('cofft of f0_min=',stats.pearsonr(dataallmip['IV'],dataallmip['DV']))
print('cofft of f0_mean=',stats.pearsonr(dataallmep['IV'],dataallmep['DV']))
# Out:
# cofft of f0_range= PearsonRResult(statistic=-0.05155048954032508, pvalue=0.46180618004114316)
# cofft of f0_max= PearsonRResult(statistic=0.029308109670235876, pvalue=0.6758149932841233)
# cofft of f0_min= PearsonRResult(statistic=0.07206378446168012, pvalue=0.3033128333995817)
# cofft of f0_mean= PearsonRResult(statistic=0.0738885369499144, pvalue=0.2912011005336522)

# %%
print('cofft of f0_rangere=',stats.pearsonr(dataallrpre['IV'],dataallrpre['DV']))
print('cofft of f0_maxre=',stats.pearsonr(dataallmapre['IV'],dataallmapre['DV']))
print('cofft of f0_minre=',stats.pearsonr(dataallmipre['IV'],dataallmipre['DV']))
print('cofft of f0_meanre=',stats.pearsonr(dataallmepre['IV'],dataallmepre['DV']))
# Out:
# cofft of f0_rangere= PearsonRResult(statistic=-0.07308869191371588, pvalue=0.31627068898792554)
# cofft of f0_maxre= PearsonRResult(statistic=0.0649051225267941, pvalue=0.3736322913312226)
# cofft of f0_minre= PearsonRResult(statistic=0.1128428610404236, pvalue=0.1211121077414905)
# cofft of f0_meanre= PearsonRResult(statistic=0.13016401954627121, pvalue=0.07345868218392408)

# %%
print(np.mean(dataallrp['DV']),np.mean(dataallmap['DV']),np.mean(dataallmip['DV']),np.mean(dataallmep['DV']))
# Out:
# -82.001031861069 -112.83576576411265 -83.27092916220425 -88.71592822083458

# %%
print(np.mean(dataallrpre['DV']),np.mean(dataallmapre['DV']),np.mean(dataallmipre['DV']),np.mean(dataallmepre['DV']))
# Out:
# -82.37339448680032 -110.50640200622001 -80.37463467815547 -85.40931749707829

# %%
plt.scatter(dataallmep['IV'],dataallmep['DV'])

# %%
plt.scatter(dataallmepre['IV'],dataallmepre['DV'])

# %%
from scipy.optimize import curve_fit

# %%
# Define different types of functions to fit
def linear_func(x, a, b):
    return a * x + b

def quadratic_func(x, a, b, c):
    return a * x**2 + b * x + c

def cubic_func(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

def four_func(x, a, b, c, d,e):
    return a * x**4 + b * x**3 + c * x**2 + d*x+e

def five_func(x, a, b,c,d,e,f):
    return a * x**5 + b * x**4 + c * x**3 + d*x**2+e*x+f

def six_func(x, a, b,c,d,e,f,g):
    return a * x**6 + b * x**5 + c * x**4 + d * x**3 + e * x**2 + f * x + g
def seven_func(x, a, b,c,d,e,f,g,h,i):
    return a * x**8 + b * x**7 + c * x**6 + d * x**5 + e * x**4 + f * x**3 + g*x**2+h*x+i
#def sigmoid_func(x, L, k, x0):
    #return a * x**3 + b * x**2 + c * x + d

#def gaussian_func(x, a, x0, sigma):
    #return return a * x**3 + b * x**2 + c * x + d

# %%
# Curve fitting for each function
functions = [linear_func, quadratic_func, cubic_func, four_func,
             five_func]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def calculate_bic(y_true, y_pred, n, k): #Bayesian Information Criterion
    mse = mean_squared_error(y_true, y_pred)
    bic = n * np.log(mse) + k * np.log(n)
    return bic

# %%
def outputfit(functionsin,xin,yin):
    r2_values=[]
    fit_results=[]
    iii=2
    for func in functionsin:
        popt, _ = curve_fit(func, xin, yin)
        fit_results.append(popt)
        y_fit = func(xin, *popt)
        r2_values.append(calculate_bic(yin, y_fit, len(yin), iii))
        iii=iii+1
    return r2_values,fit_results

# %%
def fittingsep(datain2,datain3,datain4,datain5,datain6,datain7,datain8,datain9,datain10,datain11,datain12):
    rout2,fit2=outputfit(functions,np.array(datain2).reshape(2*len(datain2),3)[:,1],np.array(datain2).reshape(2*len(datain2),3)[:,0])
    print('re2=',rout2)
    rout3,fit3=outputfit(functions,np.array(datain3).reshape(3*len(datain3),3)[:,1],np.array(datain3).reshape(3*len(datain3),3)[:,0])
    print('re3=',rout3)
    rout4,fit4=outputfit(functions,np.array(datain4).reshape(4*len(datain4),3)[:,1],np.array(datain4).reshape(4*len(datain4),3)[:,0])
    print('re4=',rout2)
    rout5,fit5=outputfit(functions,np.array(datain5).reshape(5*len(datain5),3)[:,1],np.array(datain5).reshape(5*len(datain5),3)[:,0])
    print('re5=',rout5)
    rout6,fit6=outputfit(functions,np.array(datain6).reshape(6*len(datain6),3)[:,1],np.array(datain6).reshape(6*len(datain6),3)[:,0])
    print('re6=',rout6)
    datain78=np.r_[np.array(datain7).reshape(7*len(datain7),3),np.array(datain8).reshape(8*len(datain8),3)]
    rout7,fit7=outputfit(functions,datain78[:,1],datain78[:,0])
    print('re7=',rout7)
    rout8,fit8=outputfit(functions,np.array(datain8).reshape(8*len(datain8),3)[:,1],np.array(datain8).reshape(8*len(datain8),3)[:,0])
    print('re8=',rout8)
    datain912=np.r_[np.array(datain9).reshape(9*len(datain9),3),np.array(datain11).reshape(11*len(datain11),3),np.array(datain12).reshape(12*len(datain12),3)]
    rout9,fit9=outputfit(functions,datain912[:,1],datain912[:,0])
    print('re9=',rout9)
    #rout10,fit10=outputfit(functions,np.array(datain10).reshape(10*len(datain10),3)[:,1],np.array(datain10).reshape(10*len(datain10),3)[:,0])
    #print('re10=',rout10)
    rout11,fit11=outputfit(functions,np.array(datain11).reshape(11*len(datain11),3)[:,1],np.array(datain11).reshape(11*len(datain11),3)[:,0])
    print('re11=',rout11)
    rout12,fit12=outputfit(functions,np.array(datain12).reshape(12*len(datain12),3)[:,1],np.array(datain12).reshape(12*len(datain12),3)[:,0])
    print('re12=',rout12)
    return rout2,rout3,rout4,rout5,rout6,rout7,rout8,rout9,rout11,rout12,fit2,fit3,fit4,fit5,fit6,fit7,fit8,fit9,fit11,fit12

# %%
routme2,routme3,routme4,routme5,routme6,routme7,routme8,routme9,routme11,routme12,fitme2,fitme3,fitme4,fitme5,fitme6,fitme7,fitme8,fitme9,fitme11,fitme12=fittingsep(data2mere,data3mere,data4mere,data5mere,data6mere,data7mere,data8mere,data9mere,data10mere,data11mere,data12mere)
# Out:
# re2= [296.89321347532365, 300.4195739999398, 303.945934524556, 307.47229504917215, 310.99865557378826]
# re3= [200.7699121281803, 202.84909849736687, 205.8936209350903, 208.93814337281373, 211.98266581053716]
# re4= [296.89321347532365, 300.4195739999398, 303.945934524556, 307.47229504917215, 310.99865557378826]
# re5= [109.86290827332606, 105.57816340107686, 107.87417888742709, 109.71694553138899, 112.4249957324912]
# re6= [196.09528610616943, 198.73318222288265, 200.1218211321068, 201.56902345649237, 202.57097108062666]
# re7= [181.98350367332324, 184.83007172587537, 186.2468858657428, 187.3482905340954, 190.45162792452572]
# re8= [129.7857157129801, 131.4168658992726, 129.65157705732713, 128.18191222198806, 130.9541328312153]
# re9= [411.3757914829281, 410.15016757697646, 413.88355786006855, 417.74383382858014, 420.9951088037843]
# re11= [67.45136077117233, 65.29690892101621, 65.59074747278052, 66.86461348686522, 67.99900805798873]
# ...

# %%
routma2,routma3,routma4,routma5,routma6,routma7,routma8,routma9,routma11,routma12,fitma2,fitma3,fitma4,fitma5,fitma6,fitma7,fitma8,fitma9,fitma11,fitma12=fittingsep(data2mare,data3mare,data4mare,data5mare,data6mare,data7mare,data8mare,data9mare,data10mare,data11mare,data12mare)
# Out:
# re2= [319.71469792830095, 323.2410584529171, 326.7674189775333, 330.29377950214945, 333.82014002676556]
# re3= [224.47482913869595, 226.76742190630034, 229.81194434402383, 232.8564667817472, 235.9009892194707]
# re4= [319.71469792830095, 323.2410584529171, 326.7674189775333, 330.29377950214945, 333.82014002676556]
# re5= [118.8586189207996, 120.82468092073694, 123.46202674783439, 125.66886909438746, 128.37691929548967]
# re6= [207.1070224288401, 210.28319977092647, 212.36440356961432, 212.62044552614515, 215.68629912644033]
# re7= [192.2236473723733, 195.3271651412717, 197.58983589546622, 196.95651623740517, 199.68516486459123]
# re8= [134.63678217474015, 137.27237709597134, 140.03900665188786, 139.9797424503039, 142.49415361192507]
# re9= [458.3372627523824, 460.2730438212576, 464.2089110831284, 468.1789785481898, 472.03847073753633]
# re11= [79.95938586776441, 81.70218747189232, 82.30097405039729, 83.52008164081982, 85.00986806130686]
# ...

# %%
routmi2,routmi3,routmi4,routmi5,routmi6,routmi7,routmi8,routmi9,routmi11,routmi12,fitmi2,fitmi3,fitmi4,fitmi5,fitmi6,fitmi7,fitmi8,fitmi9,fitmi11,fitmi12=fittingsep(data2mire,data3mire,data4mire,data5mire,data6mire,data7mire,data8mire,data9mire,data10mire,data11mire,data12mire)
# Out:
# re2= [293.72926697181657, 297.25562749643274, 300.7819880210489, 304.30834854566507, 307.8347090702812]
# re3= [186.46162134088576, 188.96625878628345, 192.01078122400688, 195.0553036617303, 198.09982609945374]
# re4= [293.72926697181657, 297.25562749643274, 300.7819880210489, 304.30834854566507, 307.8347090702812]
# re5= [104.72953084536671, 106.84330769218627, 108.03053283251691, 109.53723528983625, 112.24528549093847]
# re6= [208.01648227893824, 211.1918250987344, 211.75658209829294, 214.9324802917906, 217.76137127153876]
# re7= [185.7835732300117, 188.8580824566258, 190.59630684583826, 191.66991055519438, 194.04736569809927]
# re8= [131.6320295183619, 134.4046135255235, 132.84974337718074, 132.39349414160444, 132.2704904949884]
# re9= [358.14547523507207, 354.4626893768039, 356.50629531613635, 360.15959745047587, 363.99420061161777]
# re11= [72.8705729627612, 59.776833865145534, 61.69244552104412, 46.23555319474138, 46.338453106244714]
# ...

# %%
routr2,routr3,routr4,routr5,routr6,routr7,routr8,routr9,routr11,routr12,fitr2,fitr3,fitr4,fitr5,fitr6,fitr7,fitr8,fitr9,fitr11,fitr12=fittingsep(data2rre,data3rre,data4rre,data5rre,data6rre,data7rre,data8rre,data9rre,data10rre,data11rre,data12rre)
# Out:
# re2= [285.440455519148, 288.96681604376414, 292.4931765683803, 296.0195370929965, 299.5458976176126]
# re3= [200.24307632668965, 202.9395911399315, 205.98411357765494, 209.02863601537837, 212.0731584531018]
# re4= [285.440455519148, 288.96681604376414, 292.4931765683803, 296.0195370929965, 299.5458976176126]
# re5= [138.44732801822596, 137.8822040101954, 140.3870462264084, 142.87596394018485, 145.58401414128707]
# re6= [203.1207151674951, 206.0143595737149, 205.38760775742315, 208.21344251740524, 211.3758783572706]
# re7= [194.11807436507365, 195.34740556885492, 198.40552461435234, 199.73750989528114, 202.780087767101]
# re8= [139.35480270154062, 140.96224498548654, 143.7209135810183, 145.7708916040757, 148.3808973282786]
# re9= [459.78232987781337, 463.52793249843205, 466.4140962278521, 470.1229779492765, 472.8354408472222]
# re11= [68.57710573593772, 65.9210203480409, 68.18314560500272, 68.58280433403957, 69.58885433392304]
# ...

# %%
plt.scatter(np.array(data2mere).reshape(2*len(data2mere),3)[:,1],np.array(data2mere).reshape(2*len(data2mere),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mere).reshape(3*len(data3mere),3)[:,1],np.array(data3mere).reshape(3*len(data3mere),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mere).reshape(4*len(data4mere),3)[:,1],np.array(data4mere).reshape(4*len(data4mere),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mere).reshape(5*len(data5mere),3)[:,1],np.array(data5mere).reshape(5*len(data5mere),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routme5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

plt.scatter(np.array(data6mere).reshape(6*len(data6mere),3)[:,1],np.array(data6mere).reshape(6*len(data6mere),3)[:,0], label='Data')
xplotin=np.arange(6)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
data78me=np.r_[np.array(data7mere).reshape(7*len(data7mere),3),np.array(data8mere).reshape(8*len(data8mere),3)]
plt.scatter(data78me[:,1],data78me[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routme7[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme7[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data912me=np.r_[np.array(data9mere).reshape(9*len(data9mere),3),np.array(data11mere).reshape(11*len(data11mere),3),np.array(data12mere).reshape(12*len(data12mere),3)]
plt.scatter(data912me[:,1],data912me[:,0], label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routme9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitme9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2mare).reshape(2*len(data2mare),3)[:,1],np.array(data2mare).reshape(2*len(data2mare),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mare).reshape(3*len(data3mare),3)[:,1],np.array(data3mare).reshape(3*len(data3mare),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mare).reshape(4*len(data4mare),3)[:,1],np.array(data4mare).reshape(4*len(data4mare),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mare).reshape(5*len(data5mare),3)[:,1],np.array(data5mare).reshape(5*len(data5mare),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

plt.scatter(np.array(data6mare).reshape(6*len(data6mare),3)[:,1],np.array(data6mare).reshape(6*len(data6mare),3)[:,0], label='Data')
xplotin=np.arange(6)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
data78ma=np.r_[np.array(data7mare).reshape(7*len(data7mare),3),np.array(data8mare).reshape(8*len(data8mare),3)]
plt.scatter(data78ma[:,1],data78ma[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routma7[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma7[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data912ma=np.r_[np.array(data9mare).reshape(9*len(data9mare),3),np.array(data11mare).reshape(11*len(data11mare),3),np.array(data12mare).reshape(12*len(data12mare),3)]
plt.scatter(data912ma[:,1],data912ma[:,0], label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routma9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitma9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2mire).reshape(2*len(data2mire),3)[:,1],np.array(data2mire).reshape(2*len(data2mire),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3mire).reshape(3*len(data3mire),3)[:,1],np.array(data3mire).reshape(3*len(data3mire),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4mire).reshape(4*len(data4mire),3)[:,1],np.array(data4mire).reshape(4*len(data4mire),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5mire).reshape(5*len(data5mire),3)[:,1],np.array(data5mire).reshape(5*len(data5mire),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

plt.scatter(np.array(data6mire).reshape(6*len(data6mire),3)[:,1],np.array(data6mire).reshape(6*len(data6mire),3)[:,0], label='Data')
xplotin=np.arange(6)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
data78mi=np.r_[np.array(data7mire).reshape(7*len(data7mire),3),np.array(data8mire).reshape(8*len(data8mire),3)]
plt.scatter(data78mi[:,1],data78mi[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routmi7[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi7[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data912mi=np.r_[np.array(data9mire).reshape(9*len(data9mire),3),np.array(data11mire).reshape(11*len(data11mire),3),np.array(data12mire).reshape(12*len(data12mire),3)]
plt.scatter(data912mi[:,1],data912mi[:,0], label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routmi9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitmi9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
plt.scatter(np.array(data2rre).reshape(2*len(data2rre),3)[:,1],np.array(data2rre).reshape(2*len(data2rre),3)[:,0], label='Data')
xplotin=np.arange(2)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr2[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr2[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data3rre).reshape(3*len(data3rre),3)[:,1],np.array(data3rre).reshape(3*len(data3rre),3)[:,0], label='Data')
xplotin=np.arange(3)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr3[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr3[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data4rre).reshape(4*len(data4rre),3)[:,1],np.array(data4rre).reshape(4*len(data4rre),3)[:,0], label='Data')
xplotin=np.arange(4)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr4[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr4[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
plt.scatter(np.array(data5rre).reshape(5*len(data5rre),3)[:,1],np.array(data5rre).reshape(5*len(data5rre),3)[:,0], label='Data')
xplotin=np.arange(5)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={routr5[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr5[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

plt.scatter(np.array(data6rre).reshape(6*len(data6rre),3)[:,1],np.array(data6rre).reshape(6*len(data6rre),3)[:,0], label='Data')
xplotin=np.arange(6)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr6[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr6[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()
data78r=np.r_[np.array(data7rre).reshape(7*len(data7rre),3),np.array(data8rre).reshape(8*len(data8rre),3)]
plt.scatter(data78r[:,1],data78r[:,0], label='Data')
xplotin=np.arange(8)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr7[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr7[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

data912r=np.r_[np.array(data9rre).reshape(9*len(data9rre),3),np.array(data11rre).reshape(11*len(data11rre),3),np.array(data12rre).reshape(12*len(data12rre),3)]
plt.scatter(data912r[:,1],data912r[:,0], label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={routr9[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fitr9[i]), label=label)
#plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
fit_resultsme = []
r2_valuesme = []
r2_valuesmer = []
xin=dataallmep['IV']
yin=dataallmep['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsme.append(popt)
    y_fit = func(xin, *popt)
    #r2_valuesmer.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesme.append(mean_absolute_error(yin, y_fit))
    r2_valuesme.append(calculate_bic(yin, y_fit, len(yin), iii))
    iii=iii+1
print(r2_valuesme)
#print(r2_valuesmer,r2_valuesme,(np.array(r2_valuesmer)+np.array(r2_valuesme))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1767.8322788898656, 1762.741970719471, 1768.0425578735992, 1771.5226248283393, 1776.8223365596007]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(16)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={r2_valuesme[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsme[i]), label=label)
plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
fit_resultsmere = []
r2_valuesmere = []
r2_valuesmerre = []
xin=dataallmepre['IV']
yin=dataallmepre['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsmere.append(popt)
    y_fit = func(xin, *popt)
    #r2_valuesmer.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesme.append(mean_absolute_error(yin, y_fit))
    r2_valuesmere.append(calculate_bic(yin, y_fit, len(yin), iii))
    iii=iii+1
print(r2_valuesmere)
# Out:
# [1628.9884870191313, 1628.6762592191224, 1632.7914836189473, 1637.7672384777907, 1642.9927017729349]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={r2_valuesmere[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsmere[i]), label=label)
plt.ylim(-450,10)
plt.xlabel('x')
plt.ylabel('y')
plt.xlabel('number of turns')
plt.ylabel('similarity of mean pitch')
#plt.legend()
plt.show()

# %%
fit_resultsma = []
r2_valuesma = []
r2_valuesmar = []
xin=dataallmap['IV']
yin=dataallmap['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsma.append(popt)
    y_fit = func(xin, *popt)
    #r2_valuesma.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmar.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesma.append(mean_absolute_error(yin, y_fit))
    r2_valuesma.append(calculate_bic(yin, y_fit, len(yin), iii))
    iii=iii+1
print(r2_valuesma)
#print(r2_valuesmar,r2_valuesma,(np.array(r2_valuesmar)+np.array(r2_valuesma))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1928.9300999043048, 1926.1810434400743, 1930.2623879688222, 1934.106991434169, 1938.8166328180982]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(16)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={r2_valuesma[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsma[i]), label=label)

plt.ylim(-750,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of max pitch')
#plt.legend()
plt.show()

# %%
fit_resultsmare = []
r2_valuesmare = []
r2_valuesmarre = []
xin=dataallmapre['IV']
yin=dataallmapre['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsmare.append(popt)
    y_fit = func(xin, *popt)
    #r2_valuesma.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmar.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesma.append(mean_absolute_error(yin, y_fit))
    r2_valuesmare.append(calculate_bic(yin, y_fit, len(yin), iii))
    iii=iii+1
print(r2_valuesmare)
#print(r2_valuesmar,r2_valuesma,(np.array(r2_valuesmar)+np.array(r2_valuesma))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1784.6144213266136, 1783.8866624204243, 1788.9826732602528, 1793.6943709219877, 1798.6103943562957]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==1:
        label = func.__name__ + f' (R-squared={r2_valuesmare[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsmare[i]), label=label)

plt.ylim(-750,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of max pitch')
#plt.legend()
plt.show()

# %%
fit_resultsmi = []
r2_valuesmi = []
r2_valuesmir = []
xin=dataallmip['IV']
yin=dataallmip['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsmi.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesmi.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesmi.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmir.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesmi.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesmi)
#print(r2_valuesmir,r2_valuesmi,(np.array(r2_valuesmir)+np.array(r2_valuesmi))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1710.550946078467, 1712.7084930294457, 1717.587829865908, 1721.9278366444357, 1727.04454066285]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(16)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesmi[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsmi[i]), label=label)

plt.ylim(-420,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
fit_resultsmire = []
r2_valuesmire = []
r2_valuesmirre = []
xin=dataallmipre['IV']
yin=dataallmipre['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsmire.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesmire.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesmi.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesmir.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesmi.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesmire)
#print(r2_valuesmir,r2_valuesmi,(np.array(r2_valuesmir)+np.array(r2_valuesmi))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1576.2632642138942, 1581.068851371289, 1585.1537345123386, 1589.777785565753, 1595.0192553720622]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesmi[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsmire[i]), label=label)

plt.ylim(-420,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
fit_resultsr = []
r2_valuesr = []
r2_valuesrr = []
xin=dataallrp['IV']
yin=dataallrp['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsr.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesr.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesr.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesrr.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesr.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesr)
#print(r2_valuesrr,r2_valuesr,(np.array(r2_valuesrr)+np.array(r2_valuesr))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1791.9058640307221, 1797.1583925679213, 1797.9228069063781, 1803.247057235819, 1806.1810039284778]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(16)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesr[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsr[i]), label=label)

plt.ylim(-700,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
fit_resultsrre = []
r2_valuesrre = []
r2_valuesrrre = []
xin=dataallrpre['IV']
yin=dataallrpre['DV']
iii=2
for func in functions:
    popt, _ = curve_fit(func, xin, yin)
    fit_resultsrre.append(popt)
    y_fit = func(xin, *popt)
    r2_valuesrre.append(calculate_bic(yin, y_fit, len(yin), iii))
    #r2_valuesr.append(1 - np.sum((yin - y_fit)**2) / np.sum((yin - np.mean(yin))**2))
    #r2_valuesrr.append(np.sqrt(mean_squared_error(yin, y_fit)))
    #r2_valuesr.append(mean_absolute_error(yin, y_fit))
    iii=iii+1
print(r2_valuesrre)
#print(r2_valuesrr,r2_valuesr,(np.array(r2_valuesrr)+np.array(r2_valuesr))/2) #linear quadratic cubic exponential logaridatic power sigmoid guassion
# Out:
# [1657.3885911688094, 1660.799615075931, 1665.5148012035147, 1669.8521758577815, 1674.4038127270155]

# %%
plt.scatter(xin, yin, label='Data')
xplotin=np.arange(12)+1
for i, func in enumerate(functions):
    if i==0:
        label = func.__name__ + f' (R-squared={r2_valuesrre[i]:.2f})'
        plt.plot(xplotin, func(xplotin, *fit_resultsrre[i]), label=label)

plt.ylim(-700,10)
plt.xlabel('number of turns')
plt.ylabel('similarity of min pitch')
#plt.legend()
plt.show()

# %%
med=smf.mixedlm("DV~IV",dataallmep,groups=dataallmep['type'])
medf = med.fit(method=['powell'])
print(medf.summary())
# Out:
#           Mixed Linear Model Regression Results
# ...
# Model:             MixedLM Dependent Variable: DV
# No. Observations:  206     Method:             REML
# No. Groups:        6       Scale:              5087.6929
# Min. group size:   11      Log-Likelihood:     -1166.9052
# Max. group size:   108     Converged:          Yes
# Mean group size:   34.3
# ---------------------------------------------------------
#            Coef.  Std.Err.    z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------
# Intercept -94.211    9.033 -10.430 0.000 -111.915 -76.507
# IV          1.769    1.607   1.101 0.271   -1.381   4.920
# Group Var  38.930    1.730
# ...

# %%
med=smf.mixedlm("DV~IV",dataallmepre,groups=dataallmepre['type'])
medf = med.fit(method=['powell'])
print(medf.summary())
print(medf.tvalues['IV'])
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 190     Method:             REML
# No. Groups:       6       Scale:              5059.2518
# Min. group size:  11      Log-Likelihood:     -1074.7016
# Max. group size:  92      Converged:          Yes
# Mean group size:  31.7
# --------------------------------------------------------
#            Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------
# Intercept -98.078   14.791 -6.631 0.000 -127.069 -69.088
# IV          3.519    1.958  1.798 0.072   -0.317   7.356
# Group Var   0.000    5.839
# ...
#
# 1.7977833690286469
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
med=smf.mixedlm("DV~IV",dataallmep,groups=dataallmep['type'],re_formula="~IV")
medf = med.fit(method=['powell'])
print(medf.summary())
# Out:
#             Mixed Linear Model Regression Results
# ...
# Model:              MixedLM   Dependent Variable:   DV
# No. Observations:   206       Method:               REML
# No. Groups:         6         Scale:                4822.0225
# Min. group size:    11        Log-Likelihood:       -1164.1551
# Max. group size:    108       Converged:            Yes
# Mean group size:    34.3
# --------------------------------------------------------------
#                 Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------
# Intercept       -93.625   20.385 -4.593 0.000 -133.580 -53.671
# IV                1.524    5.831  0.261 0.794   -9.904  12.952
# Group Var      1410.850   25.117
# Group x IV Cov -306.330    6.343
# IV Var           67.519    1.724
# ...

# %%
mad=smf.mixedlm("DV~IV",dataallmap,groups=dataallmap['type'])
madf = mad.fit(method=['powell'])
print(madf.summary())
# Out:
#            Mixed Linear Model Regression Results
# ...
# Model:             MixedLM  Dependent Variable:  DV
# No. Observations:  206      Method:              REML
# No. Groups:        6        Scale:               11178.7236
# Min. group size:   11       Log-Likelihood:      -1246.7526
# Max. group size:   108      Converged:           Yes
# Mean group size:   34.3
# -----------------------------------------------------------
#            Coef.   Std.Err.    z    P>|z|  [0.025   0.975]
# -----------------------------------------------------------
# Intercept -116.759    7.172 -16.279 0.000 -130.817 -102.701
# IV           0.986    2.249   0.438 0.661   -3.422    5.393
# Group Var    0.000
# ...
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
mad=smf.mixedlm("DV~IV",dataallmapre,groups=dataallmapre['type'])
madf = mad.fit(method=['powell'])
print(madf.summary())
print(madf.tvalues['IV'])
# Out:
#           Mixed Linear Model Regression Results
# ...
# Model:             MixedLM Dependent Variable: DV
# No. Observations:  190     Method:             REML
# No. Groups:        6       Scale:              11476.5116
# Min. group size:   11      Log-Likelihood:     -1151.6954
# Max. group size:   92      Converged:          Yes
# Mean group size:   31.7
# ---------------------------------------------------------
#            Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# ---------------------------------------------------------
# Intercept -119.960   12.664 -9.472 0.000 -144.782 -95.138
# IV           2.626    2.944  0.892 0.372   -3.144   8.396
# Group Var    0.000
# ...
#
# 0.8919915359210407
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# ...

# %%
mad=smf.mixedlm("DV~IV",dataallmap,groups=dataallmap['type'],re_formula="~IV")
madf = mad.fit(method=['powell'])
print(madf.summary())
# Out:
#             Mixed Linear Model Regression Results
# ...
# Model:              MixedLM   Dependent Variable:   DV
# No. Observations:   206       Method:               REML
# No. Groups:         6         Scale:                10495.6349
# Min. group size:    11        Log-Likelihood:       -1243.5521
# Max. group size:    108       Converged:            Yes
# Mean group size:    34.3
# --------------------------------------------------------------
#                 Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------
# Intercept      -121.174   29.898 -4.053 0.000 -179.773 -62.575
# IV                2.463    9.809  0.251 0.802  -16.763  21.688
# Group Var      3297.487   36.714
# Group x IV Cov -861.562   10.427
# IV Var          225.108    3.332
# ...

# %%
mid=smf.mixedlm("DV~IV",dataallmip,groups=dataallmip['type'])
midf = mid.fit(method=['powell'])
print(midf.summary())
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 206     Method:             REML
# No. Groups:       6       Scale:              3750.3443
# Min. group size:  11      Log-Likelihood:     -1137.3574
# Max. group size:  108     Converged:          Yes
# Mean group size:  34.3
# --------------------------------------------------------
#            Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------
# Intercept -85.293    9.485 -8.992 0.000 -103.884 -66.703
# IV          1.558    1.392  1.119 0.263   -1.170   4.286
# Group Var 200.549    4.120
# ...

# %%
mid=smf.mixedlm("DV~IV",dataallmipre,groups=dataallmipre['type'])
midf = mid.fit(method=['powell'])
print(midf.summary())
print(midf.tvalues['IV'])
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 190     Method:             REML
# No. Groups:       6       Scale:              3760.3389
# Min. group size:  11      Log-Likelihood:     -1048.2148
# Max. group size:  92      Converged:          Yes
# Mean group size:  31.7
# --------------------------------------------------------
#            Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------
# Intercept -87.383    9.326 -9.369 0.000 -105.662 -69.104
# IV          2.511    1.716  1.463 0.143   -0.852   5.875
# Group Var 122.185    3.530
# ...
#
# 1.4634178381957974

# %%
mid=smf.mixedlm("DV~IV",dataallmip,groups=dataallmip['type'],re_formula="~IV")
midf = mid.fit(method=['powell'])
print(midf.summary())
# Out:
#             Mixed Linear Model Regression Results
# ...
# Model:               MixedLM  Dependent Variable:  DV
# No. Observations:    206      Method:              REML
# No. Groups:          6        Scale:               3739.1002
# Min. group size:     11       Log-Likelihood:      -1137.3139
# Max. group size:     108      Converged:           Yes
# Mean group size:     34.3
# -------------------------------------------------------------
#                 Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------
# Intercept      -83.925   11.502 -7.296 0.000 -106.469 -61.380
# IV               1.140    2.078  0.548 0.583   -2.933   5.212
# Group Var      354.383   11.576
# Group x IV Cov -19.702    1.779
# IV Var           1.095    0.134
# ...
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ...

# %%
rd=smf.mixedlm("DV~IV",dataallrp,groups=dataallrp['type'])
rdf = rd.fit(method=['powell'])
print(rdf.summary())
print(rdf.tvalues['IV'])
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 206     Method:             REML
# No. Groups:       6       Scale:              5629.8222
# Min. group size:  11      Log-Likelihood:     -1178.0984
# Max. group size:  108     Converged:          Yes
# Mean group size:  34.3
# --------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# --------------------------------------------------------
# Intercept  -76.784   10.320 -7.440 0.000 -97.011 -56.557
# IV          -1.257    1.698 -0.740 0.459  -4.585   2.071
# Group Var  162.767    2.934
# ...
#
# -0.7400739397490997

# %%
rd=smf.mixedlm("DV~IV",dataallrpre,groups=dataallrpre['type'])
rdf = rd.fit(method=['powell'])
print(rdf.summary())
print(rdf.tvalues['IV'])
# Out:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: DV
# No. Observations: 190     Method:             REML
# No. Groups:       6       Scale:              5762.0253
# Min. group size:  11      Log-Likelihood:     -1088.1175
# Max. group size:  92      Converged:          Yes
# Mean group size:  31.7
# --------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# --------------------------------------------------------
# Intercept  -75.039   10.920 -6.872 0.000 -96.441 -53.637
# IV          -1.877    2.121 -0.885 0.376  -6.033   2.280
# Group Var  149.522    2.853
# ...
#
# -0.8849926197034647

# %%
rd=smf.mixedlm("DV~IV",dataallrp,groups=dataallrp['type'],re_formula="~IV")
rdf = rd.fit(method=['powell'])
print(rdf.summary())
# Out:
#            Mixed Linear Model Regression Results
# ...
# Model:              MixedLM  Dependent Variable:  DV
# No. Observations:   206      Method:              REML
# No. Groups:         6        Scale:               5291.5609
# Min. group size:    11       Log-Likelihood:      -1173.1799
# Max. group size:    108      Converged:           Yes
# Mean group size:    34.3
# ------------------------------------------------------------
#                 Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ------------------------------------------------------------
# Intercept      -75.749    8.894 -8.517 0.000 -93.181 -58.318
# IV              -0.976    3.643 -0.268 0.789  -8.115   6.164
# Group Var        0.041    1.744
# Group x IV Cov  -0.367    0.608
# IV Var          32.155    0.375
# ...
# C:\Users\ljr\anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ...

# %%
mothert=np.r_[t1s,t2,t3,t4,t5,t6]
infantt=np.r_[tc1s,tc2,tc3,tc4,tc5,tc6]

# %%
meanb=np.r_[mdiff1.T,mdiff2.T,mdiff3.T,mdiff4.T,mdiff5.T,mdiff6.T]

# %%
#np.savetxt('meanblocke.txt',meanb)

# %%
#data_d=np.c_[diff[:,1],mothert[:,1],infantt[:,1]]
#data_dp=pd.DataFrame(data_d)
#data_dp.columns=['Diff_d','Mother_d','Infant_d']
#data_dp.to_csv(r'C:\LJR\babylab\English\datamanual\cut\blockdata\Duration.csv')

data_r=np.c_[dataallrre[:,0],mothert[:,3],infantt[:,3]]
data_rp=pd.DataFrame(data_r)
data_rp.columns=['Diff_r','Mother_r','Infant_r']
#data_rp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\Pitchrange.csv')

data_max=np.c_[dataallmare[:,0],mothert[:,4],infantt[:,4]]
data_maxp=pd.DataFrame(data_max)
data_maxp.columns=['Diff_max','Mother_max','Infant_max']
data_maxp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\Pitchmax.csv')

data_min=np.c_[dataallmire[:,0],mothert[:,5],infantt[:,5]]
data_minp=pd.DataFrame(data_min)
data_minp.columns=['Diff_min','Mother_min','Infant_min']
#data_minp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\Pitchmin.csv')

data_mean=np.c_[dataallmere[:,0],mothert[:,6],infantt[:,6]]
data_meanp=pd.DataFrame(data_mean)
data_meanp.columns=['Diff_mean','Mother_mean','Infant_mean']
#data_meanp.to_csv(r'C:\LJR\paper\tseltalvsenglish\dataplot\English\conversation\Pitchmean.csv')

# %%
modrm = """Diff_r~Mother_r+Infant_r
      """
modelrm = Model(modrm)
resrm = modelrm.fit(data_rp)
insrm = modelrm.inspect(std_est=True)
print(resrm,insrm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.026
# Number of iterations: 3
# Params: -0.199 -0.411 2922.151      lval  op      rval     Estimate  Est. Std    Std. Err    z-value  p-value
# 0  Diff_r   ~  Mother_r    -0.199074 -0.208602    0.053537  -3.718471   0.0002
# 1  Diff_r   ~  Infant_r    -0.411230 -0.578211    0.039898 -10.307029   0.0000
# 2  Diff_r  ~~    Diff_r  2922.150614  0.570126  299.806327   9.746794   0.0000

# %%
statsr = semopy.calc_stats(modelrm)
print(statsr)
# Out:
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value    3             5  4.951716      0.175367     157.263092  0.987182
#
#             GFI      AGFI       NFI       TLI    RMSEA       AIC        BIC  \
# Value  0.968513  0.947522  0.968513  0.978637  0.05867  5.947877  15.688949
#
#          LogLik
# Value  0.026062

# %%
from scipy.stats import norm

# %%
coefmr=np.array(insrm.loc[insrm['rval']=='Mother_r','Est. Std'])
coefir=np.array(insrm.loc[insrm['rval']=='Infant_r','Est. Std'])

errmr=np.array(insrm.loc[insrm['rval']=='Mother_r','Std. Err'])
errir=np.array(insrm.loc[insrm['rval']=='Infant_r','Std. Err'])

diff_coefr=coefmr-coefir
diff_errr=(errmr**2+errir**2)**0.5

zr=diff_coefr/diff_errr
pr=2*(1-norm.cdf(abs(zr)))
print(pr)
# Out:
# [3.09990875e-08]

# %%
modrm = """Diff_r~Mother_r+Infant_r
          Mother_r~Infant_r
      """
modelrm = Model(modrm)
resrm = modelrm.fit(data_rp)
insrm = modelrm.inspect(std_est=True)
print(insrm)
# Out:
#        lval  op      rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Mother_r   ~  Infant_r     0.160742  0.291759    0.038230   4.204553
# 1    Diff_r   ~  Mother_r    -0.199075 -0.155758    0.073930  -2.692746
# 2    Diff_r   ~  Infant_r    -0.411230 -0.584002    0.040731 -10.096240
# 3  Mother_r  ~~  Mother_r  2813.886152  0.914877  288.698628   9.746794
# 4    Diff_r  ~~    Diff_r  2922.150626  0.581602  299.806328   9.746794
#
#     p-value
# 0  0.000026
# 1  0.007087
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %%
modri = """Diff_r~Mother_r+Infant_r
           Infant_r~Mother_r
      """
modelri = Model(modri)
resri = modelri.fit(data_rp)
insri = modelri.inspect(std_est=True)
print(insri)
# Out:
#        lval  op      rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Infant_r   ~  Mother_r     0.289421  0.291761    0.068835  4.204580
# 1    Diff_r   ~  Mother_r    -0.199074 -0.226475    0.054654 -3.642418
# 2    Diff_r   ~  Infant_r    -0.411230 -0.464080    0.055096 -7.463857
# 3  Infant_r  ~~  Infant_r  5066.470151  0.914876  519.808870  9.746794
# 4    Diff_r  ~~    Diff_r  2922.150655  0.672009  299.806331  9.746794
#
#         p-value
# 0  2.615674e-05
# 1  2.700890e-04
# 2  8.393286e-14
# 3  0.000000e+00
# 4  0.000000e+00

# %%
modmaxm = """Diff_max~Mother_max+Infant_max
      """
modelmaxm = Model(modmaxm)
resmaxm = modelmaxm.fit(data_maxp)
insmaxm = modelmaxm.inspect(std_est=True)
print(resmaxm,insmaxm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.005
# Number of iterations: 3
# Params: 0.240 -0.594 5701.873        lval  op        rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_max   ~  Mother_max     0.240351  0.201171    0.064047   3.752739
# 1  Diff_max   ~  Infant_max    -0.593554 -0.697123    0.045642 -13.004442
# 2  Diff_max  ~~    Diff_max  5701.873301  0.526521  584.999857   9.746794
#
#     p-value
# 0  0.000175
# 1  0.000000
# 2  0.000000

# %%
statsmax = semopy.calc_stats(modelmaxm)
print(statsmax)
# Out:
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline      CFI  \
# Value    3             5  0.903913      0.824483     178.663883  1.01207
#
#             GFI      AGFI       NFI       TLI  RMSEA       AIC        BIC  \
# Value  0.994941  0.991568  0.994941  1.020116      0  5.990485  15.731557
#
#          LogLik
# Value  0.004757

# %%
coefmmax=np.array(insmaxm.loc[insmaxm['rval']=='Mother_max','Est. Std'])
coefimax=np.array(insmaxm.loc[insmaxm['rval']=='Infant_max','Est. Std'])

errmmax=np.array(insmaxm.loc[insmaxm['rval']=='Mother_max','Std. Err'])
errimax=np.array(insmaxm.loc[insmaxm['rval']=='Infant_max','Std. Err'])

diff_coefmax=coefmmax-coefimax
diff_errmax=(errmmax**2+errimax**2)**0.5

zmax=diff_coefmax/diff_errmax
pmax=2*(1-norm.cdf(abs(zmax)))
print(coefmmax,pmax)
# Out:
# [0.20117142] [0.]

# %%
modmaxm = """Diff_max~Mother_max+Infant_max
            Mother_max~Infant_max
      """
modelmaxm = Model(modmaxm)
resmaxm = modelmaxm.fit(data_maxp)
insmaxm = modelmaxm.inspect(std_est=True)
print(insmaxm)
# Out:
#          lval  op        rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Mother_max   ~  Infant_max     0.134590  0.258044    0.036558   3.681577
# 1    Diff_max   ~  Mother_max     0.240351  0.148639    0.088946   2.702217
# 2    Diff_max   ~  Infant_max    -0.593554 -0.703767    0.046392 -12.794270
# 3  Mother_max  ~~  Mother_max  3793.244795  0.933413  389.178704   9.746794
# 4    Diff_max  ~~    Diff_max  5701.873302  0.536605  584.999857   9.746794
#
#     p-value
# 0  0.000232
# 1  0.006888
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %%
modmaxi = """Diff_max~Mother_max+Infant_max
            Infant_max~Mother_max
      """
modelmaxi = Model(modmaxi)
resmaxi = modelmaxi.fit(data_maxp)
insmaxi = modelmaxi.inspect(std_est=True)
print(insmaxi)
# Out:
#          lval  op        rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Infant_max   ~  Mother_max     0.265016  0.258044    0.071984  3.681579
# 1    Diff_max   ~  Mother_max     0.240351  0.228612    0.065099  3.692088
# 2    Diff_max   ~  Infant_max    -0.593554 -0.579817    0.063386 -9.364046
# 3  Infant_max  ~~  Infant_max  7469.144477  0.933413  766.318054  9.746794
# 4    Diff_max  ~~    Diff_max  5701.873311  0.679958  584.999858  9.746794
#
#     p-value
# 0  0.000232
# 1  0.000222
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %%
modminm = """Diff_min~Mother_min+Infant_min
      """
modelminm = Model(modminm)
resminm = modelminm.fit(data_minp)
insminm = modelminm.inspect(std_est=True)
print(resminm,insminm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.048
# Number of iterations: 3
# Params: 0.422 -0.446 1920.919        lval  op        rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Diff_min   ~  Mother_min     0.421766  0.439841    0.054345  7.760823
# 1  Diff_min   ~  Infant_min    -0.446434 -0.501649    0.050436 -8.851406
# 2  Diff_min  ~~    Diff_min  1920.918636  0.603020  197.082094  9.746794
#
#         p-value
# 0  8.437695e-15
# 1  0.000000e+00
# 2  0.000000e+00

# %%
statsmin = semopy.calc_stats(modelminm)
print(statsmin)
# Out:
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value    3             5  9.073952      0.028324     136.428487  0.953785
#
#             GFI      AGFI       NFI       TLI     RMSEA       AIC        BIC  \
# Value  0.933489  0.889149  0.933489  0.922975  0.103501  5.904485  15.645557
#
#          LogLik
# Value  0.047758

# %%
coefmmin=np.array(insminm.loc[insminm['rval']=='Mother_min','Est. Std'])
coefimin=np.array(insminm.loc[insminm['rval']=='Infant_min','Est. Std'])

errmmin=np.array(insminm.loc[insminm['rval']=='Mother_min','Std. Err'])
errimin=np.array(insminm.loc[insminm['rval']=='Infant_min','Std. Err'])

diff_coefmin=coefmmin-coefimin
diff_errmin=(errmmin**2+errimin**2)**0.5

zmin=diff_coefmin/diff_errmin
pmin=2*(1-norm.cdf(abs(zmin)))
print(coefmmin,zmin,pmin)
# Out:
# [0.43984102] [12.69820234] [0.]

# %%
modminm = """Diff_min~Mother_min+Infant_min
             Mother_min~Infant_min
      """
modelminm = Model(modminm)
resminm = modelminm.fit(data_minp)
insminm = modelminm.inspect(std_est=True)
print(insminm)
# Out:
#          lval  op        rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Mother_min   ~  Infant_min     0.101234  0.152459    0.047609  2.126366
# 1    Diff_min   ~  Mother_min     0.421769  0.330698    0.076398  5.520714
# 2    Diff_min   ~  Infant_min    -0.446429 -0.527152    0.050729 -8.800339
# 3  Mother_min  ~~  Mother_min  1732.191796  0.976756  177.719128  9.746794
# 4    Diff_min  ~~    Diff_min  1920.918674  0.665906  197.082098  9.746794
#
#         p-value
# 0  3.347280e-02
# 1  3.376258e-08
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00

# %%
modmini = """Diff_min~Mother_min+Infant_min
             Infant_min~Mother_min
      """
modelmini = Model(modmini)
resmini = modelmini.fit(data_minp)
insmini = modelmini.inspect(std_est=True)
print(insmini)
# Out:
#          lval  op        rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Infant_min   ~  Mother_min     0.117477  0.152387    0.055275  2.125327
# 1    Diff_min   ~  Mother_min     0.421774  0.469630    0.054660  7.716368
# 2    Diff_min   ~  Infant_min    -0.446439 -0.383217    0.070902 -6.296528
# 3  Infant_min  ~~  Infant_min  2011.098767  0.976778  206.334380  9.746794
# 4    Diff_min  ~~    Diff_min  1920.918694  0.687442  197.082100  9.746794
#
#         p-value
# 0  3.355933e-02
# 1  1.199041e-14
# 2  3.043854e-10
# 3  0.000000e+00
# 4  0.000000e+00

# %%
modmeanm = """Diff_mean~Mother_mean+Infant_mean
      """
modelmeanm = Model(modmeanm)
resmeanm = modelmeanm.fit(data_meanp)
insmeanm = modelmeanm.inspect(std_est=True)
print(resmeanm,insmeanm)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.002
# Number of iterations: 3
# Params: 0.496 -0.587 2546.137         lval  op         rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Diff_mean   ~  Mother_mean     0.496279  0.401182    0.065660   7.558307
# 1  Diff_mean   ~  Infant_mean    -0.586542 -0.646673    0.048143 -12.183389
# 2  Diff_mean  ~~    Diff_mean  2546.136767  0.516937  261.228120   9.746794
#
#         p-value
# 0  4.085621e-14
# 1  0.000000e+00
# 2  0.000000e+00

# %%
statsmean = semopy.calc_stats(modelmeanm)
print(statsmean)
# Out:
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline      CFI  \
# Value    3             5  0.390918      0.942112     184.568514  1.01453
#
#             GFI     AGFI       NFI       TLI  RMSEA       AIC        BIC  \
# Value  0.997882  0.99647  0.997882  1.024216      0  5.995885  15.736957
#
#          LogLik
# Value  0.002057

# %%
coefmmean=np.array(insmeanm.loc[insmeanm['rval']=='Mother_mean','Est. Std'])
coefimean=np.array(insmeanm.loc[insmeanm['rval']=='Infant_mean','Est. Std'])

errmmean=np.array(insmeanm.loc[insmeanm['rval']=='Mother_mean','Std. Err'])
errimean=np.array(insmeanm.loc[insmeanm['rval']=='Infant_mean','Std. Err'])

diff_coefmean=coefmmean-coefimean
diff_errmean=(errmmean**2+errimean**2)**0.5

zmean=diff_coefmean/diff_errmean
pmean=2*(1-norm.cdf(abs(zmean)))
print(coefmmean,diff_errmean,pmean)
# Out:
# [0.40118157] [0.08141843] [0.]

# %%
modmeanm = """Diff_mean~Mother_mean+Infant_mean
              Mother_mean~Infant_mean
      """
modelmeanm = Model(modmeanm)
resmeanm = modelmeanm.fit(data_meanp)
insmeanm = modelmeanm.inspect(std_est=True)
print(insmeanm)
# Out:
#           lval  op         rval     Estimate  Est. Std    Std. Err    z-value  \
# 0  Mother_mean   ~  Infant_mean     0.135755  0.253304    0.037613   3.609266
# 1    Diff_mean   ~  Mother_mean     0.496279  0.304891    0.091252   5.438567
# 2    Diff_mean   ~  Infant_mean    -0.586542 -0.672362    0.048905 -11.993415
# 3  Mother_mean  ~~  Mother_mean  1609.331315  0.935837  165.113909   9.746794
# 4    Diff_mean  ~~    Diff_mean  2546.136763  0.558824  261.228120   9.746794
#
#         p-value
# 0  3.070646e-04
# 1  5.371074e-08
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00

# %%
modmeani = """Diff_mean~Mother_mean+Infant_mean
              Infant_mean~Mother_mean
      """
modelmeani = Model(modmeani)
resmeani = modelmeani.fit(data_meanp)
insmeani = modelmeani.inspect(std_est=True)
print(insmeani)
# Out:
#           lval  op         rval     Estimate  Est. Std    Std. Err   z-value  \
# 0  Infant_mean   ~  Mother_mean     0.252523  0.253306    0.069965  3.609290
# 1    Diff_mean   ~  Mother_mean     0.496278  0.447072    0.066700  7.440440
# 2    Diff_mean   ~  Infant_mean    -0.586542 -0.526752    0.066907 -8.766528
# 3  Infant_mean  ~~  Infant_mean  2993.545541  0.935836  307.131292  9.746794
# 4    Diff_mean  ~~    Diff_mean  2546.136782  0.641964  261.228122  9.746794
#
#         p-value
# 0  3.070364e-04
# 1  1.003642e-13
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00

# %%
diff_maxmulti=np.r_[dataallmare[:,0],dataallmare[:,0]]
maxmulti=np.r_[mothert[:,4],infantt[:,4]]
groupm=np.zeros((len(mothert[:,4])))+1
groupi=np.zeros((len(infantt[:,4])))
group=np.r_[groupm,groupi]
data_maxmulti=np.c_[diff_maxmulti,maxmulti,group]
data_maxmultip=pd.DataFrame(data_maxmulti)
data_maxmultip.columns=['Diff_max','Max','Group']
print(data_maxmultip)
#data_maxmultip.to_csv(r'D:\blockdatae\multiPitchmax.csv')
# Out:
#        Diff_max         Max  Group
# 0   -221.628095  376.187723    1.0
# 1   -157.653878  440.161941    1.0
# 2   -240.428826  202.011404    1.0
# 3    -89.848127  352.592103    1.0
# 4   -290.660815  290.136348    1.0
# ..          ...         ...    ...
# 375 -234.770927  354.770927    0.0
# 376 -269.881150  389.881150    0.0
# 377  -48.503706  389.881150    0.0
# 378 -308.181781  698.713528    0.0
# 379  -33.553723  424.085470    0.0
#
# [380 rows x 3 columns]

# %%
diff_rangemulti=np.r_[dataallrre[:,0],dataallrre[:,0]]
rangemulti=np.r_[mothert[:,3],infantt[:,3]]
groupm=np.zeros((len(mothert[:,3])))+1
groupi=np.zeros((len(infantt[:,3])))
group=np.r_[groupm,groupi]
data_rangemulti=np.c_[diff_rangemulti,rangemulti,group]
data_rangemultip=pd.DataFrame(data_rangemulti)
data_rangemultip.columns=['Diff_range','Range','Group']
print(data_rangemultip)
#data_rangemultip.to_csv(r'D:\blockdatae\multiPitchrange.csv')
# Out:
#      Diff_range       Range  Group
# 0   -100.889998  141.462408    1.0
# 1     -1.687561  240.664846    1.0
# 2    -63.635446   41.337443    1.0
# 3    -54.320879  159.293767    1.0
# 4   -235.826056   90.699964    1.0
# ..          ...         ...    ...
# 375  -63.531214   63.531214    0.0
# 376  -54.368366   54.368366    0.0
# 377 -142.646074   54.368366    0.0
# 378 -167.944137  278.428594    0.0
# 379  -53.017075   57.467383    0.0
#
# [380 rows x 3 columns]

# %%
diff_minmulti=np.r_[dataallmire[:,0],dataallmire[:,0]]
minmulti=np.r_[mothert[:,5],infantt[:,5]]
groupm=np.zeros((len(mothert[:,5])))+1
groupi=np.zeros((len(infantt[:,5])))
group=np.r_[groupm,groupi]
data_minmulti=np.c_[diff_minmulti,minmulti,group]
data_minmultip=pd.DataFrame(data_minmulti)
data_minmultip.columns=['Diff_min','Min','Group']
print(data_minmultip)
#data_minmultip.to_csv(r'D:\blockdatae\multiPitchmin.csv')
# Out:
#        Diff_min         Min  Group
# 0   -120.738097  234.725315    1.0
# 1   -155.966317  199.497095    1.0
# 2   -176.793380  160.673961    1.0
# 3   -144.169006  193.298335    1.0
# 4    -54.834758  199.436384    1.0
# ..          ...         ...    ...
# 375 -171.239712  291.239712    0.0
# 376 -215.512784  335.512784    0.0
# 377 -191.149780  335.512784    0.0
# 378 -140.237644  420.284933    0.0
# 379  -86.570798  366.618087    0.0
#
# [380 rows x 3 columns]

# %%
diff_meanmulti=np.r_[dataallmere[:,0],dataallmere[:,0]]
meanmulti=np.r_[mothert[:,6],infantt[:,6]]
groupm=np.zeros((len(mothert[:,6])))+1
groupi=np.zeros((len(infantt[:,6])))
group=np.r_[groupm,groupi]
data_meanmulti=np.c_[diff_meanmulti,meanmulti,group]
data_meanmultip=pd.DataFrame(data_meanmulti)
data_meanmultip.columns=['Diff_mean','Mean','Group']
print(data_meanmultip)
#data_meanmultip.to_csv(r'D:\blockdatae\multiPitchmean.csv')
# Out:
#       Diff_mean        Mean  Group
# 0   -130.402386  290.307079    1.0
# 1   -117.144908  303.564557    1.0
# 2   -222.249121  173.097702    1.0
# 3   -169.652032  225.694790    1.0
# 4   -185.528632  227.757410    1.0
# ..          ...         ...    ...
# 375 -206.894803  326.894803    0.0
# 376 -243.006620  363.006620    0.0
# 377 -125.320261  363.006620    0.0
# 378 -141.187225  492.499772    0.0
# 379  -43.631182  394.943729    0.0
#
# [380 rows x 3 columns]

# %%
#data_d=np.c_[diff[:,1],mothert[:,1],infantt[:,1]]
#data_dp=pd.DataFrame(data_d)
#data_dp.columns=['Diff_d','Mother_d','Infant_d']
#data_dp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Duration.csv')
#data_dp.to_csv(r'D:\blockdatae\Duration.csv')
data_r=np.c_[dataallrre[:,0],mothert[:,3],infantt[:,3]]
data_rp=pd.DataFrame(data_r)
data_rp.columns=['Diff_r','Mother_r','Infant_r']
#data_rp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Pitchrange.csv')
#data_rp.to_csv(r'D:\blockdatae\Pitchrange.csv')
data_max=np.c_[dataallmare[:,0],mothert[:,4],infantt[:,4]]
data_maxp=pd.DataFrame(data_max)
data_maxp.columns=['Diff_max','Mother_max','Infant_max']
#data_maxp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Pitchmax.csv')
#data_maxp.to_csv(r'D:\blockdatae\Pitchmax.csv')
data_min=np.c_[dataallmire[:,0],mothert[:,5],infantt[:,5]]
data_minp=pd.DataFrame(data_min)
data_minp.columns=['Diff_min','Mother_min','Infant_min']
#data_minp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Pitchmin.csv')
#data_minp.to_csv(r'D:\blockdatae\Pitchmin.csv')
data_mean=np.c_[dataallmere[:,0],mothert[:,6],infantt[:,6]]
data_meanp=pd.DataFrame(data_mean)
data_meanp.columns=['Diff_mean','Mother_mean','Infant_mean']
#data_meanp.to_csv(r'C:\LJR\babylab\marisa\datamanual\cut\blockdata\Pitchmean.csv')
#data_meanp.to_csv(r'D:\blockdatae\Pitchmean.csv')

# %%
#print('cofft of duration=',stats.pearsonr(xlabel,diff[:,1]))
#print('cofft of mfcc=',stats.pearsonr(xlabel,diff[:,2]))
print('cofft of f0_range=',stats.pearsonr(dataallrre[:,1],dataallrre[:,0]))
print('cofft of f0_max=',stats.pearsonr(dataallmare[:,1],dataallmare[:,0]))
print('cofft of f0_min=',stats.pearsonr(dataallmire[:,1],dataallmire[:,0]))
print('cofft of f0_mean=',stats.pearsonr(dataallmere[:,1],dataallmere[:,0]))
#print('cofft of energy_rms=',stats.pearsonr(xlabel,diff[:,7]))
#print('cofft of energy_zc=',stats.pearsonr(xlabel,diff[:,8]))
# Out:
# cofft of f0_range= PearsonRResult(statistic=-0.07308869191371588, pvalue=0.31627068898792554)
# cofft of f0_max= PearsonRResult(statistic=0.0649051225267941, pvalue=0.3736322913312226)
# cofft of f0_min= PearsonRResult(statistic=0.1128428610404236, pvalue=0.1211121077414905)
# cofft of f0_mean= PearsonRResult(statistic=0.13016401954627121, pvalue=0.07345868218392408)

# %%
plt.scatter(xlabel,diff[:,6], color='blue')
#plt.scatter(xlabel115,diffc115[:,6], color='red')
plt.scatter(xlabel22,diffc22[:,6], color='yellow')
plt.xlabel('Turns', fontsize=12)
plt.ylabel('Diff_Mean pitch',fontsize=12)
# Out:
# Text(0, 0.5, 'Diff_Mean pitch')

# %%
f0mean=np.c_[xlabel,-diff[:,6]]
f0meanp=pd.DataFrame(f0mean)
f0meanp.columns=['Turns','Diff_f0 mean']

# %%
f0range=np.c_[xlabel,-diff[:,3]]
f0rangep=pd.DataFrame(f0range)
f0meanp.columns=['Turns','Diff_f0 range']

# %%
f0max=np.c_[xlabel,-diff[:,4]]
f0maxp=pd.DataFrame(f0max)
f0maxp.columns=['Turns','Diff_f0 max']

# %%
f0min=np.c_[xlabel,-diff[:,5]]
f0minp=pd.DataFrame(f0min)
f0minp.columns=['Turns','Diff_f0 min']

# %%
print(np.mean(-diff[:,3]),np.mean(-diff[:,4]),np.mean(-diff[:,5]),np.mean(-diff[:,6]))
# Out:
# 82.001031861069 112.83576576411265 83.27092916220425 88.71592822083458

# %%
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
p1=plt.scatter(xlabel1,diffc1[:,6],color="navy")
p2=plt.scatter(xlabel2,diffc2[:,6],color="royalblue")
p3=plt.scatter(xlabel3,diffc3[:,6],color="paleturquoise")
p4=plt.scatter(xlabel4,diffc4[:,6],color="aqua")
p5=plt.scatter(xlabel5,diffc5[:,6],color="blue")
p6=plt.scatter(xlabel6,diffc6[:,6],color="lightcyan")
#plt.legend(handles=[p1,p2,p3,p4,p5,p6,p7,p8,p9],labels=['No.1','No.4','No.9','No.10','No.8','No.2','No.7','No.6','No.5'],loc='best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,17)
plt.ylim(-700,10)
linear_model=np.polyfit(xlabel,-diff[:,6],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(xlabel,linear_model_fn(xlabel),color="k")

# %%
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
p1=plt.scatter(xlabel1,diffc1[:,3],color="navy")
p2=plt.scatter(xlabel2,diffc2[:,3],color="royalblue")
p3=plt.scatter(xlabel3,diffc3[:,3],color="paleturquoise")
p4=plt.scatter(xlabel4,diffc4[:,3],color="aqua")
p5=plt.scatter(xlabel5,diffc5[:,3],color="blue")
p6=plt.scatter(xlabel6,diffc6[:,3],color="lightcyan")
#plt.legend(handles=[p1,p2,p3,p4,p5,p6,p7,p8,p9],labels=['No.1','No.4','No.9','No.10','No.8','No.2','No.7','No.6','No.5'],loc='best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,17)
plt.ylim(-700,10)
linear_model=np.polyfit(xlabel,-diff[:,3],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(xlabel,linear_model_fn(xlabel),color="k")

# %%
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
p1=plt.scatter(xlabel1,diffc1[:,4],color="navy")
p2=plt.scatter(xlabel2,diffc2[:,4],color="royalblue")
p3=plt.scatter(xlabel3,diffc3[:,4],color="paleturquoise")
p4=plt.scatter(xlabel4,diffc4[:,4],color="aqua")
p5=plt.scatter(xlabel5,diffc5[:,4],color="blue")
p6=plt.scatter(xlabel6,diffc6[:,4],color="lightcyan")
#plt.legend(handles=[p1,p2,p3,p4,p5,p6,p7,p8,p9],labels=['No.1','No.4','No.9','No.10','No.8','No.2','No.7','No.6','No.5'],loc='best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,17)
plt.ylim(-700,10)
linear_model=np.polyfit(xlabel,-diff[:,4],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(xlabel,linear_model_fn(xlabel),color="k")

# %%
corrrangefas=stats.pearsonr(xlabel,diff[:,3])
corrmaxfas=stats.pearsonr(xlabel,diff[:,4])
corrminfas=stats.pearsonr(xlabel,diff[:,5])
corrmeanfas=stats.pearsonr(xlabel,diff[:,6])

p_vfas=np.r_[corrrangefas[1],corrmaxfas[1],corrminfas[1],corrmeanfas[1]]

# %%
from statsmodels.stats import multitest
multitest.multipletests(p_vfas,alpha=0.1,method='fdr_bh')
# Out:
# (array([False, False, False, False]),
#  array([0.61574157, 0.67581499, 0.60662567, 0.60662567]),
#  0.025996253574703254,
#  0.025)

# %%
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
p1=plt.scatter(xlabel1,diffc1[:,5],color="navy")
p2=plt.scatter(xlabel2,diffc2[:,5],color="royalblue")
p3=plt.scatter(xlabel3,diffc3[:,5],color="paleturquoise")
p4=plt.scatter(xlabel4,diffc4[:,5],color="aqua")
p5=plt.scatter(xlabel5,diffc5[:,5],color="blue")
p6=plt.scatter(xlabel6,diffc6[:,5],color="lightcyan")
#plt.legend(handles=[p1,p2,p3,p4,p5,p6,p7,p8,p9],labels=['No.1','No.4','No.9','No.10','No.8','No.2','No.7','No.6','No.5'],loc='best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,17)
plt.ylim(-700,10)
linear_model=np.polyfit(xlabel,-diff[:,5],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(xlabel,linear_model_fn(xlabel),color="k")

# %%
plt.plot(diffc24[:,6],'*',color='black')
plt.plot(t24[:,6],'*',color='red')
plt.plot(tc24[:,6],'*',color='blue')

# %%
plt.scatter(dataallmep['IV'], dataallmep['DV'], label='Data')
linear_model=np.polyfit(dataallmep['IV'],dataallmep['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmep['IV'],linear_model_fn(dataallmep['IV']),color="k")
plt.ylim(-450,10)
# Out:
# (-450.0, 10.0)

# %%
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel12,diffc12[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel13,diffc13[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel53,diffc53[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel24,diffc24[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel41,diffc41[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel43,diffc43[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel31,diffc31[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmepre['IV'], dataallmepre['DV'], label='Data')
plt.scatter(xlabel122,diffc122[:,6], color='yellow')
linear_model=np.polyfit(dataallmepre['IV'],dataallmepre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmepre['IV'],linear_model_fn(dataallmepre['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel12,diffc12[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel13,diffc13[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel53,diffc53[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel24,diffc24[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel41,diffc41[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel43,diffc43[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel31,diffc31[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmapre['IV'], dataallmapre['DV'], label='Data')
plt.scatter(xlabel122,diffc122[:,4], color='yellow')
linear_model=np.polyfit(dataallmapre['IV'],dataallmapre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmapre['IV'],linear_model_fn(dataallmapre['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(dataallmap['IV'], dataallmap['DV'], label='Data')
linear_model=np.polyfit(dataallmap['IV'],dataallmap['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmap['IV'],linear_model_fn(dataallmap['IV']),color="k")
plt.ylim(-750,10)
# Out:
# (-750.0, 10.0)

# %%
plt.scatter(dataallmip['IV'], dataallmip['DV'], label='Data')
linear_model=np.polyfit(dataallmip['IV'],dataallmip['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmip['IV'],linear_model_fn(dataallmip['IV']),color="k")
plt.ylim(-410,10)
# Out:
# (-410.0, 10.0)

# %%
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel12,diffc12[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel13,diffc13[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel53,diffc53[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel24,diffc24[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel41,diffc41[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel43,diffc43[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel31,diffc31[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallmipre['IV'], dataallmipre['DV'], label='Data')
plt.scatter(xlabel122,diffc122[:,4], color='yellow')
linear_model=np.polyfit(dataallmipre['IV'],dataallmipre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallmipre['IV'],linear_model_fn(dataallmipre['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(dataallrp['IV'], dataallrp['DV'], label='Data')
linear_model=np.polyfit(dataallrp['IV'],dataallrp['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrp['IV'],linear_model_fn(dataallrp['IV']),color="k")
plt.ylim(-650,10)
# Out:
# (-650.0, 10.0)

# %%
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel12,diffc12[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel13,diffc13[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel53,diffc53[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel24,diffc24[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel41,diffc41[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel43,diffc43[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel31,diffc31[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()
plt.scatter(dataallrpre['IV'], dataallrpre['DV'], label='Data')
plt.scatter(xlabel122,diffc122[:,3], color='yellow')
linear_model=np.polyfit(dataallrpre['IV'],dataallrpre['DV'],1)
linear_model_fn=np.poly1d(linear_model)
plt.plot(dataallrpre['IV'],linear_model_fn(dataallrpre['IV']),color="k")
plt.ylim(-450,10)
plt.show()

# %%
plt.scatter(xlabel31,tc31[:,6],c='r')
plt.scatter(xlabel31,t31[:,6],c='b')

# %%
print(tc31[:,6],t31[:,6])
# Out:
# [330.55497855 303.0690447  303.0690447  288.96501086 288.96501086
#  350.22353844 350.22353844 289.61825059 289.61825059] [255.31329524 255.31329524 278.61461411 278.61461411 258.65174785
#  258.65174785 316.85061804 316.85061804 271.42857235]

# %%
print(tc31[:,5],t31[:,5])
# Out:
# [301.25503877 278.89094087 278.89094087 240.         240.
#  322.21740067 322.21740067 257.22563101 257.22563101] [223.84265339 223.84265339 247.03253679 247.03253679 247.03253679
#  247.03253679 267.83931423 267.83931423 238.81278333]

# %%
print(tc31[:,4],t31[:,4])
# Out:
# [345.20146996 311.24149312 311.24149312 302.38105197 302.38105197
#  374.43130849 374.43130849 322.21740067 322.21740067] [283.04309331 283.04309331 300.63946527 300.63946527 270.95145715
#  270.95145715 383.18322545 383.18322545 304.64023494]

# %%
print(tc31[:,3],t31[:,3])
# Out:
# [43.94643119 32.35055225 32.35055225 62.38105197 62.38105197 52.21390782
#  52.21390782 64.99176966 64.99176966] [ 59.20043991  59.20043991  53.60692848  53.60692848  23.91892036
#   23.91892036 115.34391122 115.34391122  65.82745161]

# %%
iexpr=np.array([[1,43.94],[3,32.35],[5,62.38],[7,52.21],[9,64.99]])
mexpr=np.array([[2,59.20],[4,53.61],[6,23.92],[8,115.34],[10,65.83]])
plt.plot(iexpr[:,0],iexpr[:,1],'*-',c='orange')
plt.plot(mexpr[:,0],mexpr[:,1],'*-',c='b')
plt.ylim(20,140)
# Out:
# (20.0, 140.0)

# %%
iexpma=np.array([[1,345.20],[3,311.24],[5,302.38],[7,374.43],[9,322.22]])
mexpma=np.array([[2,283.04],[4,300.64],[6,270.95],[8,383.18],[10,304.64]])
plt.plot(iexpma[:,0],iexpma[:,1],'*-',c='r')
plt.plot(mexpma[:,0],mexpma[:,1],'*-',c='b')
plt.ylim(220,460)
# Out:
# (220.0, 460.0)

# %%
iexpmi=np.array([[1,301.26],[3,278.89],[5,240],[7,322.22],[9,257.23]])
mexpmi=np.array([[2,223.84],[4,247.03],[6,247.03],[8,267.84],[10,238.81]])
plt.plot(iexpmi[:,0],iexpmi[:,1],'*-',c='r')
plt.plot(mexpmi[:,0],mexpmi[:,1],'*-',c='b')
plt.ylim(170,360)
# Out:
# (170.0, 360.0)

# %%
iexpme=np.array([[1,330.55],[3,303.07],[5,288.97],[7,350.22],[9,289.62]])
mexpme=np.array([[2,255.31],[4,278.61],[6,258.65],[8,316.85],[10,271.43]])
plt.rc('font',family='Times New Roman')
fig, ax=plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(iexpme[:,0],iexpme[:,1],'*-',c='orangered')
plt.plot(mexpme[:,0],mexpme[:,1],'*-',c='b')
plt.ylim(190,420)
filesaveconmee=r'C:\LJR\paper\tseltalvsenglish\figures\eexample.jpg'
fig.savefig(filesaveconmee, bbox_inches='tight', pad_inches=0)

# %%
print(tc110[:,6],t110[:,6])
# Out:
# [462.87932392 462.87932392 363.68756801 363.68756801 380.71900767
#  380.71900767 386.29971282] [427.33957904 409.02436373 409.02436373 354.10752229 354.10752229
#  375.44516639 375.44516639]

# %%
testi=np.array([[2,462.88],[4,363.69],[6,380.72],[8,386.30]])
testa=np.array([[1,427.34],[3,409.02],[5,354.11],[7,375.45]])
plt.plot(testi[:,0],testi[:,1],'*-',c='r')
plt.plot(testa[:,0],testa[:,1],'*-',c='b')
